# %%
import pandas as pd
import re, os, string
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score, average_precision_score,precision_score,f1_score,recall_score
import spacy
import matplotlib.pyplot as plt

# %%
nlp_nl = spacy.load('nl_core_news_sm')

# %%
def clean_text(text):
    """Doc cleaning"""
    
    # Lowering text
    text = text.lower()
    
    # Removing punctuation
    text = "".join([c for c in text if c not in PUNCTUATION])
    
    # Removing whitespace and newlines
    text = re.sub('\s+',' ',text)
    
    # extract Noun
    noun_words = []
    for token in nlp_nl(text):
        taged_w = token.pos_
        if taged_w == 'NOUN':
            noun_words.append(token.lemma_)
            text = ' '.join(noun_words)
    
    return text

# %%
def get_stopwords_list(stop_file_path):
    """load stop words """
    
    with open(stop_file_path, 'r', encoding="utf-8") as f:
        stopwords = f.readlines()
        stop_set = set(m.strip() for m in stopwords)
        return list(frozenset(stop_set))

# %%
def sort_coo(coo_matrix):
    """Sort a dict with highest score"""
    tuples = zip(coo_matrix.col, coo_matrix.data)
    return sorted(tuples, key=lambda x: (x[1], x[0]), reverse=True)

def extract_topn_from_vector(feature_names, sorted_items, topn=10):
    """get the feature names and tf-idf score of top n items"""
    
    #use only topn items from vector
    sorted_items = sorted_items[:topn]

    score_vals = []
    feature_vals = []
    
    # word index and corresponding tf-idf score
    for idx, score in sorted_items:
        
        #keep track of feature name and its corresponding score
        score_vals.append(round(score, 3))
        feature_vals.append(feature_names[idx])

    #create a tuples of feature, score
    results= {}
    for idx in range(len(feature_vals)):
        results[feature_vals[idx]]=score_vals[idx]
    
    return results

# %%
def get_keywords(vectorizer, feature_names, doc):
    """Return top k keywords from a doc using TF-IDF method"""

    #generate tf-idf for the given document
    tf_idf_vector = vectorizer.transform([doc])
    
    #sort the tf-idf vectors by descending order of scores
    sorted_items=sort_coo(tf_idf_vector.tocoo())

    #extract only TOP_K_KEYWORDS
    keywords=extract_topn_from_vector(feature_names,sorted_items,TOP_K_KEYWORDS)
    
    return list(keywords.keys())

# %%
# Constants
PUNCTUATION = """!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~""" 
TOP_K_KEYWORDS = 10 # top k number of keywords to retrieve in a ranked document
STOPWORD_PATH = "../data/stopwords/nl_stopwords_list.txt"
PAPERS_PATH = "../data/test_data.csv"

# %%
data = pd.read_csv(PAPERS_PATH,encoding="unicode_escape")
data.head()
# Out:
#                           title         chapter  \
# 0  Library Guide Google scholar  Google scholar
# 1  Library Guide Healthy Ageing  Healthy Ageing
# 2        Library Guide Refworks         Reforks
# 3             Outreach de focus  Hoe wat waarom
# 4       Hoe herken je fake news             NaN
#
#                                              content  \
# 0  Wat is Google Scholar?\nGoogle Scholar biedt e...
# 1  Systematisch zoeken\nIn deze library guide kri...
# 2  Wat is RefWorks?\nBeheer en verwerk je bronnen...
# 3  Na het voltooien van je scriptie, hoeft het we...
# 4  en heel erg om de nieuws uit met name rusland ...
#
#                                          gold_label  \
# 0      Selecteren informatiebronnen en zoeksystemen
# 1                                 Plannen en zoeken
# 2                  Managen proces en zoekresultaten
# 3            Valoriseren van bevindingen (outreach)
# 4  Beoordelingscriteria relevantie/ betrouwbaarheid
#
#                                        bl_label  \
# 0  Selecteren informatiebronnen en zoeksystemen
# 1                        Informatievaardigheden
# 2               Manage proces en zoekresultaten
# 3        Valoriseren van bevindingen (outreach)
# 4          Beoordelen van resultaten (kritisch)
#
#                                          w2v_label
# 0  Aard en verschijningsvormen van informatie/data
# 1                  Manage proces en zoekresultaten
# 2                  Manage proces en zoekresultaten
# 3                       Waarde van informatie/data
# 4             Beoordelen van resultaten (kritisch)

# %%
data.dropna(subset=['content'], inplace=True)

# %%
data['content'] = data['content'].apply(clean_text)
data.head()
# Out:
#                           title         chapter  \
# 0  Library Guide Google scholar  Google scholar
# 1  Library Guide Healthy Ageing  Healthy Ageing
# 2        Library Guide Refworks         Reforks
# 3             Outreach de focus  Hoe wat waarom
# 4       Hoe herken je fake news             NaN
#
#                                              content  \
# 0  manier lijn literatuur plek discipline bron ar...
# 1  uitleg aanpak gebied ageing tabblad zoekstrate...
# 2  beheer verwerken refwork refwork citatie logbo...
# 3  scriptie proces einde wetenschap rapporter ond...
# 4  nieuws naam democratie muziek koning mens inte...
#
#                                          gold_label  \
# 0      Selecteren informatiebronnen en zoeksystemen
# 1                                 Plannen en zoeken
# 2                  Managen proces en zoekresultaten
# 3            Valoriseren van bevindingen (outreach)
# 4  Beoordelingscriteria relevantie/ betrouwbaarheid
#
#                                        bl_label  \
# 0  Selecteren informatiebronnen en zoeksystemen
# 1                        Informatievaardigheden
# 2               Manage proces en zoekresultaten
# 3        Valoriseren van bevindingen (outreach)
# 4          Beoordelen van resultaten (kritisch)
#
#                                          w2v_label
# 0  Aard en verschijningsvormen van informatie/data
# 1                  Manage proces en zoekresultaten
# 2                  Manage proces en zoekresultaten
# 3                       Waarde van informatie/data
# 4             Beoordelen van resultaten (kritisch)

# %%
corpora = data['content'].to_list()

# %%
#load a set of stop words
stopwords=get_stopwords_list(STOPWORD_PATH)

# Initializing TF-IDF Vectorizer with stopwords
vectorizer = TfidfVectorizer(ngram_range=(1,1),stop_words=stopwords, smooth_idf=True, use_idf=True)

# Creating vocab with our corpora
vectorizer.fit_transform(corpora)

# Storing vocab
feature_names = vectorizer.get_feature_names()

# %%
result = [] #a list of dictionary, key is 'top_keywords', value is list of keywords
for doc in corpora:
    df = {}
    #df['full_text'] = doc
    df['top_keywords'] = get_keywords(vectorizer, feature_names, doc)
    result.append(df)


final = pd.DataFrame(result)
final
# Out:
#                                          top_keywords
# 0   [schouder, reus, literatuur, document, plek, c...
# 1   [zoekstrategie, uitleg, tabblad, literatuurond...
# 2   [citatie, referentie, toevoeg, refwork, logboe...
# 3   [kennis, publiek, maatschappij, doelgroep, die...
# 4   [nieuws, bericht, verkiezing, leven, intentie,...
# 5   [search, mesh, subject, querie, filter, zoekop...
# 6   [informatie, vraag, waarde, proces, kanaal, fa...
# 7   [afbeelding, plaat, toestemming, licentie, rec...
# 8   [foto, film, maker, kunstwerk, toestemming, af...
# 9   [zoekbalk, optie, zoekresultaat, motivatie, le...
# 10  [industrie, hotel, airbnb, catalogus, woord, z...
# 11  [koffie, invloed, deelvrag, onderzoeksonderwer...
# 12  [drank, koffie, hyponiem, zoekterm, student, o...
# 13  [informatie, internet, catalogus, database, br...
# 14  [zoekterm, koffie, consumptie, student, filety...
# 15  [bron, punt, overheid, ding, autoriteit, menin...
# 16  [bron, atema, achternaam, citatie, auteur, bro...
# 17  [verslag, bedrijfsgegeven, persoon, informatie...
# 18  [jans, stijl, inwoner, criminaliteit, citatie,...
# 19  [verwijzing, lijst, referentie, stijl, bibliot...
# 20  [informatie, obesitas, boek, artikel, vraag, u...
# 21  [kop, einde, conclusie, tekst, hoofdstuk, arti...
# 22  [melding, scholar, filter, google, zoekopdrach...
# 23  [informatie, mening, vraag, bron, datum, auteu...
# 24  [bron, informatie, catalogus, verwijzing, soor...
# 25  [autoriteit, bruikbaarheid, werkstuk, houding,...
# 26  [richtlijn, volstaan, verwerk, bod, betrekking...
# 27  [zoekvraag, punt, resultaat, informatiebron, z...
# 28  [jans, stijl, inwoner, criminaliteit, citatie,...
# 29  [schermafbeelding, libguide, universiteit, voo...
# 30  [informatie, herkomst, uitgever, site, web, br...
# 31  [publicatie, boek, literatuurverwijzing, weten...
# 32  [onderzoek, bron, taal, materiaal, gebied, mus...
# 33  [operator, woord, zoekoperator, wildcard, teke...
# 34  [referentie, boek, hoofdstuk, titel, type, tij...
# 35  [boek, ebook, librarie, titel, artikel, refere...
# 36  [collectie, dissertatie, zoekmogelijkheid, scr...
# 37  [schermafbeelding, libguide, universiteit, voo...
# 38  [informatie, herkomst, uitgever, site, web, br...
# 39  [publicatie, boek, literatuurverwijzing, weten...
# 40  [rechtsbron, wet, uitspraak, rechtsorde, juris...
# 41  [operator, woord, zoekoperator, wildcard, teke...
# 42  [referentie, boek, hoofdstuk, titel, type, tij...
# 43  [boek, ebook, librarie, titel, artikel, refere...
# 44  [zoeklicht, informatie, onderbouwing, gericht,...
# 45  [thesaurus, term, onderwijs, zoekterm, vakblad...
# 46  [tijdschrift, niveau, bron, databank, vaktijds...
# 47  [werk, cclicentie, informatie, licentie, bouws...
# 48  [cursus, informatie, manier, logboek, zoeklogb...
# 49  [zoekterm, hulpmiddel, woordenboek, element, g...
# 50  [informatie, databank, soort, informatiebron, ...
# 51  [zoekfilter, zoekveld, stad, zoekresultaat, pu...
# 52  [website, criterium, betrouwbaarheid, relevant...
# 53  [verslag, citatiestijl, apastijl, auteursrecht...

# %%
text_keyword=[]
for item in result:
    text_keyword.append(item['top_keywords'])
print(text_keyword[:5])
# Out:
# [['schouder', 'reus', 'literatuur', 'document', 'plek', 'collectie', 'onderzoeker', 'vereniging', 'repositorie', 'opinie'], ['zoekstrategie', 'uitleg', 'tabblad', 'literatuuronderzoek', 'onderdeel', 'beoordeel', 'pagina', 'zoektechniek', 'zoekmethode', 'subpagina'], ['citatie', 'referentie', 'toevoeg', 'refwork', 'logboek', 'worddocument', 'verwerken', 'procesmanagement', 'kopie', 'folder'], ['kennis', 'publiek', 'maatschappij', 'doelgroep', 'dienst', 'einde', 'resultaat', 'onderzoek', 'writing', 'weg'], ['nieuws', 'bericht', 'verkiezing', 'leven', 'intentie', 'beslissing', 'arno', 'tijd', 'muziek', 'mens']]

# %%
# read taxonomy
import pickle
with open('../data/LO_picklefile/surf.pickle','rb') as pickle_file:
    los = pickle.load(pickle_file)

# %%
extracted_key_value_from_dict = []
for item in los:
    key_to_extract = {'name','keywords'}
    extracted_dict = {key: item[key] for key in item.keys()
                               & key_to_extract}
    extracted_key_value_from_dict.append(extracted_dict)

# %%
def classify_text(text_kws, los):
    """classify text by counting the overlapping keywords between text and taxonomy
       text_kws: list of lists, keywords extracted from text
       los: list of dicts, keywords of learning obkectives
    """
    rv = []
    for ks in text_kws:
        #initialize the value of lo['name']
        scores = {lo['name']: 0 for lo in los}
        for lo in los:
            #create a set to collect cleaned value of dictionary
            cl=set()
            for kw in lo['keywords']:
                # clean up the value of dictionary
                cw = kw.lower().replace('_',' ')
                cl.add(cw)
            scores[lo['name']] = len(cl & set(ks))
        rv.append(scores)
            
    return rv

# %%
text_kws = text_keyword
los = extracted_key_value_from_dict
classified=classify_text(text_kws, los)

# %%
#sort dictionary by the number of overlapping keywords, from high to low
for dic in classified:
    x=sorted(dic.items(), key=lambda dic:dic[1], reverse=True)
    print(x)
    print()
    print(x[0][0])
    print()
# Out:
# [('Selecteren informatiebronnen en zoeksystemen', 1), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Waarde van informatie/data', 0), ('Aard en verschijningsvormen van informatie/data', 0), ('Werking en structuur van het internet', 0), ('Rol en totstandkoming van netwerken', 0), ('Individu in het informatielandschap', 0), ('Identificeren van informatiebehoefte', 0), ('Zoeken ter oriëntatie', 0), ('Formuleren van onderzoeksvraag', 0), ('Plannen en zoeken', 0), ('Selecteren zoektermen', 0), ('Zoeken naar informatie', 0), ('Kritisch beoordelen', 0), ('Beoordelen van resultaten (kritisch)', 0), ('Informatieverwerking (lezen, luisteren e.d.)', 0), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 0), ('Evalueren van zoekproces (kritisch)', 0), ('Organiseren en verwerken', 0), ('Manage proces en zoekresultaten', 0), ('Samenwerken (in teams)', 0), ('Analyseren van zoekresultaten (informatieanalyse)', 0), ('Gebruik en verwerken van informatie (ethisch)', 0), ('Bronvermelding', 0), ('Auteursrecht', 0), ('Privacygevoelige informatie', 0), ('Synthetiseren of creëren van nieuwe informatie', 0), ('Publiceren en communiceren', 0), ('Publiceren (van eindproduct)', 0), ('Communiceren (van eindproduct)', 0), ('Valoriseren van bevindingen (outreach)', 0)]
#
# Selecteren informatiebronnen en zoeksystemen
#
# [('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Waarde van informatie/data', 0), ('Aard en verschijningsvormen van informatie/data', 0), ('Werking en structuur van het internet', 0), ('Rol en totstandkoming van netwerken', 0), ('Individu in het informatielandschap', 0), ('Identificeren van informatiebehoefte', 0), ('Zoeken ter oriëntatie', 0), ('Formuleren van onderzoeksvraag', 0), ('Plannen en zoeken', 0), ('Selecteren informatiebronnen en zoeksystemen', 0), ('Selecteren zoektermen', 0), ('Zoeken naar informatie', 0), ('Kritisch beoordelen', 0), ('Beoordelen van resultaten (kritisch)', 0), ('Informatieverwerking (lezen, luisteren e.d.)', 0), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 0), ('Evalueren van zoekproces (kritisch)', 0), ('Organiseren en verwerken', 0), ('Manage proces en zoekresultaten', 0), ('Samenwerken (in teams)', 0), ('Analyseren van zoekresultaten (informatieanalyse)', 0), ('Gebruik en verwerken van informatie (ethisch)', 0), ('Bronvermelding', 0), ('Auteursrecht', 0), ('Privacygevoelige informatie', 0), ('Synthetiseren of creëren van nieuwe informatie', 0), ('Publiceren en communiceren', 0), ('Publiceren (van eindproduct)', 0), ('Communiceren (van eindproduct)', 0), ('Valoriseren van bevindingen (outreach)', 0)]
#
# Informatievaardigheden
#
# [('Manage proces en zoekresultaten', 3), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 2), ('Zoeken ter oriëntatie', 1), ('Evalueren van zoekproces (kritisch)', 1), ('Bronvermelding', 1), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Waarde van informatie/data', 0), ('Aard en verschijningsvormen van informatie/data', 0), ('Werking en structuur van het internet', 0), ('Rol en totstandkoming van netwerken', 0), ('Individu in het informatielandschap', 0), ('Identificeren van informatiebehoefte', 0), ('Formuleren van onderzoeksvraag', 0), ('Plannen en zoeken', 0), ('Selecteren informatiebronnen en zoeksystemen', 0), ('Selecteren zoektermen', 0), ('Zoeken naar informatie', 0), ('Kritisch beoordelen', 0), ('Beoordelen van resultaten (kritisch)', 0), ('Informatieverwerking (lezen, luisteren e.d.)', 0), ('Organiseren en verwerken', 0), ('Samenwerken (in teams)', 0), ('Analyseren van zoekresultaten (informatieanalyse)', 0), ('Gebruik en verwerken van informatie (ethisch)', 0), ('Auteursrecht', 0), ('Privacygevoelige informatie', 0), ('Synthetiseren of creëren van nieuwe informatie', 0), ('Publiceren en communiceren', 0), ('Publiceren (van eindproduct)', 0), ('Communiceren (van eindproduct)', 0), ('Valoriseren van bevindingen (outreach)', 0)]
#
# Manage proces en zoekresultaten
#
# [('Valoriseren van bevindingen (outreach)', 2), ('Aard en verschijningsvormen van informatie/data', 1), ('Communiceren (van eindproduct)', 1), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Waarde van informatie/data', 0), ('Werking en structuur van het internet', 0), ('Rol en totstandkoming van netwerken', 0), ('Individu in het informatielandschap', 0), ('Identificeren van informatiebehoefte', 0), ('Zoeken ter oriëntatie', 0), ('Formuleren van onderzoeksvraag', 0), ('Plannen en zoeken', 0), ('Selecteren informatiebronnen en zoeksystemen', 0), ('Selecteren zoektermen', 0), ('Zoeken naar informatie', 0), ('Kritisch beoordelen', 0), ('Beoordelen van resultaten (kritisch)', 0), ('Informatieverwerking (lezen, luisteren e.d.)', 0), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 0), ('Evalueren van zoekproces (kritisch)', 0), ('Organiseren en verwerken', 0), ('Manage proces en zoekresultaten', 0), ('Samenwerken (in teams)', 0), ('Analyseren van zoekresultaten (informatieanalyse)', 0), ('Gebruik en verwerken van informatie (ethisch)', 0), ('Bronvermelding', 0), ('Auteursrecht', 0), ('Privacygevoelige informatie', 0), ('Synthetiseren of creëren van nieuwe informatie', 0), ('Publiceren en communiceren', 0), ('Publiceren (van eindproduct)', 0)]
#
# Valoriseren van bevindingen (outreach)
#
# [('Beoordelen van resultaten (kritisch)', 1), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 1), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Waarde van informatie/data', 0), ('Aard en verschijningsvormen van informatie/data', 0), ('Werking en structuur van het internet', 0), ('Rol en totstandkoming van netwerken', 0), ('Individu in het informatielandschap', 0), ('Identificeren van informatiebehoefte', 0), ('Zoeken ter oriëntatie', 0), ('Formuleren van onderzoeksvraag', 0), ('Plannen en zoeken', 0), ('Selecteren informatiebronnen en zoeksystemen', 0), ('Selecteren zoektermen', 0), ('Zoeken naar informatie', 0), ('Kritisch beoordelen', 0), ('Informatieverwerking (lezen, luisteren e.d.)', 0), ('Evalueren van zoekproces (kritisch)', 0), ('Organiseren en verwerken', 0), ('Manage proces en zoekresultaten', 0), ('Samenwerken (in teams)', 0), ('Analyseren van zoekresultaten (informatieanalyse)', 0), ('Gebruik en verwerken van informatie (ethisch)', 0), ('Bronvermelding', 0), ('Auteursrecht', 0), ('Privacygevoelige informatie', 0), ('Synthetiseren of creëren van nieuwe informatie', 0), ('Publiceren en communiceren', 0), ('Publiceren (van eindproduct)', 0), ('Communiceren (van eindproduct)', 0), ('Valoriseren van bevindingen (outreach)', 0)]
#
# Beoordelen van resultaten (kritisch)
#
# [('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Waarde van informatie/data', 0), ('Aard en verschijningsvormen van informatie/data', 0), ('Werking en structuur van het internet', 0), ('Rol en totstandkoming van netwerken', 0), ('Individu in het informatielandschap', 0), ('Identificeren van informatiebehoefte', 0), ('Zoeken ter oriëntatie', 0), ('Formuleren van onderzoeksvraag', 0), ('Plannen en zoeken', 0), ('Selecteren informatiebronnen en zoeksystemen', 0), ('Selecteren zoektermen', 0), ('Zoeken naar informatie', 0), ('Kritisch beoordelen', 0), ('Beoordelen van resultaten (kritisch)', 0), ('Informatieverwerking (lezen, luisteren e.d.)', 0), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 0), ('Evalueren van zoekproces (kritisch)', 0), ('Organiseren en verwerken', 0), ('Manage proces en zoekresultaten', 0), ('Samenwerken (in teams)', 0), ('Analyseren van zoekresultaten (informatieanalyse)', 0), ('Gebruik en verwerken van informatie (ethisch)', 0), ('Bronvermelding', 0), ('Auteursrecht', 0), ('Privacygevoelige informatie', 0), ('Synthetiseren of creëren van nieuwe informatie', 0), ('Publiceren en communiceren', 0), ('Publiceren (van eindproduct)', 0), ('Communiceren (van eindproduct)', 0), ('Valoriseren van bevindingen (outreach)', 0)]
#
# Informatievaardigheden
#
# [('Aard en verschijningsvormen van informatie/data', 2), ('Synthetiseren of creëren van nieuwe informatie', 2), ('Communiceren (van eindproduct)', 2), ('Waarde van informatie/data', 1), ('Zoeken ter oriëntatie', 1), ('Selecteren informatiebronnen en zoeksystemen', 1), ('Beoordelen van resultaten (kritisch)', 1), ('Informatieverwerking (lezen, luisteren e.d.)', 1), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 1), ('Privacygevoelige informatie', 1), ('Publiceren (van eindproduct)', 1), ('Valoriseren van bevindingen (outreach)', 1), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Werking en structuur van het internet', 0), ('Rol en totstandkoming van netwerken', 0), ('Individu in het informatielandschap', 0), ('Identificeren van informatiebehoefte', 0), ('Formuleren van onderzoeksvraag', 0), ('Plannen en zoeken', 0), ('Selecteren zoektermen', 0), ('Zoeken naar informatie', 0), ('Kritisch beoordelen', 0), ('Evalueren van zoekproces (kritisch)', 0), ('Organiseren en verwerken', 0), ('Manage proces en zoekresultaten', 0), ('Samenwerken (in teams)', 0), ('Analyseren van zoekresultaten (informatieanalyse)', 0), ('Gebruik en verwerken van informatie (ethisch)', 0), ('Bronvermelding', 0), ('Auteursrecht', 0), ('Publiceren en communiceren', 0)]
#
# Aard en verschijningsvormen van informatie/data
#
# [('Werking en structuur van het internet', 2), ('Waarde van informatie/data', 1), ('Aard en verschijningsvormen van informatie/data', 1), ('Zoeken ter oriëntatie', 1), ('Selecteren informatiebronnen en zoeksystemen', 1), ('Beoordelen van resultaten (kritisch)', 1), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 1), ('Auteursrecht', 1), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Rol en totstandkoming van netwerken', 0), ('Individu in het informatielandschap', 0), ('Identificeren van informatiebehoefte', 0), ('Formuleren van onderzoeksvraag', 0), ('Plannen en zoeken', 0), ('Selecteren zoektermen', 0), ('Zoeken naar informatie', 0), ('Kritisch beoordelen', 0), ('Informatieverwerking (lezen, luisteren e.d.)', 0), ('Evalueren van zoekproces (kritisch)', 0), ('Organiseren en verwerken', 0), ('Manage proces en zoekresultaten', 0), ('Samenwerken (in teams)', 0), ('Analyseren van zoekresultaten (informatieanalyse)', 0), ('Gebruik en verwerken van informatie (ethisch)', 0), ('Bronvermelding', 0), ('Privacygevoelige informatie', 0), ('Synthetiseren of creëren van nieuwe informatie', 0), ('Publiceren en communiceren', 0), ('Publiceren (van eindproduct)', 0), ('Communiceren (van eindproduct)', 0), ('Valoriseren van bevindingen (outreach)', 0)]
#
# Werking en structuur van het internet
#
# [('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Waarde van informatie/data', 0), ('Aard en verschijningsvormen van informatie/data', 0), ('Werking en structuur van het internet', 0), ('Rol en totstandkoming van netwerken', 0), ('Individu in het informatielandschap', 0), ('Identificeren van informatiebehoefte', 0), ('Zoeken ter oriëntatie', 0), ('Formuleren van onderzoeksvraag', 0), ('Plannen en zoeken', 0), ('Selecteren informatiebronnen en zoeksystemen', 0), ('Selecteren zoektermen', 0), ('Zoeken naar informatie', 0), ('Kritisch beoordelen', 0), ('Beoordelen van resultaten (kritisch)', 0), ('Informatieverwerking (lezen, luisteren e.d.)', 0), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 0), ('Evalueren van zoekproces (kritisch)', 0), ('Organiseren en verwerken', 0), ('Manage proces en zoekresultaten', 0), ('Samenwerken (in teams)', 0), ('Analyseren van zoekresultaten (informatieanalyse)', 0), ('Gebruik en verwerken van informatie (ethisch)', 0), ('Bronvermelding', 0), ('Auteursrecht', 0), ('Privacygevoelige informatie', 0), ('Synthetiseren of creëren van nieuwe informatie', 0), ('Publiceren en communiceren', 0), ('Publiceren (van eindproduct)', 0), ('Communiceren (van eindproduct)', 0), ('Valoriseren van bevindingen (outreach)', 0)]
#
# Informatievaardigheden
#
# [('Zoeken ter oriëntatie', 2), ('Zoeken naar informatie', 2), ('Selecteren informatiebronnen en zoeksystemen', 1), ('Beoordelen van resultaten (kritisch)', 1), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 1), ('Manage proces en zoekresultaten', 1), ('Analyseren van zoekresultaten (informatieanalyse)', 1), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Waarde van informatie/data', 0), ('Aard en verschijningsvormen van informatie/data', 0), ('Werking en structuur van het internet', 0), ('Rol en totstandkoming van netwerken', 0), ('Individu in het informatielandschap', 0), ('Identificeren van informatiebehoefte', 0), ('Formuleren van onderzoeksvraag', 0), ('Plannen en zoeken', 0), ('Selecteren zoektermen', 0), ('Kritisch beoordelen', 0), ('Informatieverwerking (lezen, luisteren e.d.)', 0), ('Evalueren van zoekproces (kritisch)', 0), ('Organiseren en verwerken', 0), ('Samenwerken (in teams)', 0), ('Gebruik en verwerken van informatie (ethisch)', 0), ('Bronvermelding', 0), ('Auteursrecht', 0), ('Privacygevoelige informatie', 0), ('Synthetiseren of creëren van nieuwe informatie', 0), ('Publiceren en communiceren', 0), ('Publiceren (van eindproduct)', 0), ('Communiceren (van eindproduct)', 0), ('Valoriseren van bevindingen (outreach)', 0)]
#
# Zoeken ter oriëntatie
#
# [('Zoeken ter oriëntatie', 1), ('Selecteren informatiebronnen en zoeksystemen', 1), ('Zoeken naar informatie', 1), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Waarde van informatie/data', 0), ('Aard en verschijningsvormen van informatie/data', 0), ('Werking en structuur van het internet', 0), ('Rol en totstandkoming van netwerken', 0), ('Individu in het informatielandschap', 0), ('Identificeren van informatiebehoefte', 0), ('Formuleren van onderzoeksvraag', 0), ('Plannen en zoeken', 0), ('Selecteren zoektermen', 0), ('Kritisch beoordelen', 0), ('Beoordelen van resultaten (kritisch)', 0), ('Informatieverwerking (lezen, luisteren e.d.)', 0), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 0), ('Evalueren van zoekproces (kritisch)', 0), ('Organiseren en verwerken', 0), ('Manage proces en zoekresultaten', 0), ('Samenwerken (in teams)', 0), ('Analyseren van zoekresultaten (informatieanalyse)', 0), ('Gebruik en verwerken van informatie (ethisch)', 0), ('Bronvermelding', 0), ('Auteursrecht', 0), ('Privacygevoelige informatie', 0), ('Synthetiseren of creëren van nieuwe informatie', 0), ('Publiceren en communiceren', 0), ('Publiceren (van eindproduct)', 0), ('Communiceren (van eindproduct)', 0), ('Valoriseren van bevindingen (outreach)', 0)]
#
# Zoeken ter oriëntatie
#
# [('Identificeren van informatiebehoefte', 1), ('Zoeken ter oriëntatie', 1), ('Formuleren van onderzoeksvraag', 1), ('Selecteren zoektermen', 1), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Waarde van informatie/data', 0), ('Aard en verschijningsvormen van informatie/data', 0), ('Werking en structuur van het internet', 0), ('Rol en totstandkoming van netwerken', 0), ('Individu in het informatielandschap', 0), ('Plannen en zoeken', 0), ('Selecteren informatiebronnen en zoeksystemen', 0), ('Zoeken naar informatie', 0), ('Kritisch beoordelen', 0), ('Beoordelen van resultaten (kritisch)', 0), ('Informatieverwerking (lezen, luisteren e.d.)', 0), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 0), ('Evalueren van zoekproces (kritisch)', 0), ('Organiseren en verwerken', 0), ('Manage proces en zoekresultaten', 0), ('Samenwerken (in teams)', 0), ('Analyseren van zoekresultaten (informatieanalyse)', 0), ('Gebruik en verwerken van informatie (ethisch)', 0), ('Bronvermelding', 0), ('Auteursrecht', 0), ('Privacygevoelige informatie', 0), ('Synthetiseren of creëren van nieuwe informatie', 0), ('Publiceren en communiceren', 0), ('Publiceren (van eindproduct)', 0), ('Communiceren (van eindproduct)', 0), ('Valoriseren van bevindingen (outreach)', 0)]
#
# Identificeren van informatiebehoefte
#
# [('Waarde van informatie/data', 1), ('Aard en verschijningsvormen van informatie/data', 1), ('Selecteren informatiebronnen en zoeksystemen', 1), ('Selecteren zoektermen', 1), ('Beoordelen van resultaten (kritisch)', 1), ('Informatieverwerking (lezen, luisteren e.d.)', 1), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 1), ('Privacygevoelige informatie', 1), ('Synthetiseren of creëren van nieuwe informatie', 1), ('Communiceren (van eindproduct)', 1), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Werking en structuur van het internet', 0), ('Rol en totstandkoming van netwerken', 0), ('Individu in het informatielandschap', 0), ('Identificeren van informatiebehoefte', 0), ('Zoeken ter oriëntatie', 0), ('Formuleren van onderzoeksvraag', 0), ('Plannen en zoeken', 0), ('Zoeken naar informatie', 0), ('Kritisch beoordelen', 0), ('Evalueren van zoekproces (kritisch)', 0), ('Organiseren en verwerken', 0), ('Manage proces en zoekresultaten', 0), ('Samenwerken (in teams)', 0), ('Analyseren van zoekresultaten (informatieanalyse)', 0), ('Gebruik en verwerken van informatie (ethisch)', 0), ('Bronvermelding', 0), ('Auteursrecht', 0), ('Publiceren en communiceren', 0), ('Publiceren (van eindproduct)', 0), ('Valoriseren van bevindingen (outreach)', 0)]
#
# Waarde van informatie/data
#
# [('Selecteren informatiebronnen en zoeksystemen', 3), ('Zoeken ter oriëntatie', 2), ('Waarde van informatie/data', 1), ('Aard en verschijningsvormen van informatie/data', 1), ('Werking en structuur van het internet', 1), ('Zoeken naar informatie', 1), ('Beoordelen van resultaten (kritisch)', 1), ('Informatieverwerking (lezen, luisteren e.d.)', 1), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 1), ('Privacygevoelige informatie', 1), ('Synthetiseren of creëren van nieuwe informatie', 1), ('Communiceren (van eindproduct)', 1), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Rol en totstandkoming van netwerken', 0), ('Individu in het informatielandschap', 0), ('Identificeren van informatiebehoefte', 0), ('Formuleren van onderzoeksvraag', 0), ('Plannen en zoeken', 0), ('Selecteren zoektermen', 0), ('Kritisch beoordelen', 0), ('Evalueren van zoekproces (kritisch)', 0), ('Organiseren en verwerken', 0), ('Manage proces en zoekresultaten', 0), ('Samenwerken (in teams)', 0), ('Analyseren van zoekresultaten (informatieanalyse)', 0), ('Gebruik en verwerken van informatie (ethisch)', 0), ('Bronvermelding', 0), ('Auteursrecht', 0), ('Publiceren en communiceren', 0), ('Publiceren (van eindproduct)', 0), ('Valoriseren van bevindingen (outreach)', 0)]
#
# Selecteren informatiebronnen en zoeksystemen
#
# [('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Waarde van informatie/data', 0), ('Aard en verschijningsvormen van informatie/data', 0), ('Werking en structuur van het internet', 0), ('Rol en totstandkoming van netwerken', 0), ('Individu in het informatielandschap', 0), ('Identificeren van informatiebehoefte', 0), ('Zoeken ter oriëntatie', 0), ('Formuleren van onderzoeksvraag', 0), ('Plannen en zoeken', 0), ('Selecteren informatiebronnen en zoeksystemen', 0), ('Selecteren zoektermen', 0), ('Zoeken naar informatie', 0), ('Kritisch beoordelen', 0), ('Beoordelen van resultaten (kritisch)', 0), ('Informatieverwerking (lezen, luisteren e.d.)', 0), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 0), ('Evalueren van zoekproces (kritisch)', 0), ('Organiseren en verwerken', 0), ('Manage proces en zoekresultaten', 0), ('Samenwerken (in teams)', 0), ('Analyseren van zoekresultaten (informatieanalyse)', 0), ('Gebruik en verwerken van informatie (ethisch)', 0), ('Bronvermelding', 0), ('Auteursrecht', 0), ('Privacygevoelige informatie', 0), ('Synthetiseren of creëren van nieuwe informatie', 0), ('Publiceren en communiceren', 0), ('Publiceren (van eindproduct)', 0), ('Communiceren (van eindproduct)', 0), ('Valoriseren van bevindingen (outreach)', 0)]
#
# Informatievaardigheden
#
# [('Waarde van informatie/data', 1), ('Aard en verschijningsvormen van informatie/data', 1), ('Selecteren informatiebronnen en zoeksystemen', 1), ('Beoordelen van resultaten (kritisch)', 1), ('Informatieverwerking (lezen, luisteren e.d.)', 1), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 1), ('Privacygevoelige informatie', 1), ('Synthetiseren of creëren van nieuwe informatie', 1), ('Communiceren (van eindproduct)', 1), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Werking en structuur van het internet', 0), ('Rol en totstandkoming van netwerken', 0), ('Individu in het informatielandschap', 0), ('Identificeren van informatiebehoefte', 0), ('Zoeken ter oriëntatie', 0), ('Formuleren van onderzoeksvraag', 0), ('Plannen en zoeken', 0), ('Selecteren zoektermen', 0), ('Zoeken naar informatie', 0), ('Kritisch beoordelen', 0), ('Evalueren van zoekproces (kritisch)', 0), ('Organiseren en verwerken', 0), ('Manage proces en zoekresultaten', 0), ('Samenwerken (in teams)', 0), ('Analyseren van zoekresultaten (informatieanalyse)', 0), ('Gebruik en verwerken van informatie (ethisch)', 0), ('Bronvermelding', 0), ('Auteursrecht', 0), ('Publiceren en communiceren', 0), ('Publiceren (van eindproduct)', 0), ('Valoriseren van bevindingen (outreach)', 0)]
#
# Waarde van informatie/data
#
# [('Zoeken ter oriëntatie', 2), ('Bronvermelding', 2), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 1), ('Manage proces en zoekresultaten', 1), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Waarde van informatie/data', 0), ('Aard en verschijningsvormen van informatie/data', 0), ('Werking en structuur van het internet', 0), ('Rol en totstandkoming van netwerken', 0), ('Individu in het informatielandschap', 0), ('Identificeren van informatiebehoefte', 0), ('Formuleren van onderzoeksvraag', 0), ('Plannen en zoeken', 0), ('Selecteren informatiebronnen en zoeksystemen', 0), ('Selecteren zoektermen', 0), ('Zoeken naar informatie', 0), ('Kritisch beoordelen', 0), ('Beoordelen van resultaten (kritisch)', 0), ('Informatieverwerking (lezen, luisteren e.d.)', 0), ('Evalueren van zoekproces (kritisch)', 0), ('Organiseren en verwerken', 0), ('Samenwerken (in teams)', 0), ('Analyseren van zoekresultaten (informatieanalyse)', 0), ('Gebruik en verwerken van informatie (ethisch)', 0), ('Auteursrecht', 0), ('Privacygevoelige informatie', 0), ('Synthetiseren of creëren van nieuwe informatie', 0), ('Publiceren en communiceren', 0), ('Publiceren (van eindproduct)', 0), ('Communiceren (van eindproduct)', 0), ('Valoriseren van bevindingen (outreach)', 0)]
#
# Zoeken ter oriëntatie
#
# [('Privacygevoelige informatie', 2), ('Waarde van informatie/data', 1), ('Aard en verschijningsvormen van informatie/data', 1), ('Selecteren informatiebronnen en zoeksystemen', 1), ('Beoordelen van resultaten (kritisch)', 1), ('Informatieverwerking (lezen, luisteren e.d.)', 1), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 1), ('Synthetiseren of creëren van nieuwe informatie', 1), ('Communiceren (van eindproduct)', 1), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Werking en structuur van het internet', 0), ('Rol en totstandkoming van netwerken', 0), ('Individu in het informatielandschap', 0), ('Identificeren van informatiebehoefte', 0), ('Zoeken ter oriëntatie', 0), ('Formuleren van onderzoeksvraag', 0), ('Plannen en zoeken', 0), ('Selecteren zoektermen', 0), ('Zoeken naar informatie', 0), ('Kritisch beoordelen', 0), ('Evalueren van zoekproces (kritisch)', 0), ('Organiseren en verwerken', 0), ('Manage proces en zoekresultaten', 0), ('Samenwerken (in teams)', 0), ('Analyseren van zoekresultaten (informatieanalyse)', 0), ('Gebruik en verwerken van informatie (ethisch)', 0), ('Bronvermelding', 0), ('Auteursrecht', 0), ('Publiceren en communiceren', 0), ('Publiceren (van eindproduct)', 0), ('Valoriseren van bevindingen (outreach)', 0)]
#
# Privacygevoelige informatie
#
# [('Zoeken ter oriëntatie', 1), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 1), ('Manage proces en zoekresultaten', 1), ('Bronvermelding', 1), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Waarde van informatie/data', 0), ('Aard en verschijningsvormen van informatie/data', 0), ('Werking en structuur van het internet', 0), ('Rol en totstandkoming van netwerken', 0), ('Individu in het informatielandschap', 0), ('Identificeren van informatiebehoefte', 0), ('Formuleren van onderzoeksvraag', 0), ('Plannen en zoeken', 0), ('Selecteren informatiebronnen en zoeksystemen', 0), ('Selecteren zoektermen', 0), ('Zoeken naar informatie', 0), ('Kritisch beoordelen', 0), ('Beoordelen van resultaten (kritisch)', 0), ('Informatieverwerking (lezen, luisteren e.d.)', 0), ('Evalueren van zoekproces (kritisch)', 0), ('Organiseren en verwerken', 0), ('Samenwerken (in teams)', 0), ('Analyseren van zoekresultaten (informatieanalyse)', 0), ('Gebruik en verwerken van informatie (ethisch)', 0), ('Auteursrecht', 0), ('Privacygevoelige informatie', 0), ('Synthetiseren of creëren van nieuwe informatie', 0), ('Publiceren en communiceren', 0), ('Publiceren (van eindproduct)', 0), ('Communiceren (van eindproduct)', 0), ('Valoriseren van bevindingen (outreach)', 0)]
#
# Zoeken ter oriëntatie
#
# [('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Waarde van informatie/data', 0), ('Aard en verschijningsvormen van informatie/data', 0), ('Werking en structuur van het internet', 0), ('Rol en totstandkoming van netwerken', 0), ('Individu in het informatielandschap', 0), ('Identificeren van informatiebehoefte', 0), ('Zoeken ter oriëntatie', 0), ('Formuleren van onderzoeksvraag', 0), ('Plannen en zoeken', 0), ('Selecteren informatiebronnen en zoeksystemen', 0), ('Selecteren zoektermen', 0), ('Zoeken naar informatie', 0), ('Kritisch beoordelen', 0), ('Beoordelen van resultaten (kritisch)', 0), ('Informatieverwerking (lezen, luisteren e.d.)', 0), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 0), ('Evalueren van zoekproces (kritisch)', 0), ('Organiseren en verwerken', 0), ('Manage proces en zoekresultaten', 0), ('Samenwerken (in teams)', 0), ('Analyseren van zoekresultaten (informatieanalyse)', 0), ('Gebruik en verwerken van informatie (ethisch)', 0), ('Bronvermelding', 0), ('Auteursrecht', 0), ('Privacygevoelige informatie', 0), ('Synthetiseren of creëren van nieuwe informatie', 0), ('Publiceren en communiceren', 0), ('Publiceren (van eindproduct)', 0), ('Communiceren (van eindproduct)', 0), ('Valoriseren van bevindingen (outreach)', 0)]
#
# Informatievaardigheden
#
# [('Aard en verschijningsvormen van informatie/data', 2), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 2), ('Waarde van informatie/data', 1), ('Selecteren informatiebronnen en zoeksystemen', 1), ('Beoordelen van resultaten (kritisch)', 1), ('Informatieverwerking (lezen, luisteren e.d.)', 1), ('Privacygevoelige informatie', 1), ('Synthetiseren of creëren van nieuwe informatie', 1), ('Communiceren (van eindproduct)', 1), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Werking en structuur van het internet', 0), ('Rol en totstandkoming van netwerken', 0), ('Individu in het informatielandschap', 0), ('Identificeren van informatiebehoefte', 0), ('Zoeken ter oriëntatie', 0), ('Formuleren van onderzoeksvraag', 0), ('Plannen en zoeken', 0), ('Selecteren zoektermen', 0), ('Zoeken naar informatie', 0), ('Kritisch beoordelen', 0), ('Evalueren van zoekproces (kritisch)', 0), ('Organiseren en verwerken', 0), ('Manage proces en zoekresultaten', 0), ('Samenwerken (in teams)', 0), ('Analyseren van zoekresultaten (informatieanalyse)', 0), ('Gebruik en verwerken van informatie (ethisch)', 0), ('Bronvermelding', 0), ('Auteursrecht', 0), ('Publiceren en communiceren', 0), ('Publiceren (van eindproduct)', 0), ('Valoriseren van bevindingen (outreach)', 0)]
#
# Aard en verschijningsvormen van informatie/data
#
# [('Aard en verschijningsvormen van informatie/data', 1), ('Publiceren (van eindproduct)', 1), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Waarde van informatie/data', 0), ('Werking en structuur van het internet', 0), ('Rol en totstandkoming van netwerken', 0), ('Individu in het informatielandschap', 0), ('Identificeren van informatiebehoefte', 0), ('Zoeken ter oriëntatie', 0), ('Formuleren van onderzoeksvraag', 0), ('Plannen en zoeken', 0), ('Selecteren informatiebronnen en zoeksystemen', 0), ('Selecteren zoektermen', 0), ('Zoeken naar informatie', 0), ('Kritisch beoordelen', 0), ('Beoordelen van resultaten (kritisch)', 0), ('Informatieverwerking (lezen, luisteren e.d.)', 0), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 0), ('Evalueren van zoekproces (kritisch)', 0), ('Organiseren en verwerken', 0), ('Manage proces en zoekresultaten', 0), ('Samenwerken (in teams)', 0), ('Analyseren van zoekresultaten (informatieanalyse)', 0), ('Gebruik en verwerken van informatie (ethisch)', 0), ('Bronvermelding', 0), ('Auteursrecht', 0), ('Privacygevoelige informatie', 0), ('Synthetiseren of creëren van nieuwe informatie', 0), ('Publiceren en communiceren', 0), ('Communiceren (van eindproduct)', 0), ('Valoriseren van bevindingen (outreach)', 0)]
#
# Aard en verschijningsvormen van informatie/data
#
# [('Zoeken ter oriëntatie', 1), ('Zoeken naar informatie', 1), ('Beoordelen van resultaten (kritisch)', 1), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 1), ('Manage proces en zoekresultaten', 1), ('Analyseren van zoekresultaten (informatieanalyse)', 1), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Waarde van informatie/data', 0), ('Aard en verschijningsvormen van informatie/data', 0), ('Werking en structuur van het internet', 0), ('Rol en totstandkoming van netwerken', 0), ('Individu in het informatielandschap', 0), ('Identificeren van informatiebehoefte', 0), ('Formuleren van onderzoeksvraag', 0), ('Plannen en zoeken', 0), ('Selecteren informatiebronnen en zoeksystemen', 0), ('Selecteren zoektermen', 0), ('Kritisch beoordelen', 0), ('Informatieverwerking (lezen, luisteren e.d.)', 0), ('Evalueren van zoekproces (kritisch)', 0), ('Organiseren en verwerken', 0), ('Samenwerken (in teams)', 0), ('Gebruik en verwerken van informatie (ethisch)', 0), ('Bronvermelding', 0), ('Auteursrecht', 0), ('Privacygevoelige informatie', 0), ('Synthetiseren of creëren van nieuwe informatie', 0), ('Publiceren en communiceren', 0), ('Publiceren (van eindproduct)', 0), ('Communiceren (van eindproduct)', 0), ('Valoriseren van bevindingen (outreach)', 0)]
#
# Zoeken ter oriëntatie
#
# [('Beoordelingscriteria (relevantie/betrouwbaarheid)', 2), ('Waarde van informatie/data', 1), ('Aard en verschijningsvormen van informatie/data', 1), ('Selecteren informatiebronnen en zoeksystemen', 1), ('Beoordelen van resultaten (kritisch)', 1), ('Informatieverwerking (lezen, luisteren e.d.)', 1), ('Privacygevoelige informatie', 1), ('Synthetiseren of creëren van nieuwe informatie', 1), ('Communiceren (van eindproduct)', 1), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Werking en structuur van het internet', 0), ('Rol en totstandkoming van netwerken', 0), ('Individu in het informatielandschap', 0), ('Identificeren van informatiebehoefte', 0), ('Zoeken ter oriëntatie', 0), ('Formuleren van onderzoeksvraag', 0), ('Plannen en zoeken', 0), ('Selecteren zoektermen', 0), ('Zoeken naar informatie', 0), ('Kritisch beoordelen', 0), ('Evalueren van zoekproces (kritisch)', 0), ('Organiseren en verwerken', 0), ('Manage proces en zoekresultaten', 0), ('Samenwerken (in teams)', 0), ('Analyseren van zoekresultaten (informatieanalyse)', 0), ('Gebruik en verwerken van informatie (ethisch)', 0), ('Bronvermelding', 0), ('Auteursrecht', 0), ('Publiceren en communiceren', 0), ('Publiceren (van eindproduct)', 0), ('Valoriseren van bevindingen (outreach)', 0)]
#
# Beoordelingscriteria (relevantie/betrouwbaarheid)
#
# [('Selecteren informatiebronnen en zoeksystemen', 2), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 2), ('Waarde van informatie/data', 1), ('Aard en verschijningsvormen van informatie/data', 1), ('Zoeken ter oriëntatie', 1), ('Zoeken naar informatie', 1), ('Beoordelen van resultaten (kritisch)', 1), ('Informatieverwerking (lezen, luisteren e.d.)', 1), ('Privacygevoelige informatie', 1), ('Synthetiseren of creëren van nieuwe informatie', 1), ('Publiceren (van eindproduct)', 1), ('Communiceren (van eindproduct)', 1), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Werking en structuur van het internet', 0), ('Rol en totstandkoming van netwerken', 0), ('Individu in het informatielandschap', 0), ('Identificeren van informatiebehoefte', 0), ('Formuleren van onderzoeksvraag', 0), ('Plannen en zoeken', 0), ('Selecteren zoektermen', 0), ('Kritisch beoordelen', 0), ('Evalueren van zoekproces (kritisch)', 0), ('Organiseren en verwerken', 0), ('Manage proces en zoekresultaten', 0), ('Samenwerken (in teams)', 0), ('Analyseren van zoekresultaten (informatieanalyse)', 0), ('Gebruik en verwerken van informatie (ethisch)', 0), ('Bronvermelding', 0), ('Auteursrecht', 0), ('Publiceren en communiceren', 0), ('Valoriseren van bevindingen (outreach)', 0)]
#
# Selecteren informatiebronnen en zoeksystemen
#
# [('Beoordelen van resultaten (kritisch)', 1), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 1), ('Evalueren van zoekproces (kritisch)', 1), ('Synthetiseren of creëren van nieuwe informatie', 1), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Waarde van informatie/data', 0), ('Aard en verschijningsvormen van informatie/data', 0), ('Werking en structuur van het internet', 0), ('Rol en totstandkoming van netwerken', 0), ('Individu in het informatielandschap', 0), ('Identificeren van informatiebehoefte', 0), ('Zoeken ter oriëntatie', 0), ('Formuleren van onderzoeksvraag', 0), ('Plannen en zoeken', 0), ('Selecteren informatiebronnen en zoeksystemen', 0), ('Selecteren zoektermen', 0), ('Zoeken naar informatie', 0), ('Kritisch beoordelen', 0), ('Informatieverwerking (lezen, luisteren e.d.)', 0), ('Organiseren en verwerken', 0), ('Manage proces en zoekresultaten', 0), ('Samenwerken (in teams)', 0), ('Analyseren van zoekresultaten (informatieanalyse)', 0), ('Gebruik en verwerken van informatie (ethisch)', 0), ('Bronvermelding', 0), ('Auteursrecht', 0), ('Privacygevoelige informatie', 0), ('Publiceren en communiceren', 0), ('Publiceren (van eindproduct)', 0), ('Communiceren (van eindproduct)', 0), ('Valoriseren van bevindingen (outreach)', 0)]
#
# Beoordelen van resultaten (kritisch)
#
# [('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Waarde van informatie/data', 0), ('Aard en verschijningsvormen van informatie/data', 0), ('Werking en structuur van het internet', 0), ('Rol en totstandkoming van netwerken', 0), ('Individu in het informatielandschap', 0), ('Identificeren van informatiebehoefte', 0), ('Zoeken ter oriëntatie', 0), ('Formuleren van onderzoeksvraag', 0), ('Plannen en zoeken', 0), ('Selecteren informatiebronnen en zoeksystemen', 0), ('Selecteren zoektermen', 0), ('Zoeken naar informatie', 0), ('Kritisch beoordelen', 0), ('Beoordelen van resultaten (kritisch)', 0), ('Informatieverwerking (lezen, luisteren e.d.)', 0), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 0), ('Evalueren van zoekproces (kritisch)', 0), ('Organiseren en verwerken', 0), ('Manage proces en zoekresultaten', 0), ('Samenwerken (in teams)', 0), ('Analyseren van zoekresultaten (informatieanalyse)', 0), ('Gebruik en verwerken van informatie (ethisch)', 0), ('Bronvermelding', 0), ('Auteursrecht', 0), ('Privacygevoelige informatie', 0), ('Synthetiseren of creëren van nieuwe informatie', 0), ('Publiceren en communiceren', 0), ('Publiceren (van eindproduct)', 0), ('Communiceren (van eindproduct)', 0), ('Valoriseren van bevindingen (outreach)', 0)]
#
# Informatievaardigheden
#
# [('Evalueren van zoekproces (kritisch)', 2), ('Synthetiseren of creëren van nieuwe informatie', 1), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Waarde van informatie/data', 0), ('Aard en verschijningsvormen van informatie/data', 0), ('Werking en structuur van het internet', 0), ('Rol en totstandkoming van netwerken', 0), ('Individu in het informatielandschap', 0), ('Identificeren van informatiebehoefte', 0), ('Zoeken ter oriëntatie', 0), ('Formuleren van onderzoeksvraag', 0), ('Plannen en zoeken', 0), ('Selecteren informatiebronnen en zoeksystemen', 0), ('Selecteren zoektermen', 0), ('Zoeken naar informatie', 0), ('Kritisch beoordelen', 0), ('Beoordelen van resultaten (kritisch)', 0), ('Informatieverwerking (lezen, luisteren e.d.)', 0), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 0), ('Organiseren en verwerken', 0), ('Manage proces en zoekresultaten', 0), ('Samenwerken (in teams)', 0), ('Analyseren van zoekresultaten (informatieanalyse)', 0), ('Gebruik en verwerken van informatie (ethisch)', 0), ('Bronvermelding', 0), ('Auteursrecht', 0), ('Privacygevoelige informatie', 0), ('Publiceren en communiceren', 0), ('Publiceren (van eindproduct)', 0), ('Communiceren (van eindproduct)', 0), ('Valoriseren van bevindingen (outreach)', 0)]
#
# Evalueren van zoekproces (kritisch)
#
# [('Zoeken ter oriëntatie', 1), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 1), ('Manage proces en zoekresultaten', 1), ('Bronvermelding', 1), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Waarde van informatie/data', 0), ('Aard en verschijningsvormen van informatie/data', 0), ('Werking en structuur van het internet', 0), ('Rol en totstandkoming van netwerken', 0), ('Individu in het informatielandschap', 0), ('Identificeren van informatiebehoefte', 0), ('Formuleren van onderzoeksvraag', 0), ('Plannen en zoeken', 0), ('Selecteren informatiebronnen en zoeksystemen', 0), ('Selecteren zoektermen', 0), ('Zoeken naar informatie', 0), ('Kritisch beoordelen', 0), ('Beoordelen van resultaten (kritisch)', 0), ('Informatieverwerking (lezen, luisteren e.d.)', 0), ('Evalueren van zoekproces (kritisch)', 0), ('Organiseren en verwerken', 0), ('Samenwerken (in teams)', 0), ('Analyseren van zoekresultaten (informatieanalyse)', 0), ('Gebruik en verwerken van informatie (ethisch)', 0), ('Auteursrecht', 0), ('Privacygevoelige informatie', 0), ('Synthetiseren of creëren van nieuwe informatie', 0), ('Publiceren en communiceren', 0), ('Publiceren (van eindproduct)', 0), ('Communiceren (van eindproduct)', 0), ('Valoriseren van bevindingen (outreach)', 0)]
#
# Zoeken ter oriëntatie
#
# [('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Waarde van informatie/data', 0), ('Aard en verschijningsvormen van informatie/data', 0), ('Werking en structuur van het internet', 0), ('Rol en totstandkoming van netwerken', 0), ('Individu in het informatielandschap', 0), ('Identificeren van informatiebehoefte', 0), ('Zoeken ter oriëntatie', 0), ('Formuleren van onderzoeksvraag', 0), ('Plannen en zoeken', 0), ('Selecteren informatiebronnen en zoeksystemen', 0), ('Selecteren zoektermen', 0), ('Zoeken naar informatie', 0), ('Kritisch beoordelen', 0), ('Beoordelen van resultaten (kritisch)', 0), ('Informatieverwerking (lezen, luisteren e.d.)', 0), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 0), ('Evalueren van zoekproces (kritisch)', 0), ('Organiseren en verwerken', 0), ('Manage proces en zoekresultaten', 0), ('Samenwerken (in teams)', 0), ('Analyseren van zoekresultaten (informatieanalyse)', 0), ('Gebruik en verwerken van informatie (ethisch)', 0), ('Bronvermelding', 0), ('Auteursrecht', 0), ('Privacygevoelige informatie', 0), ('Synthetiseren of creëren van nieuwe informatie', 0), ('Publiceren en communiceren', 0), ('Publiceren (van eindproduct)', 0), ('Communiceren (van eindproduct)', 0), ('Valoriseren van bevindingen (outreach)', 0)]
#
# Informatievaardigheden
#
# [('Waarde van informatie/data', 1), ('Aard en verschijningsvormen van informatie/data', 1), ('Selecteren informatiebronnen en zoeksystemen', 1), ('Beoordelen van resultaten (kritisch)', 1), ('Informatieverwerking (lezen, luisteren e.d.)', 1), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 1), ('Privacygevoelige informatie', 1), ('Synthetiseren of creëren van nieuwe informatie', 1), ('Communiceren (van eindproduct)', 1), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Werking en structuur van het internet', 0), ('Rol en totstandkoming van netwerken', 0), ('Individu in het informatielandschap', 0), ('Identificeren van informatiebehoefte', 0), ('Zoeken ter oriëntatie', 0), ('Formuleren van onderzoeksvraag', 0), ('Plannen en zoeken', 0), ('Selecteren zoektermen', 0), ('Zoeken naar informatie', 0), ('Kritisch beoordelen', 0), ('Evalueren van zoekproces (kritisch)', 0), ('Organiseren en verwerken', 0), ('Manage proces en zoekresultaten', 0), ('Samenwerken (in teams)', 0), ('Analyseren van zoekresultaten (informatieanalyse)', 0), ('Gebruik en verwerken van informatie (ethisch)', 0), ('Bronvermelding', 0), ('Auteursrecht', 0), ('Publiceren en communiceren', 0), ('Publiceren (van eindproduct)', 0), ('Valoriseren van bevindingen (outreach)', 0)]
#
# Waarde van informatie/data
#
# [('Beoordelingscriteria (relevantie/betrouwbaarheid)', 1), ('Publiceren (van eindproduct)', 1), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Waarde van informatie/data', 0), ('Aard en verschijningsvormen van informatie/data', 0), ('Werking en structuur van het internet', 0), ('Rol en totstandkoming van netwerken', 0), ('Individu in het informatielandschap', 0), ('Identificeren van informatiebehoefte', 0), ('Zoeken ter oriëntatie', 0), ('Formuleren van onderzoeksvraag', 0), ('Plannen en zoeken', 0), ('Selecteren informatiebronnen en zoeksystemen', 0), ('Selecteren zoektermen', 0), ('Zoeken naar informatie', 0), ('Kritisch beoordelen', 0), ('Beoordelen van resultaten (kritisch)', 0), ('Informatieverwerking (lezen, luisteren e.d.)', 0), ('Evalueren van zoekproces (kritisch)', 0), ('Organiseren en verwerken', 0), ('Manage proces en zoekresultaten', 0), ('Samenwerken (in teams)', 0), ('Analyseren van zoekresultaten (informatieanalyse)', 0), ('Gebruik en verwerken van informatie (ethisch)', 0), ('Bronvermelding', 0), ('Auteursrecht', 0), ('Privacygevoelige informatie', 0), ('Synthetiseren of creëren van nieuwe informatie', 0), ('Publiceren en communiceren', 0), ('Communiceren (van eindproduct)', 0), ('Valoriseren van bevindingen (outreach)', 0)]
#
# Beoordelingscriteria (relevantie/betrouwbaarheid)
#
# [('Aard en verschijningsvormen van informatie/data', 1), ('Publiceren (van eindproduct)', 1), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Waarde van informatie/data', 0), ('Werking en structuur van het internet', 0), ('Rol en totstandkoming van netwerken', 0), ('Individu in het informatielandschap', 0), ('Identificeren van informatiebehoefte', 0), ('Zoeken ter oriëntatie', 0), ('Formuleren van onderzoeksvraag', 0), ('Plannen en zoeken', 0), ('Selecteren informatiebronnen en zoeksystemen', 0), ('Selecteren zoektermen', 0), ('Zoeken naar informatie', 0), ('Kritisch beoordelen', 0), ('Beoordelen van resultaten (kritisch)', 0), ('Informatieverwerking (lezen, luisteren e.d.)', 0), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 0), ('Evalueren van zoekproces (kritisch)', 0), ('Organiseren en verwerken', 0), ('Manage proces en zoekresultaten', 0), ('Samenwerken (in teams)', 0), ('Analyseren van zoekresultaten (informatieanalyse)', 0), ('Gebruik en verwerken van informatie (ethisch)', 0), ('Bronvermelding', 0), ('Auteursrecht', 0), ('Privacygevoelige informatie', 0), ('Synthetiseren of creëren van nieuwe informatie', 0), ('Publiceren en communiceren', 0), ('Communiceren (van eindproduct)', 0), ('Valoriseren van bevindingen (outreach)', 0)]
#
# Aard en verschijningsvormen van informatie/data
#
# [('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Waarde van informatie/data', 0), ('Aard en verschijningsvormen van informatie/data', 0), ('Werking en structuur van het internet', 0), ('Rol en totstandkoming van netwerken', 0), ('Individu in het informatielandschap', 0), ('Identificeren van informatiebehoefte', 0), ('Zoeken ter oriëntatie', 0), ('Formuleren van onderzoeksvraag', 0), ('Plannen en zoeken', 0), ('Selecteren informatiebronnen en zoeksystemen', 0), ('Selecteren zoektermen', 0), ('Zoeken naar informatie', 0), ('Kritisch beoordelen', 0), ('Beoordelen van resultaten (kritisch)', 0), ('Informatieverwerking (lezen, luisteren e.d.)', 0), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 0), ('Evalueren van zoekproces (kritisch)', 0), ('Organiseren en verwerken', 0), ('Manage proces en zoekresultaten', 0), ('Samenwerken (in teams)', 0), ('Analyseren van zoekresultaten (informatieanalyse)', 0), ('Gebruik en verwerken van informatie (ethisch)', 0), ('Bronvermelding', 0), ('Auteursrecht', 0), ('Privacygevoelige informatie', 0), ('Synthetiseren of creëren van nieuwe informatie', 0), ('Publiceren en communiceren', 0), ('Publiceren (van eindproduct)', 0), ('Communiceren (van eindproduct)', 0), ('Valoriseren van bevindingen (outreach)', 0)]
#
# Informatievaardigheden
#
# [('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Waarde van informatie/data', 0), ('Aard en verschijningsvormen van informatie/data', 0), ('Werking en structuur van het internet', 0), ('Rol en totstandkoming van netwerken', 0), ('Individu in het informatielandschap', 0), ('Identificeren van informatiebehoefte', 0), ('Zoeken ter oriëntatie', 0), ('Formuleren van onderzoeksvraag', 0), ('Plannen en zoeken', 0), ('Selecteren informatiebronnen en zoeksystemen', 0), ('Selecteren zoektermen', 0), ('Zoeken naar informatie', 0), ('Kritisch beoordelen', 0), ('Beoordelen van resultaten (kritisch)', 0), ('Informatieverwerking (lezen, luisteren e.d.)', 0), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 0), ('Evalueren van zoekproces (kritisch)', 0), ('Organiseren en verwerken', 0), ('Manage proces en zoekresultaten', 0), ('Samenwerken (in teams)', 0), ('Analyseren van zoekresultaten (informatieanalyse)', 0), ('Gebruik en verwerken van informatie (ethisch)', 0), ('Bronvermelding', 0), ('Auteursrecht', 0), ('Privacygevoelige informatie', 0), ('Synthetiseren of creëren van nieuwe informatie', 0), ('Publiceren en communiceren', 0), ('Publiceren (van eindproduct)', 0), ('Communiceren (van eindproduct)', 0), ('Valoriseren van bevindingen (outreach)', 0)]
#
# Informatievaardigheden
#
# ...
#
# Informatievaardigheden
#
# [('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Waarde van informatie/data', 0), ('Aard en verschijningsvormen van informatie/data', 0), ('Werking en structuur van het internet', 0), ('Rol en totstandkoming van netwerken', 0), ('Individu in het informatielandschap', 0), ('Identificeren van informatiebehoefte', 0), ('Zoeken ter oriëntatie', 0), ('Formuleren van onderzoeksvraag', 0), ('Plannen en zoeken', 0), ('Selecteren informatiebronnen en zoeksystemen', 0), ('Selecteren zoektermen', 0), ('Zoeken naar informatie', 0), ('Kritisch beoordelen', 0), ('Beoordelen van resultaten (kritisch)', 0), ('Informatieverwerking (lezen, luisteren e.d.)', 0), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 0), ('Evalueren van zoekproces (kritisch)', 0), ('Organiseren en verwerken', 0), ('Manage proces en zoekresultaten', 0), ('Samenwerken (in teams)', 0), ('Analyseren van zoekresultaten (informatieanalyse)', 0), ('Gebruik en verwerken van informatie (ethisch)', 0), ('Bronvermelding', 0), ('Auteursrecht', 0), ('Privacygevoelige informatie', 0), ('Synthetiseren of creëren van nieuwe informatie', 0), ('Publiceren en communiceren', 0), ('Publiceren (van eindproduct)', 0), ('Communiceren (van eindproduct)', 0), ('Valoriseren van bevindingen (outreach)', 0)]
#
# Informatievaardigheden
#
# [('Waarde van informatie/data', 1), ('Aard en verschijningsvormen van informatie/data', 1), ('Selecteren informatiebronnen en zoeksystemen', 1), ('Beoordelen van resultaten (kritisch)', 1), ('Informatieverwerking (lezen, luisteren e.d.)', 1), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 1), ('Privacygevoelige informatie', 1), ('Synthetiseren of creëren van nieuwe informatie', 1), ('Communiceren (van eindproduct)', 1), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Werking en structuur van het internet', 0), ('Rol en totstandkoming van netwerken', 0), ('Individu in het informatielandschap', 0), ('Identificeren van informatiebehoefte', 0), ('Zoeken ter oriëntatie', 0), ('Formuleren van onderzoeksvraag', 0), ('Plannen en zoeken', 0), ('Selecteren zoektermen', 0), ('Zoeken naar informatie', 0), ('Kritisch beoordelen', 0), ('Evalueren van zoekproces (kritisch)', 0), ('Organiseren en verwerken', 0), ('Manage proces en zoekresultaten', 0), ('Samenwerken (in teams)', 0), ('Analyseren van zoekresultaten (informatieanalyse)', 0), ('Gebruik en verwerken van informatie (ethisch)', 0), ('Bronvermelding', 0), ('Auteursrecht', 0), ('Publiceren en communiceren', 0), ('Publiceren (van eindproduct)', 0), ('Valoriseren van bevindingen (outreach)', 0)]
#
# Waarde van informatie/data
#
# [('Selecteren zoektermen', 2), ('Aard en verschijningsvormen van informatie/data', 1), ('Zoeken ter oriëntatie', 1), ('Selecteren informatiebronnen en zoeksystemen', 1), ('Zoeken naar informatie', 1), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 1), ('Valoriseren van bevindingen (outreach)', 1), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Waarde van informatie/data', 0), ('Werking en structuur van het internet', 0), ('Rol en totstandkoming van netwerken', 0), ('Individu in het informatielandschap', 0), ('Identificeren van informatiebehoefte', 0), ('Formuleren van onderzoeksvraag', 0), ('Plannen en zoeken', 0), ('Kritisch beoordelen', 0), ('Beoordelen van resultaten (kritisch)', 0), ('Informatieverwerking (lezen, luisteren e.d.)', 0), ('Evalueren van zoekproces (kritisch)', 0), ('Organiseren en verwerken', 0), ('Manage proces en zoekresultaten', 0), ('Samenwerken (in teams)', 0), ('Analyseren van zoekresultaten (informatieanalyse)', 0), ('Gebruik en verwerken van informatie (ethisch)', 0), ('Bronvermelding', 0), ('Auteursrecht', 0), ('Privacygevoelige informatie', 0), ('Synthetiseren of creëren van nieuwe informatie', 0), ('Publiceren en communiceren', 0), ('Publiceren (van eindproduct)', 0), ('Communiceren (van eindproduct)', 0)]
#
# Selecteren zoektermen
#
# [('Aard en verschijningsvormen van informatie/data', 1), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Waarde van informatie/data', 0), ('Werking en structuur van het internet', 0), ('Rol en totstandkoming van netwerken', 0), ('Individu in het informatielandschap', 0), ('Identificeren van informatiebehoefte', 0), ('Zoeken ter oriëntatie', 0), ('Formuleren van onderzoeksvraag', 0), ('Plannen en zoeken', 0), ('Selecteren informatiebronnen en zoeksystemen', 0), ('Selecteren zoektermen', 0), ('Zoeken naar informatie', 0), ('Kritisch beoordelen', 0), ('Beoordelen van resultaten (kritisch)', 0), ('Informatieverwerking (lezen, luisteren e.d.)', 0), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 0), ('Evalueren van zoekproces (kritisch)', 0), ('Organiseren en verwerken', 0), ('Manage proces en zoekresultaten', 0), ('Samenwerken (in teams)', 0), ('Analyseren van zoekresultaten (informatieanalyse)', 0), ('Gebruik en verwerken van informatie (ethisch)', 0), ('Bronvermelding', 0), ('Auteursrecht', 0), ('Privacygevoelige informatie', 0), ('Synthetiseren of creëren van nieuwe informatie', 0), ('Publiceren en communiceren', 0), ('Publiceren (van eindproduct)', 0), ('Communiceren (van eindproduct)', 0), ('Valoriseren van bevindingen (outreach)', 0)]
#
# Aard en verschijningsvormen van informatie/data
#
# [('Waarde van informatie/data', 1), ('Aard en verschijningsvormen van informatie/data', 1), ('Selecteren informatiebronnen en zoeksystemen', 1), ('Beoordelen van resultaten (kritisch)', 1), ('Informatieverwerking (lezen, luisteren e.d.)', 1), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 1), ('Privacygevoelige informatie', 1), ('Synthetiseren of creëren van nieuwe informatie', 1), ('Communiceren (van eindproduct)', 1), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Werking en structuur van het internet', 0), ('Rol en totstandkoming van netwerken', 0), ('Individu in het informatielandschap', 0), ('Identificeren van informatiebehoefte', 0), ('Zoeken ter oriëntatie', 0), ('Formuleren van onderzoeksvraag', 0), ('Plannen en zoeken', 0), ('Selecteren zoektermen', 0), ('Zoeken naar informatie', 0), ('Kritisch beoordelen', 0), ('Evalueren van zoekproces (kritisch)', 0), ('Organiseren en verwerken', 0), ('Manage proces en zoekresultaten', 0), ('Samenwerken (in teams)', 0), ('Analyseren van zoekresultaten (informatieanalyse)', 0), ('Gebruik en verwerken van informatie (ethisch)', 0), ('Bronvermelding', 0), ('Auteursrecht', 0), ('Publiceren en communiceren', 0), ('Publiceren (van eindproduct)', 0), ('Valoriseren van bevindingen (outreach)', 0)]
#
# Waarde van informatie/data
#
# [('Beoordelingscriteria (relevantie/betrouwbaarheid)', 2), ('Waarde van informatie/data', 1), ('Aard en verschijningsvormen van informatie/data', 1), ('Selecteren informatiebronnen en zoeksystemen', 1), ('Beoordelen van resultaten (kritisch)', 1), ('Informatieverwerking (lezen, luisteren e.d.)', 1), ('Evalueren van zoekproces (kritisch)', 1), ('Manage proces en zoekresultaten', 1), ('Privacygevoelige informatie', 1), ('Synthetiseren of creëren van nieuwe informatie', 1), ('Communiceren (van eindproduct)', 1), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Werking en structuur van het internet', 0), ('Rol en totstandkoming van netwerken', 0), ('Individu in het informatielandschap', 0), ('Identificeren van informatiebehoefte', 0), ('Zoeken ter oriëntatie', 0), ('Formuleren van onderzoeksvraag', 0), ('Plannen en zoeken', 0), ('Selecteren zoektermen', 0), ('Zoeken naar informatie', 0), ('Kritisch beoordelen', 0), ('Organiseren en verwerken', 0), ('Samenwerken (in teams)', 0), ('Analyseren van zoekresultaten (informatieanalyse)', 0), ('Gebruik en verwerken van informatie (ethisch)', 0), ('Bronvermelding', 0), ('Auteursrecht', 0), ('Publiceren en communiceren', 0), ('Publiceren (van eindproduct)', 0), ('Valoriseren van bevindingen (outreach)', 0)]
#
# Beoordelingscriteria (relevantie/betrouwbaarheid)
#
# [('Zoeken ter oriëntatie', 3), ('Selecteren informatiebronnen en zoeksystemen', 2), ('Zoeken naar informatie', 2), ('Aard en verschijningsvormen van informatie/data', 1), ('Selecteren zoektermen', 1), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Waarde van informatie/data', 0), ('Werking en structuur van het internet', 0), ('Rol en totstandkoming van netwerken', 0), ('Individu in het informatielandschap', 0), ('Identificeren van informatiebehoefte', 0), ('Formuleren van onderzoeksvraag', 0), ('Plannen en zoeken', 0), ('Kritisch beoordelen', 0), ('Beoordelen van resultaten (kritisch)', 0), ('Informatieverwerking (lezen, luisteren e.d.)', 0), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 0), ('Evalueren van zoekproces (kritisch)', 0), ('Organiseren en verwerken', 0), ('Manage proces en zoekresultaten', 0), ('Samenwerken (in teams)', 0), ('Analyseren van zoekresultaten (informatieanalyse)', 0), ('Gebruik en verwerken van informatie (ethisch)', 0), ('Bronvermelding', 0), ('Auteursrecht', 0), ('Privacygevoelige informatie', 0), ('Synthetiseren of creëren van nieuwe informatie', 0), ('Publiceren en communiceren', 0), ('Publiceren (van eindproduct)', 0), ('Communiceren (van eindproduct)', 0), ('Valoriseren van bevindingen (outreach)', 0)]
#
# Zoeken ter oriëntatie
#
# [('Aard en verschijningsvormen van informatie/data', 2), ('Selecteren informatiebronnen en zoeksystemen', 2), ('Beoordelen van resultaten (kritisch)', 2), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 2), ('Waarde van informatie/data', 1), ('Werking en structuur van het internet', 1), ('Zoeken ter oriëntatie', 1), ('Informatieverwerking (lezen, luisteren e.d.)', 1), ('Privacygevoelige informatie', 1), ('Synthetiseren of creëren van nieuwe informatie', 1), ('Communiceren (van eindproduct)', 1), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Rol en totstandkoming van netwerken', 0), ('Individu in het informatielandschap', 0), ('Identificeren van informatiebehoefte', 0), ('Formuleren van onderzoeksvraag', 0), ('Plannen en zoeken', 0), ('Selecteren zoektermen', 0), ('Zoeken naar informatie', 0), ('Kritisch beoordelen', 0), ('Evalueren van zoekproces (kritisch)', 0), ('Organiseren en verwerken', 0), ('Manage proces en zoekresultaten', 0), ('Samenwerken (in teams)', 0), ('Analyseren van zoekresultaten (informatieanalyse)', 0), ('Gebruik en verwerken van informatie (ethisch)', 0), ('Bronvermelding', 0), ('Auteursrecht', 0), ('Publiceren en communiceren', 0), ('Publiceren (van eindproduct)', 0), ('Valoriseren van bevindingen (outreach)', 0)]
#
# Aard en verschijningsvormen van informatie/data
#
# [('Zoeken ter oriëntatie', 2), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 2), ('Publiceren (van eindproduct)', 2), ('Aard en verschijningsvormen van informatie/data', 1), ('Zoeken naar informatie', 1), ('Beoordelen van resultaten (kritisch)', 1), ('Manage proces en zoekresultaten', 1), ('Analyseren van zoekresultaten (informatieanalyse)', 1), ('Synthetiseren of creëren van nieuwe informatie', 1), ('Communiceren (van eindproduct)', 1), ('Valoriseren van bevindingen (outreach)', 1), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Waarde van informatie/data', 0), ('Werking en structuur van het internet', 0), ('Rol en totstandkoming van netwerken', 0), ('Individu in het informatielandschap', 0), ('Identificeren van informatiebehoefte', 0), ('Formuleren van onderzoeksvraag', 0), ('Plannen en zoeken', 0), ('Selecteren informatiebronnen en zoeksystemen', 0), ('Selecteren zoektermen', 0), ('Kritisch beoordelen', 0), ('Informatieverwerking (lezen, luisteren e.d.)', 0), ('Evalueren van zoekproces (kritisch)', 0), ('Organiseren en verwerken', 0), ('Samenwerken (in teams)', 0), ('Gebruik en verwerken van informatie (ethisch)', 0), ('Bronvermelding', 0), ('Auteursrecht', 0), ('Privacygevoelige informatie', 0), ('Publiceren en communiceren', 0)]
#
# Zoeken ter oriëntatie
#
# [('Aard en verschijningsvormen van informatie/data', 2), ('Selecteren informatiebronnen en zoeksystemen', 2), ('Beoordelen van resultaten (kritisch)', 2), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 2), ('Waarde van informatie/data', 1), ('Werking en structuur van het internet', 1), ('Zoeken ter oriëntatie', 1), ('Informatieverwerking (lezen, luisteren e.d.)', 1), ('Privacygevoelige informatie', 1), ('Synthetiseren of creëren van nieuwe informatie', 1), ('Communiceren (van eindproduct)', 1), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Rol en totstandkoming van netwerken', 0), ('Individu in het informatielandschap', 0), ('Identificeren van informatiebehoefte', 0), ('Formuleren van onderzoeksvraag', 0), ('Plannen en zoeken', 0), ('Selecteren zoektermen', 0), ('Zoeken naar informatie', 0), ('Kritisch beoordelen', 0), ('Evalueren van zoekproces (kritisch)', 0), ('Organiseren en verwerken', 0), ('Manage proces en zoekresultaten', 0), ('Samenwerken (in teams)', 0), ('Analyseren van zoekresultaten (informatieanalyse)', 0), ('Gebruik en verwerken van informatie (ethisch)', 0), ('Bronvermelding', 0), ('Auteursrecht', 0), ('Publiceren en communiceren', 0), ('Publiceren (van eindproduct)', 0), ('Valoriseren van bevindingen (outreach)', 0)]
#
# Aard en verschijningsvormen van informatie/data
#
# [('Aard en verschijningsvormen van informatie/data', 2), ('Bronvermelding', 2), ('Synthetiseren of creëren van nieuwe informatie', 2), ('Publiceren (van eindproduct)', 2), ('Waarde van informatie/data', 1), ('Zoeken ter oriëntatie', 1), ('Selecteren informatiebronnen en zoeksystemen', 1), ('Beoordelen van resultaten (kritisch)', 1), ('Informatieverwerking (lezen, luisteren e.d.)', 1), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 1), ('Auteursrecht', 1), ('Privacygevoelige informatie', 1), ('Communiceren (van eindproduct)', 1), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Werking en structuur van het internet', 0), ('Rol en totstandkoming van netwerken', 0), ('Individu in het informatielandschap', 0), ('Identificeren van informatiebehoefte', 0), ('Formuleren van onderzoeksvraag', 0), ('Plannen en zoeken', 0), ('Selecteren zoektermen', 0), ('Zoeken naar informatie', 0), ('Kritisch beoordelen', 0), ('Evalueren van zoekproces (kritisch)', 0), ('Organiseren en verwerken', 0), ('Manage proces en zoekresultaten', 0), ('Samenwerken (in teams)', 0), ('Analyseren van zoekresultaten (informatieanalyse)', 0), ('Gebruik en verwerken van informatie (ethisch)', 0), ('Publiceren en communiceren', 0), ('Valoriseren van bevindingen (outreach)', 0)]
#
# Aard en verschijningsvormen van informatie/data
