# %%
import pandas as pd
import re, os, string
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.stem import WordNetLemmatizer
import nltk

# %%
def clean_text(text):
    """Doc cleaning"""
    
    # Lowering text
    text = text.lower()
    
    # Removing whitespace and newlines
    text = re.sub('\s+',' ',text)
    
    # extract Noun
    token_words = word_tokenize(text)
    noun_words=[]
    for word,pos in nltk.pos_tag(token_words):
        if (pos == 'NN' or pos == 'NNP' or pos == 'NNS' or pos == 'NNPS'):
            noun_words.append(word)   
            text = " ".join(noun_words)

    # lemmatize
    wl = WordNetLemmatizer()
    lemma_words=[]
    for word in noun_words:
        lemma_words.append(wl.lemmatize(word))
        lemma_words.append(" ")
        text = " ".join(lemma_words)
    
    return text

# %%
def get_stopwords_list(stop_file_path):
    """load stop words """
    
    with open(stop_file_path, 'r', encoding="utf-8") as f:
        stopwords = f.readlines()
        stop_set = set(m.strip() for m in stopwords)
        return list(frozenset(stop_set))

# %%
def sort_coo(coo_matrix):
    """Sort a dict with highest score"""
    tuples = zip(coo_matrix.col, coo_matrix.data)
    return sorted(tuples, key=lambda x: (x[1], x[0]), reverse=True)

def extract_topn_from_vector(feature_names, sorted_items, topn=10):
    """get the feature names and tf-idf score of top n items"""
    
    #use only topn items from vector
    sorted_items = sorted_items[:topn]

    score_vals = []
    feature_vals = []
    
    # word index and corresponding tf-idf score
    for idx, score in sorted_items:
        
        #keep track of feature name and its corresponding score
        score_vals.append(round(score, 3))
        feature_vals.append(feature_names[idx])

    #create a tuples of feature, score
    results= {}
    for idx in range(len(feature_vals)):
        results[feature_vals[idx]]=score_vals[idx]
    
    return results

# %%
def get_keywords(vectorizer, feature_names, doc):
    """Return top k keywords from a doc using TF-IDF method"""

    #generate tf-idf for the given document
    tf_idf_vector = vectorizer.transform([doc])
    
    #sort the tf-idf vectors by descending order of scores
    sorted_items=sort_coo(tf_idf_vector.tocoo())

    #extract only TOP_K_KEYWORDS
    keywords=extract_topn_from_vector(feature_names,sorted_items,TOP_K_KEYWORDS)
    
    return list(keywords.keys())

# %%
# Constants
PUNCTUATION = """!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~""" 
TOP_K_KEYWORDS = 10 # top k number of keywords to retrieve in a ranked document
STOPWORD_PATH = "../data/stopwords/en_stopwords_list.txt"
PAPERS_PATH = "../data/dev_data.csv"

# %%
data = pd.read_csv(PAPERS_PATH)
data.head()
# Out:
#    id                                     title  \
# 0   1                 Solids, liquids and gases
# 1   2                                   Density
# 2   3  Required practical - determining density
# 3   4                              Gas pressure
# 4   5              Heating and changes of state
#
#                                              content        gold_label  \
# 0  The kinetic theory is an attempt to explain wh...  States of matter
# 1  Jonny Nelson explains density with a GCSE Phys...  States of matter
# 2  There are different ways to investigate densit...  States of matter
# 3  The particles in a solid simply vibrate around...  States of matter
# 4  When a material is heated or cooled, two chang...  States of matter
#
#            bl_label         w2v_label
# 0  States of matter  States of matter
# 1  States of matter  States of matter
# 2  States of matter  States of matter
# 3  States of matter  States of matter
# 4  States of matter  States of matter

# %%
data.dropna(subset=['content'], inplace=True)

# %%
data['content'] = data['content'].apply(clean_text)
data.head()
# Out:
#    id                                     title  \
# 0   1                 Solids, liquids and gases
# 1   2                                   Density
# 2   3  Required practical - determining density
# 3   4                              Gas pressure
# 4   5              Heating and changes of state
#
#                                              content        gold_label  \
# 0  theory   attempt   material   form   state   p...  States of matter
# 1  jonny   nelson   density   gcse   physic   exp...  States of matter
# 2  way   density   activity   mass   measure   ma...  States of matter
# 3  particle   point   particle   liquid   roll   ...  States of matter
# 4  material   change   particle   material   bond...  States of matter
#
#            bl_label         w2v_label
# 0  States of matter  States of matter
# 1  States of matter  States of matter
# 2  States of matter  States of matter
# 3  States of matter  States of matter
# 4  States of matter  States of matter

# %%
corpora = data['content'].to_list()

# %%
#load a set of stop words
stopwords=get_stopwords_list(STOPWORD_PATH)

# Initializing TF-IDF Vectorizer with stopwords
vectorizer = TfidfVectorizer(stop_words=stopwords, smooth_idf=True, use_idf=True)

# Creating vocab with our corpora
vectorizer.fit_transform(corpora)

# Storing vocab
feature_names = vectorizer.get_feature_names()

# %%
result = [] #a list of dictionary, key is 'top_keywords', value is list of keywords
for doc in corpora:
    df = {}
    #df['full_text'] = doc
    df['top_keywords'] = get_keywords(vectorizer, feature_names, doc)
    result.append(df)


final = pd.DataFrame(result)
final
# Out:
#                                           top_keywords
# 0    [liquid, particle, solid, bond, gas, theory, m...
# 1    [density, m3, rho, kg, mass, centimetre, volum...
# 2    [density, mass, steel, cylinder, pan, measure,...
# 3    [particle, gas, container, pressure, collision...
# 4    [energy, particle, store, bond, change, materi...
# ..                                                 ...
# 287  [variable, value, hypothesis, prediction, rate...
# 288  [equipment, cylinder, hazard, liquid, step, ex...
# 289  [cross, experiment, reaction, data, observatio...
# 290  [variable, graph, data, repeat, line, result, ...
# 291  [error, result, investigation, quality, reprod...
#
# [292 rows x 1 columns]

# %%
text_keyword=[]
for item in result:
    text_keyword.append(item['top_keywords'])
print(text_keyword[:5])
# Out:
# [['liquid', 'particle', 'solid', 'bond', 'gas', 'theory', 'marble', 'container', 'arrangement', 'property'], ['density', 'm3', 'rho', 'kg', 'mass', 'centimetre', 'volume', 'particle', 'frac', 'material'], ['density', 'mass', 'steel', 'cylinder', 'pan', 'measure', 'volume', 'cube', 'stone', 'balance'], ['particle', 'gas', 'container', 'pressure', 'collision', 'balloon', 'air', 'room', 'liquid', 'vary'], ['energy', 'particle', 'store', 'bond', 'change', 'material', 'ice', 'substance', 'thermal', 'system']]

# %%
# read taxonomy
import pickle
with open('../data/LO_picklefile/gcse.pickle','rb') as pickle_file:
    los = pickle.load(pickle_file)

# %%
extracted_key_value_from_dict = []
for item in los:
    key_to_extract = {'name','keywords'}
    extracted_dict = {key: item[key] for key in item.keys()
                               & key_to_extract}
    extracted_key_value_from_dict.append(extracted_dict)

# %%
from gensim.models import KeyedVectors
print("loading")
word2vec_model  = KeyedVectors.load_word2vec_format("/Users/zjy/Desktop/EDIA intern/code/w2v_model/17/model.txt")
print("done loading")
# Out:
# loading
# done loading

# %%
import numpy as np

# A function that takes a sentence as a list of tokens and returns the mean vector for a given model
def get_sentence_vector(sentence, model): 
    word_vectors =[]
    for word in sentence: 
        # Ignore words that are not in the vocabulary
        try: 
            index = model.key_to_index[word]
            word_vectors.append(model.get_vector(word))
        except:
            continue
    
    word_matrix = np.asarray(word_vectors)
    mean_vector = np.mean(word_matrix, axis=0)
    sum_vector = np.sum(word_matrix, axis=0)

    return mean_vector, sum_vector

# %%
def classify_text(text_kws, los):
    """classify text by counting the overlapping keywords between text and taxonomy
       text_kws: list of lists, keywords extracted from text
       los: list of dicts, keywords of learning obkectives
    """
    from scipy.spatial import distance
    rv = []
    for ks in text_kws:
        #initialize the value of lo['name']
        scores = {lo['name']: 0 for lo in los}
        vector1 = get_sentence_vector(ks, word2vec_model)[0]
        for lo in los:
            #create a set to collect cleaned value of dictionary
            cl=set()
            for kw in lo['keywords']:
                # clean up the value of dictionary
                cw = kw.lower().replace('_',' ')
                cw = word_tokenize(cw)
                for i in cw:
                    cl.add(i)
            
            if cl:
                vector2 = get_sentence_vector(cl, word2vec_model)[0]
                scores[lo['name']] = 1- distance.cosine(vector1,vector2)
            
        rv.append(scores)
            
    return rv

# %%
text_kws = text_keyword
los = extracted_key_value_from_dict
classified=classify_text(text_kws, los)

# %%
#sort dictionary by the similarity score from high to low
for dic in classified:
    x=sorted(dic.items(), key=lambda x:x[1], reverse=True)
    print(x)
    print()
    print(x[0][0])
    print()
# Out:
# [('States of matter', 0.8504772186279297), ('Groups in the periodic table', 0.8175879120826721), ('Atomic structure', 0.7619838714599609), ('The periodic table', 0.7615774273872375), ('Metals', 0.7405233979225159), ('Carbon chemistry', 0.7384146451950073), ('Covalent bonding', 0.7334937453269958), ('Transport into and out of cells', 0.7231638431549072), ('Ionic compounds', 0.7028122544288635), ('Forces', 0.6990305781364441), ('Photosynthesis', 0.6915920972824097), ('Chemical equations', 0.6819543838500977), ('Electrons and chemical reactions', 0.6769500970840454), ('Waves', 0.6765685081481934), ('Cells in animals and plants', 0.6732091903686523), ('Plant organisation', 0.6717327833175659), ('Energy changes', 0.6683484315872192), ('Equilibria', 0.6629935503005981), ('Exchange surfaces and transport systems', 0.6589025259017944), ('Circuits', 0.6481848955154419), ("Newton's laws", 0.6450170278549194), ('The digestive system', 0.6392830014228821), ('Water', 0.6379223465919495), ('Energy, rates and reactions', 0.6352217197418213), ('Calculations in chemistry', 0.6323209404945374), ('Magnetism and electromagnetism', 0.6269922852516174), ('Respiration', 0.6222860217094421), ('Motion', 0.6198787093162537), ('Rates of reaction', 0.6193274855613708), ('Radiation and risk', 0.6106610894203186), ('Acids and alkalis', 0.6029406189918518), ('The atmosphere', 0.6021237969398499), ('Energy resources', 0.5927730798721313), ('Material resources', 0.5800304412841797), ('Cell division', 0.5784257650375366), ('Plant diseases', 0.5613610744476318), ('Homeostasis', 0.5589423179626465), ('Mains electricity', 0.5524921417236328), ('Coordination and control', 0.5446667671203613), ('Ecosystems and biodiversity', 0.5368430614471436), ('Evolution', 0.5256981253623962), ('Preventing, treating and curing diseases', 0.5080633759498596), ('Lifestyle and health', 0.4842418432235718), ('Reproduction and fertility', 0.44951489567756653), ('Inheritance', 0.418130487203598), ('Practical skills for carrying out a scientific investigation', 0.41714775562286377), ('Combined Science', 0), ('Not related', 0), ('Building blocks', 0), ('Transport over larger distances', 0), ('Interactions with the environment', 0), ('Explaining change', 0), ('Building blocks for understanding', 0), ('Interactions over small and large distances', 0), ('Movement and interactions', 0), ('Guiding Spaceship Earth towards a sustainable future', 0), ('Practical skills', 0)]
#
# States of matter
#
# [('States of matter', 0.7641171813011169), ('Atomic structure', 0.7477179169654846), ('Energy changes', 0.7317360639572144), ('Cells in animals and plants', 0.722057580947876), ('Transport into and out of cells', 0.710616946220398), ('Chemical equations', 0.7098453044891357), ('Waves', 0.7064779996871948), ('The periodic table', 0.6964707970619202), ('Forces', 0.6763235926628113), ('Plant organisation', 0.6758102774620056), ('Motion', 0.6665983200073242), ('Exchange surfaces and transport systems', 0.6622195243835449), ('Circuits', 0.6525058746337891), ('Photosynthesis', 0.6482488512992859), ('Calculations in chemistry', 0.6413376927375793), ('Ionic compounds', 0.6374940872192383), ('The digestive system', 0.6325691938400269), ('Carbon chemistry', 
('Combined Science', 0), ('Not related', 0), ('Building blocks', 0), ('Transport over larger distances', 0), ('Interactions with the environment', 0), ('Explaining change', 0), ('Building blocks for understanding', 0), ('Interactions over small and large distances', 0), ('Movement and interactions', 0), ('Guiding Spaceship Earth towards a sustainable future', 0), ('Practical skills', 0)]
#
# Cells in animals and plants
#
# [('Cells in animals and plants', 0.7956088185310364), ('Waves', 0.7718375325202942), ('Atomic structure', 0.6867651343345642), ('Circuits', 0.6853247284889221), ('Forces', 0.6682868599891663), ('Transport into and out of cells', 0.6590290665626526), ('States of matter', 0.6451684236526489), ('Motion', 0.6368446350097656), ('Ionic compounds', 0.631907045841217), ('Chemical equations', 0.6223649978637695), ('Plant organisation', 0.6181784272193909), ('Radiation and risk', 0.6143147349357605), ('The periodic table', 0.6069766879081726), ('Energy changes', 0.6047855615615845), ('Carbon chemistry', 0.6037646532058716), ('Exchange surfaces and transport systems', 0.602730393409729), ('Electrons and chemical reactions', 0.6022599339485168), ('Photosynthesis', 0.5989824533462524), ('Magnetism and electromagnetism', 0.5893781185150146), ('Groups in the periodic table', 0.587899386882782), ('Equilibria', 0.5867431163787842), ('Metals', 0.5866111516952515), ('Cell division', 0.5836629867553711), ('Covalent bonding', 0.5826666951179504), ('The digestive system', 0.5780848264694214), ("Newton's laws", 0.5686504244804382), ('Coordination and control', 0.5670102834701538), ('Respiration', 0.5582154393196106), ('Rates of reaction', 0.5534210205078125), ('Calculations in chemistry', 0.5424977540969849), ('Energy, rates and reactions', 0.5265465378761292), ('Plant diseases', 0.5098027586936951), ('Mains electricity', 0.49077579379081726), ('Acids and alkalis', 0.4892043173313141), ('Energy resources', 0.4826650321483612), ('Homeostasis', 0.4752764403820038), ('Practical skills for carrying out a scientific investigation', 0.4732263684272766), ('Inheritance', 0.47225064039230347), ('Water', 0.4712281823158264), ('Evolution', 0.46617645025253296), ('Preventing, treating and curing diseases', 0.4629898965358734), ('Lifestyle and health', 0.4514930248260498), ('The atmosphere', 0.4410657286643982), ('Material resources', 0.43403372168540955), ('Ecosystems and biodiversity', 0.4339999556541443), ('Reproduction and fertility', 0.4285144805908203), ('Combined Science', 0), ('Not related', 0), ('Building blocks', 0), ('Transport over larger distances', 0), ('Interactions with the environment', 0), ('Explaining change', 0), ('Building blocks for understanding', 0), ('Interactions over small and large distances', 0), ('Movement and interactions', 0), ('Guiding Spaceship Earth towards a sustainable future', 0), ('Practical skills', 0)]
#
# Cells in animals and plants
#
# [('Exchange surfaces and transport systems', 0.8473599553108215), ('Cell division', 0.8357948064804077), ('Coordination and control', 0.8131848573684692), ('Cells in animals and plants', 0.8081284165382385), ('Transport into and out of cells', 0.8055351972579956), ('The digestive system', 0.7856032848358154), ('Plant organisation', 0.7576384544372559), ('Respiration', 0.7525449395179749), ('Homeostasis', 0.71503084897995), ('Preventing, treating and curing diseases', 0.7029659152030945), ('Reproduction and fertility', 0.6908278465270996), ('States of matter', 0.6891425848007202), ('Photosynthesis', 0.6871113777160645), ('Plant diseases', 0.6794065833091736), ('Atomic structure', 0.6737644076347351), ('Waves', 0.65657639503479), ('Chemical equations', 0.6533329486846924), ('Forces', 0.6514096856117249), ('Electrons and chemical reactions', 0.6437893509864807), ('Inheritance', 0.6430684924125671), ('Lifestyle and health', 0.6420425772666931), ('Energy, rates and reactions', 0.6340650916099548), ('Equilibria', 0.6247380375862122), ('The periodic table', 0.6245113015174866), ('Covalent bonding', 0.6241486668586731), ('Ionic compounds', 0.6218970417976379), ('Rates of reaction', 0.6171277165412903), ('Energy changes', 0.6146552562713623), ('Evolution', 0.6059948205947876), ('Groups in the periodic table', 0.5927397012710571), ('Magnetism and electromagnetism', 0.5815610289573669), ('Circuits', 0.5757984519004822), ('Carbon chemistry', 0.575625479221344), ('Radiation and risk', 0.5703903436660767), ('Acids and alkalis', 0.5605342984199524), ('Metals', 0.5586591958999634), ("Newton's laws", 0.5578495264053345), ('Calculations in chemistry', 0.5534889101982117), ('Water', 0.5532124638557434), ('Motion', 0.5459873676300049), ('The atmosphere', 0.5277889966964722), ('Ecosystems and biodiversity', 0.5232188105583191), ('Mains electricity', 0.488391637802124), ('Energy resources', 0.4809166193008423), ('Material resources', 0.46959933638572693), ('Practical skills for carrying out a scientific investigation', 0.42684727907180786), ('Combined Science', 0), ('Not related', 0), ('Building blocks', 0), ('Transport over larger distances', 0), ('Interactions with the environment', 0), ('Explaining change', 0), ('Building blocks for understanding', 0), ('Interactions over small and large distances', 0), ('Movement and interactions', 0), ('Guiding Spaceship Earth towards a sustainable future', 0), ('Practical skills', 0)]
#
# Exchange surfaces and transport systems
#
# [('Transport into and out of cells', 0.8719089031219482), ('Cells in animals and plants', 0.8603127598762512), ('Plant organisation', 0.8403080701828003), ('Cell division', 0.8271116614341736), ('Exchange surfaces and transport systems', 0.8248542547225952), ('The digestive system', 0.822124183177948), ('Respiration', 0.7942176461219788), ('Photosynthesis', 0.7711669206619263), ('Plant diseases', 0.7644278407096863), ('Coordination and control', 0.7366604804992676), ('Atomic structure', 0.7363075613975525), ('States of matter', 0.7301396131515503), ('Ionic compounds', 0.7099366188049316), ('Covalent bonding', 0.7070887088775635), ('Electrons and chemical reactions', 0.700705885887146), ('Waves', 0.6878015995025635), ('Chemical equations', 0.686739981174469), ('The periodic table', 0.6733372807502747), ('Groups in the periodic table', 0.6709447503089905), ('Carbon chemistry', 0.666119396686554), ('Homeostasis', 0.6579422354698181), ('Inheritance', 0.657535195350647), ('Metals', 0.6571365594863892), ('Forces', 0.6543960571289062), ('Energy, rates and reactions', 0.6536442637443542), ('Equilibria', 0.6468713283538818), ('Acids and alkalis', 0.6452582478523254), ('Preventing, treating and curing diseases', 0.640651524066925), ('Water', 0.6348260045051575), ('Circuits', 0.6316176056861877), ('Energy changes', 0.6021191477775574), ('Radiation and risk', 0.5977933406829834), ('Magnetism and electromagnetism', 0.5962929129600525), ('Reproduction and fertility', 0.5962156653404236), ('Rates of reaction', 0.5883457660675049), ('Evolution', 0.5863426923751831), ('Lifestyle and health', 0.567459225654602), ('Calculations in chemistry', 0.5631187558174133), ('Ecosystems and biodiversity', 0.548806369304657), ('Motion', 0.5447355508804321), ("Newton's laws", 0.5315358638763428), ('The atmosphere', 0.5308578610420227), ('Material resources', 0.5153376460075378), ('Energy resources', 0.500639021396637), ('Mains electricity', 0.49363112449645996), ('Practical skills for carrying out a scientific investigation', 0.3912225663661957), ('Combined Science', 0), ('Not related', 0), ('Building blocks', 0), ('Transport over larger distances', 0), ('Interactions with the environment', 0), ('Explaining change', 0), ('Building blocks for understanding', 0), ('Interactions over small and large distances', 0), ('Movement and interactions', 0), ('Guiding Spaceship Earth towards a sustainable future', 0), ('Practical skills', 0)]
#
# Transport into and out of cells
#
# [('Cell division', 0.8927257657051086), ('Transport into and out of cells', 0.8387856483459473), ('Cells in animals and plants', 0.8385038375854492), ('The digestive system', 0.822612464427948), ('Plant organisation', 0.8198162317276001), ('Plant diseases', 0.8090084791183472), ('Inheritance', 0.8082045912742615), ('Respiration', 0.8015010952949524), ('Exchange surfaces and transport systems', 0.799809992313385), ('Photosynthesis', 0.76052325963974), ('Coordination and control', 0.7577930688858032), ('Preventing, treating and curing diseases', 0.7054833173751831), ('Atomic structure', 0.6633374094963074), ('Covalent bonding', 0.6582777500152588), ('Energy, rates and reactions', 0.6565893888473511), ('Ev
0.5681245923042297), ('Ionic compounds', 0.5669236779212952), ('Material resources', 0.552587628364563), ('Preventing, treating and curing diseases', 0.5525559782981873), ('Mains electricity', 0.5523626804351807), ('Acids and alkalis', 0.5491302609443665), ('Plant diseases', 0.5320888757705688), ('Lifestyle and health', 0.5272499918937683), ('Evolution', 0.501059353351593), ('Reproduction and fertility', 0.49973055720329285), ('Ecosystems and biodiversity', 0.49491071701049805), ('Practical skills for carrying out a scientific investigation', 0.47611942887306213), ('Inheritance', 0.4236341118812561), ('Combined Science', 0), ('Not related', 0), ('Building blocks', 0), ('Transport over larger distances', 0), ('Interactions with the environment', 0), ('Explaining change', 0), ('Building blocks for understanding', 0), ('Interactions over small and large distances', 0), ('Movement and interactions', 0), ('Guiding Spaceship Earth towards a sustainable future', 0), ('Practical skills', 0)]
#
# States of matter
#
# [('The periodic table', 0.7253279089927673), ('Forces', 0.7202211022377014), ('Chemical equations', 0.7112568616867065), ('Waves', 0.7070006728172302), ('States of matter', 0.7025777101516724), ('Atomic structure', 0.6959913372993469), ('Motion', 0.6928991675376892), ('Calculations in chemistry', 0.668273389339447), ('Rates of reaction', 0.6679813265800476), ('Energy changes', 0.6618109941482544), ('Equilibria', 0.6601924300193787), ('Cells in animals and plants', 0.6596243381500244), ('Electrons and chemical reactions', 0.630422055721283), ('Practical skills for carrying out a scientific investigation', 0.6187854409217834), ('Circuits', 0.6118007898330688), ('Magnetism and electromagnetism', 0.6075769662857056), ('Energy, rates and reactions', 0.6051924824714661), ("Newton's laws", 0.604712188243866), ('Transport into and out of cells', 0.6001160144805908), ('Mains electricity', 0.589367687702179), ('Cell division', 0.5880768895149231), ('Exchange surfaces and transport systems', 0.5818442702293396), ('Coordination and control', 0.5681104063987732), ('Radiation and risk', 0.5662731528282166), ('Groups in the periodic table', 0.5653775930404663), ('Metals', 0.5648917555809021), ('The atmosphere', 0.5602536201477051), ('Evolution', 0.55631422996521), ('Photosynthesis', 0.5520728230476379), ('Ionic compounds', 0.5496804118156433), ('The digestive system', 0.5463790893554688), ('Material resources', 0.5414542555809021), ('Preventing, treating and curing diseases', 0.5372260808944702), ('Plant organisation', 0.5364900827407837), ('Respiration', 0.5275110006332397), ('Homeostasis', 0.5259313583374023), ('Energy resources', 0.5240222811698914), ('Plant diseases', 0.520969569683075), ('Covalent bonding', 0.5133876800537109), ('Water', 0.5083279013633728), ('Carbon chemistry', 0.4977095127105713), ('Lifestyle and health', 0.479265958070755), ('Ecosystems and biodiversity', 0.47491246461868286), ('Reproduction and fertility', 0.4707067906856537), ('Acids and alkalis', 0.4681740403175354), ('Inheritance', 0.4475986063480377), ('Combined Science', 0), ('Not related', 0), ('Building blocks', 0), ('Transport over larger distances', 0), ('Interactions with the environment', 0), ('Explaining change', 0), ('Building blocks for understanding', 0), ('Interactions over small and large distances', 0), ('Movement and interactions', 0), ('Guiding Spaceship Earth towards a sustainable future', 0), ('Practical skills', 0)]
#
# The periodic table
#
# [('Waves', 0.6368780732154846), ('Cells in animals and plants', 0.6354575157165527), ('Forces', 0.617522120475769), ('Cell division', 0.6085474491119385), ('Circuits', 0.6072062849998474), ('States of matter', 0.606816828250885), ('Atomic structure', 0.6024083495140076), ('The periodic table', 0.6009852290153503), ('Motion', 0.5980205535888672), ('Practical skills for carrying out a scientific investigation', 0.5874382257461548), ('Chemical equations', 0.5863032341003418), ('Rates of reaction', 0.581089198589325), ('Equilibria', 0.5700812339782715), ('Mains electricity', 0.5693178772926331), ('Calculations in chemistry', 0.5635380744934082), ('Transport into and out of cells', 0.5451703071594238), ('Exchange surfaces and transport systems', 0.5410403609275818), ('Coordination and control', 0.5405139327049255), ('Energy changes', 0.5401480793952942), ('Evolution', 0.5366127490997314), ("Newton's laws", 0.5192171335220337), ('Plant organisation', 0.5077029466629028), ('The digestive system', 0.5076469779014587), ('Energy, rates and reactions', 0.5005078911781311), ('Material resources', 0.497938871383667), ('Inheritance', 0.4973205626010895), ('Magnetism and electromagnetism', 0.49723073840141296), ('Plant diseases', 0.4899195432662964), ('Electrons and chemical reactions', 0.48775234818458557), ('Photosynthesis', 0.4810117185115814), ('Covalent bonding', 0.4804067313671112), ('Metals', 0.4741286337375641), ('Homeostasis', 0.4735690653324127), ('Groups in the periodic table', 0.47144967317581177), ('The atmosphere', 0.46700939536094666), ('Respiration', 0.46533894538879395), ('Ionic compounds', 0.4637431502342224), ('Radiation and risk', 0.46090343594551086), ('Preventing, treating and curing diseases', 0.4581434726715088), ('Carbon chemistry', 0.44824355840682983), ('Ecosystems and biodiversity', 0.4430283010005951), ('Reproduction and fertility', 0.439930260181427), ('Water', 0.4347464442253113), ('Lifestyle and health', 0.43403878808021545), ('Energy resources', 0.4315444827079773), ('Acids and alkalis', 0.3444294333457947), ('Combined Science', 0), ('Not related', 0), ('Building blocks', 0), ('Transport over larger distances', 0), ('Interactions with the environment', 0), ('Explaining change', 0), ('Building blocks for understanding', 0), ('Interactions over small and large distances', 0), ('Movement and interactions', 0), ('Guiding Spaceship Earth towards a sustainable future', 0), ('Practical skills', 0)]
#
# Waves
#
# [('Cells in animals and plants', 0.6919170618057251), ('Practical skills for carrying out a scientific investigation', 0.6839282512664795), ('States of matter', 0.6773569583892822), ('Waves', 0.6662442088127136), ('The periodic table', 0.6591127514839172), ('Forces', 0.6486189365386963), ('Rates of reaction', 0.6422045826911926), ('Chemical equations', 0.6397134065628052), ('Calculations in chemistry', 0.6384545564651489), ('Transport into and out of cells', 0.6258487701416016), ('Atomic structure', 0.625453770160675), ('Material resources', 0.6159811019897461), ('Circuits', 0.610113799571991), ('Energy changes', 0.6051115989685059), ('Evolution', 0.6011950969696045), ('Cell division', 0.6011786460876465), ('Exchange surfaces and transport systems', 0.5934473276138306), ('Equilibria', 0.5921228528022766), ('Electrons and chemical reactions', 0.5906015634536743), ('The digestive system', 0.5867741107940674), ('Photosynthesis', 0.5834333300590515), ('Energy, rates and reactions', 0.5759300589561462), ("Newton's laws", 0.572659432888031), ('Respiration', 0.5664064884185791), ('Plant organisation', 0.5640220642089844), ('Motion', 0.5605412125587463), ('Water', 0.5493481159210205), ('Radiation and risk', 0.54691082239151), ('Preventing, treating and curing diseases', 0.5382675528526306), ('Ecosystems and biodiversity', 0.5363141894340515), ('Homeostasis', 0.5317354798316956), ('Groups in the periodic table', 0.52867591381073), ('Plant diseases', 0.5272654294967651), ('Coordination and control', 0.5266041159629822), ('The atmosphere', 0.5257793068885803), ('Energy resources', 0.5194551944732666), ('Carbon chemistry', 0.5163186192512512), ('Mains electricity', 0.502869725227356), ('Lifestyle and health', 0.5028509497642517), ('Ionic compounds', 0.5026935935020447), ('Inheritance', 0.49665042757987976), ('Covalent bonding', 0.49641600251197815), ('Magnetism and electromagnetism', 0.4901890754699707), ('Metals', 0.4831959903240204), ('Acids and alkalis', 0.4685215651988983), ('Reproduction and fertility', 0.45397356152534485), ('Combined Science', 0), ('Not related', 0), ('Building blocks', 0), ('Transport over larger distances', 0), ('Interactions with the environment', 0), ('Explaining change', 0), ('Building blocks for understanding', 0), ('Interactions over small and large distances', 0), ('Movement and interactions', 0), ('Guiding Spaceship Earth towards a sustainable future', 0), ('Practical skills', 0)]
#
# Cells in animals and plants
