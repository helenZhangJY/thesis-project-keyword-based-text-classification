# %%
import pandas as pd
import re, os, string
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.stem import WordNetLemmatizer
import nltk

# %%
def clean_text(text):
    """Doc cleaning"""
    
    # Lowering text
    text = text.lower()
    
    # Removing whitespace and newlines
    text = re.sub('\s+',' ',text)
    
    # extract Noun
    token_words = word_tokenize(text)
    noun_words=[]
    for word,pos in nltk.pos_tag(token_words):
        if (pos == 'NN' or pos == 'NNP' or pos == 'NNS' or pos == 'NNPS'):
            noun_words.append(word)   
            text = " ".join(noun_words)

    # lemmatize
    wl = WordNetLemmatizer()
    lemma_words=[]
    for word in noun_words:
        lemma_words.append(wl.lemmatize(word))
        lemma_words.append(" ")
        text = " ".join(lemma_words)
    
    return text

# %%
def get_stopwords_list(stop_file_path):
    """load stop words """
    
    with open(stop_file_path, 'r', encoding="utf-8") as f:
        stopwords = f.readlines()
        stop_set = set(m.strip() for m in stopwords)
        return list(frozenset(stop_set))

# %%
def sort_coo(coo_matrix):
    """Sort a dict with highest score"""
    tuples = zip(coo_matrix.col, coo_matrix.data)
    return sorted(tuples, key=lambda x: (x[1], x[0]), reverse=True)

def extract_topn_from_vector(feature_names, sorted_items, topn=10):
    """get the feature names and tf-idf score of top n items"""
    
    #use only topn items from vector
    sorted_items = sorted_items[:topn]

    score_vals = []
    feature_vals = []
    
    # word index and corresponding tf-idf score
    for idx, score in sorted_items:
        
        #keep track of feature name and its corresponding score
        score_vals.append(round(score, 3))
        feature_vals.append(feature_names[idx])

    #create a tuples of feature, score
    results= {}
    for idx in range(len(feature_vals)):
        results[feature_vals[idx]]=score_vals[idx]
    
    return results

# %%
def get_keywords(vectorizer, feature_names, doc):
    """Return top k keywords from a doc using TF-IDF method"""

    #generate tf-idf for the given document
    tf_idf_vector = vectorizer.transform([doc])
    
    #sort the tf-idf vectors by descending order of scores
    sorted_items=sort_coo(tf_idf_vector.tocoo())

    #extract only TOP_K_KEYWORDS
    keywords=extract_topn_from_vector(feature_names,sorted_items,TOP_K_KEYWORDS)
    
    return list(keywords.keys())

# %%
# Constants
PUNCTUATION = """!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~""" 
TOP_K_KEYWORDS = 10 # top k number of keywords to retrieve in a ranked document
STOPWORD_PATH = "../data/stopwords/en_stopwords_list.txt"
PAPERS_PATH = "../data/dev_data.csv"

# %%
data = pd.read_csv(PAPERS_PATH)
data.head()
# Out:
#    id                                     title  \
# 0   1                 Solids, liquids and gases
# 1   2                                   Density
# 2   3  Required practical - determining density
# 3   4                              Gas pressure
# 4   5              Heating and changes of state
#
#                                              content        gold_label  \
# 0  The kinetic theory is an attempt to explain wh...  States of matter
# 1  Jonny Nelson explains density with a GCSE Phys...  States of matter
# 2  There are different ways to investigate densit...  States of matter
# 3  The particles in a solid simply vibrate around...  States of matter
# 4  When a material is heated or cooled, two chang...  States of matter
#
#            bl_label         w2v_label
# 0  States of matter  States of matter
# 1  States of matter  States of matter
# 2  States of matter  States of matter
# 3  States of matter  States of matter
# 4  States of matter  States of matter

# %%
data.dropna(subset=['content'], inplace=True)

# %%
data['content'] = data['content'].apply(clean_text)
data.head()
# Out:
#    id                                     title  \
# 0   1                 Solids, liquids and gases
# 1   2                                   Density
# 2   3  Required practical - determining density
# 3   4                              Gas pressure
# 4   5              Heating and changes of state
#
#                                              content        gold_label  \
# 0  theory   attempt   material   form   state   p...  States of matter
# 1  jonny   nelson   density   gcse   physic   exp...  States of matter
# 2  way   density   activity   mass   measure   ma...  States of matter
# 3  particle   point   particle   liquid   roll   ...  States of matter
# 4  material   change   particle   material   bond...  States of matter
#
#            bl_label         w2v_label
# 0  States of matter  States of matter
# 1  States of matter  States of matter
# 2  States of matter  States of matter
# 3  States of matter  States of matter
# 4  States of matter  States of matter

# %%
corpora = data['content'].to_list()

# %%
#load a set of stop words
stopwords=get_stopwords_list(STOPWORD_PATH)

# Initializing TF-IDF Vectorizer with stopwords
vectorizer = TfidfVectorizer(stop_words=stopwords, smooth_idf=True, use_idf=True)

# Creating vocab with our corpora
vectorizer.fit_transform(corpora)

# Storing vocab
feature_names = vectorizer.get_feature_names()

# %%
result = [] #a list of dictionary, key is 'top_keywords', value is list of keywords
for doc in corpora:
    df = {}
    #df['full_text'] = doc
    df['top_keywords'] = get_keywords(vectorizer, feature_names, doc)
    result.append(df)
    
final = pd.DataFrame(result)
final
# Out:
#                                           top_keywords
# 0    [liquid, particle, solid, bond, gas, theory, m...
# 1    [density, m3, rho, kg, mass, centimetre, volum...
# 2    [density, mass, steel, cylinder, pan, measure,...
# 3    [particle, gas, container, pressure, collision...
# 4    [energy, particle, store, bond, change, materi...
# ..                                                 ...
# 287  [variable, value, hypothesis, prediction, rate...
# 288  [equipment, cylinder, hazard, liquid, step, ex...
# 289  [cross, experiment, reaction, data, observatio...
# 290  [variable, graph, data, repeat, line, result, ...
# 291  [error, result, investigation, quality, reprod...
#
# [292 rows x 1 columns]

# %%
text_keyword=[]
for item in result:
    text_keyword.append(item['top_keywords'])
print(text_keyword[:5])
# Out:
# [['liquid', 'particle', 'solid', 'bond', 'gas', 'theory', 'marble', 'container', 'arrangement', 'property'], ['density', 'm3', 'rho', 'kg', 'mass', 'centimetre', 'volume', 'particle', 'frac', 'material'], ['density', 'mass', 'steel', 'cylinder', 'pan', 'measure', 'volume', 'cube', 'stone', 'balance'], ['particle', 'gas', 'container', 'pressure', 'collision', 'balloon', 'air', 'room', 'liquid', 'vary'], ['energy', 'particle', 'store', 'bond', 'change', 'material', 'ice', 'substance', 'thermal', 'system']]

# %%
# read taxonomy
import pickle
with open('../data/LO_picklefile/gcse.pickle','rb') as pickle_file:
    los = pickle.load(pickle_file)

# %%
extracted_key_value_from_dict = []
for item in los:
    key_to_extract = {'name','keywords'}
    extracted_dict = {key: item[key] for key in item.keys()
                               & key_to_extract}
    extracted_key_value_from_dict.append(extracted_dict)

# %%
def classify_text(text_kws, los):
    """classify text by counting the overlapping keywords between text and taxonomy
       text_kws: list of lists, keywords extracted from text
       los: list of dicts, keywords of learning obkectives
    """
    rv = []
    for ks in text_kws:
        #initialize the value of lo['name']
        scores = {lo['name']: 0 for lo in los}
        for lo in los:
            #create a set to collect cleaned value of dictionary
            cl=set()
            for kw in lo['keywords']:
                # clean up the value of dictionary
                cw = kw.lower().replace('_',' ')
                cl.add(cw)
            scores[lo['name']] = len(cl & set(ks))
        rv.append(scores)
            
    return rv

# %%
text_kws = text_keyword
los = extracted_key_value_from_dict
classified=classify_text(text_kws, los)

# %%
#sort dictionary by the number of overlapping keywords, from high to low
#def sort_dict(classify_text):
for dic in classified:
    x=sorted(dic.items(), key=lambda dic:dic[1], reverse=True)
    print(x)
    print()
    print(x[0][0])
    print()
# Out:
# [('States of matter', 5), ('Atomic structure', 1), ('Combined Science', 0), ('Not related', 0), ('Building blocks', 0), ('Cells in animals and plants', 0), ('Transport into and out of cells', 0), ('Cell division', 0), ('Waves', 0), ('Transport over larger distances', 0), ('Respiration', 0), ('Exchange surfaces and transport systems', 0), ('The digestive system', 0), ('Coordination and control', 0), ('Plant organisation', 0), ('Photosynthesis', 0), ('Plant diseases', 0), ('Interactions with the environment', 0), ('Lifestyle and health', 0), ('Homeostasis', 0), ('Reproduction and fertility', 0), ('Radiation and risk', 0), ('Preventing, treating and curing diseases', 0), ('Explaining change', 0), ('The atmosphere', 0), ('Water', 0), ('Ecosystems and biodiversity', 0), ('Inheritance', 0), ('Evolution', 0), ('Building blocks for understanding', 0), ('The periodic table', 0), ('Groups in the periodic table', 0), ('Chemical equations', 0), ('Calculations in chemistry', 0), ('Interactions over small and large distances', 0), ('Forces', 0), ('Energy changes', 0), ('Ionic compounds', 0), ('Covalent bonding', 0), ('Metals', 0), ('Magnetism and electromagnetism', 0), ('Movement and interactions', 0), ('Motion', 0), ("Newton's laws", 0), ('Circuits', 0), ('Mains electricity', 0), ('Acids and alkalis', 0), ('Rates of reaction', 0), ('Energy, rates and reactions', 0), ('Equilibria', 0), ('Electrons and chemical reactions', 0), ('Guiding Spaceship Earth towards a sustainable future', 0), ('Carbon chemistry', 0), ('Material resources', 0), ('Energy resources', 0), ('Practical skills', 0), ('Practical skills for carrying out a scientific investigation', 0)]
#
# States of matter
#
# [('States of matter', 3), ('Atomic structure', 1), ('Waves', 1), ('Energy changes', 1), ('Combined Science', 0), ('Not related', 0), ('Building blocks', 0), ('Cells in animals and plants', 0), ('Transport into and out of cells', 0), ('Cell division', 0), ('Transport over larger distances', 0), ('Respiration', 0), ('Exchange surfaces and transport systems', 0), ('The digestive system', 0), ('Coordination and control', 0), ('Plant organisation', 0), ('Photosynthesis', 0), ('Plant diseases', 0), ('Interactions with the environment', 0), ('Lifestyle and health', 0), ('Homeostasis', 0), ('Reproduction and fertility', 0), ('Radiation and risk', 0), ('Preventing, treating and curing diseases', 0), ('Explaining change', 0), ('The atmosphere', 0), ('Water', 0), ('Ecosystems and biodiversity', 0), ('Inheritance', 0), ('Evolution', 0), ('Building blocks for understanding', 0), ('The periodic table', 0), ('Groups in the periodic table', 0), ('Chemical equations', 0), ('Calculations in chemistry', 0), ('Interactions over small and large distances', 0), ('Forces', 0), ('Ionic compounds', 0), ('Covalent bonding', 0), ('Metals', 0), ('Magnetism and electromagnetism', 0), ('Movement and interactions', 0), ('Motion', 0), ("Newton's laws", 0), ('Circuits', 0), ('Mains electricity', 0), ('Acids and alkalis', 0), ('Rates of reaction', 0), ('Energy, rates and reactions', 0), ('Equilibria', 0), ('Electrons and chemical reactions', 0), ('Guiding Spaceship Earth towards a sustainable future', 0), ('Carbon chemistry', 0), ('Material resources', 0), ('Energy resources', 0), ('Practical skills', 0), ('Practical skills for carrying out a scientific investigation', 0)]
#
# States of matter
#
# [('States of matter', 2), ('Waves', 1), ('Energy changes', 1), ('Combined Science', 0), ('Not related', 0), ('Building blocks', 0), ('Atomic structure', 0), ('Cells in animals and plants', 0), ('Transport into and out of cells', 0), ('Cell division', 0), ('Transport over larger distances', 0), ('Respiration', 0), ('Exchange surfaces and transport systems', 0), ('The digestive system', 0), ('Coordination and control', 0), ('Plant organisation', 0), ('Photosynthesis', 0), ('Plant diseases', 0), ('Interactions with the environment', 0), ('Lifestyle and health', 0), ('Homeostasis', 0), ('Reproduction and fertility', 0), ('Radiation and risk', 0), ('Preventing, treating and curing diseases', 0), ('Explaining change', 0), ('The atmosphere', 0), ('Water', 0), ('Ecosystems and biodiversity', 0), ('Inheritance', 0), ('Evolution', 0), ('Building blocks for understanding', 0), ('The periodic table', 0), ('Groups in the periodic table', 0), ('Chemical equations', 0), ('Calculations in chemistry', 0), ('Interactions over small and large distances', 0), ('Forces', 0), ('Ionic compounds', 0), ('Covalent bonding', 0), ('Metals', 0), ('Magnetism and electromagnetism', 0), ('Movement and interactions', 0), ('Motion', 0), ("Newton's laws", 0), ('Circuits', 0), ('Mains electricity', 0), ('Acids and alkalis', 0), ('Rates of reaction', 0), ('Energy, rates and reactions', 0), ('Equilibria', 0), ('Electrons and chemical reactions', 0), ('Guiding Spaceship Earth towards a sustainable future', 0), ('Carbon chemistry', 0), ('Material resources', 0), ('Energy resources', 0), ('Practical skills', 0), ('Practical skills for carrying out a scientific investigation', 0)]
#
# States of matter
#
# [('States of matter', 3), ('Atomic structure', 1), ('Combined Science', 0), ('Not related', 0), ('Building blocks', 0), ('Cells in animals and plants', 0), ('Transport into and out of cells', 0), ('Cell division', 0), ('Waves', 0), ('Transport over larger distances', 0), ('Respiration', 0), ('Exchange surfaces and transport systems', 0), ('The digestive system', 0), ('Coordination and control', 0), ('Plant organisation', 0), ('Photosynthesis', 0), ('Plant diseases', 0), ('Interactions with the environment', 0), ('Lifestyle and health', 0), ('Homeostasis', 0), ('Reproduction and fertility', 0), ('Radiation and risk', 0), ('Preventing, treating and curing diseases', 0), ('Explaining change', 0), ('The atmosphere', 0), ('Water', 0), ('Ecosystems and biodiversity', 0), ('Inheritance', 0), ('Evolution', 0), ('Building blocks for understanding', 0), ('The periodic table', 0), ('Groups in the periodic table', 0), ('Chemical equations', 0), ('Calculations in chemistry', 0), ('Interactions over small and large distances', 0), ('Forces', 0), ('Energy changes', 0), ('Ionic compounds', 0), ('Covalent bonding', 0), ('Metals', 0), ('Magnetism and electromagnetism', 0), ('Movement and interactions', 0), ('Motion', 0), ("Newton's laws", 0), ('Circuits', 0), ('Mains electricity', 0), ('Acids and alkalis', 0), ('Rates of reaction', 0), ('Energy, rates and reactions', 0), ('Equilibria', 0), ('Electrons and chemical reactions', 0), ('Guiding Spaceship Earth towards a sustainable future', 0), ('Carbon chemistry', 0), ('Material resources', 0), ('Energy resources', 0), ('Practical skills', 0), ('Practical skills for carrying out a scientific investigation', 0)]
#
# States of matter
#
# [('States of matter', 2), ('Atomic structure', 1), ('Energy changes', 1), ('Energy, rates and reactions', 1), ('Combined Science', 0), ('Not related', 0), ('Building blocks', 0), ('Cells in animals and plants', 0), ('Transport into and out of cells', 0), ('Cell division', 0), ('Waves', 0), ('Transport over larger distances', 0), ('Respiration', 0), ('Exchange surfaces and transport systems', 0), ('The digestive system', 0), ('Coordination and control', 0), ('Plant organisation', 0), ('Photosynthesis', 0), ('Plant diseases', 0), ('Interactions with the environment', 0), ('Lifestyle and health', 0), ('Homeostasis', 0), ('Reproduction and fertility', 0), ('Radiation and risk', 0), ('Preventing, treating and curing diseases', 0), ('Explaining change', 0), ('The atmosphere', 0), ('Water', 0), ('Ecosystems and biodiversity', 0), ('Inheritance', 0), ('Evolution', 0), ('Building blocks for understanding', 0), ('The periodic table', 0), ('Groups in the periodic table', 0), ('Chemical equations', 0), ('Calculations in chemistry', 0), ('Interactions over small and large distances', 0), ('Forces', 0), ('Ionic compounds', 0), ('Covalent bonding', 0), ('Metals', 0), ('Magnetism and electromagnetism', 0), ('Movement and interactions', 0), ('Motion', 0), ("Newton's laws", 0), ('Circuits', 0), ('Mains electricity', 0), ('Acids and alkalis', 0), ('Rates of reaction', 0), ('Equilibria', 0), ('Electrons and chemical reactions', 0), ('Guiding Spaceship Earth towards a sustainable future', 0), ('Carbon chemistry', 0), ('Material resources', 0), ('Energy resources', 0), ('Practical skills', 0), ('Practical skills for carrying out a scientific investigation', 0)]
#
# States of matter
#
# [('States of matter', 4), ('Atomic structure', 1), ('Homeostasis', 1), ('Water', 1), ('Covalent bonding', 1), ('Metals', 1), ('Combined Science', 0), ('Not related', 0), ('Building blocks', 0), ('Cells in animals and plants', 0), ('Transport into and out of cells', 0), ('Cell division', 0), ('Waves', 0), ('Transport over larger distances', 0), ('Respiration', 0), ('Exchange surfaces and transport systems', 0), ('The digestive system', 0), ('Coordination and control', 0), ('Plant organisation', 0), ('Photosynthesis', 0), ('Plant diseases', 0), ('Interactions with the environment', 0), ('Lifestyle and health', 0), ('Reproduction and fertility', 0), ('Radiation and risk', 0), ('Preventing, treating and curing diseases', 0), ('Explaining change', 0), ('The atmosphere', 0), ('Ecosystems and biodiversity', 0), ('Inheritance', 0), ('Evolution', 0), ('Building blocks for understanding', 0), ('The periodic table', 0), ('Groups in the periodic table', 0), ('Chemical equations', 0), ('Calculations in chemistry', 0), ('Interactions over small and large distances', 0), ('Forces', 0), ('Energy changes', 0), ('Ionic compounds', 0), ('Magnetism and electromagnetism', 0), ('Movement and interactions', 0), ('Motion', 0), ("Newton's laws", 0), ('Circuits', 0), ('Mains electricity', 0), ('Acids and alkalis', 0), ('Rates of reaction', 0), ('Energy, rates and reactions', 0), ('Equilibria', 0), ('Electrons and chemical reactions', 0), ('Guiding Spaceship Earth towards a sustainable future', 0), ('Carbon chemistry', 0), ('Material resources', 0), ('Energy resources', 0), ('Practical skills', 0), ('Practical skills for carrying out a scientific investigation', 0)]
#
# States of matter
#
# [('Homeostasis', 1), ('Energy changes', 1), ('Energy, rates and reactions', 1), ('Combined Science', 0), ('Not related', 0), ('Building blocks', 0), ('States of matter', 0), ('Atomic structure', 0), ('Cells in animals and plants', 0), ('Transport into and out of cells', 0), ('Cell division', 0), ('Waves', 0), ('Transport over larger distances', 0), ('Respiration', 0), ('Exchange surfaces and transport systems', 0), ('The digestive system', 0), ('Coordination and control', 0), ('Plant organisation', 0), ('Photosynthesis', 0), ('Plant diseases', 0), ('Interactions with the environment', 0), ('Lifestyle and health', 0), ('Reproduction and fertility', 0), ('Radiation and risk', 0), ('Preventing, treating and curing diseases', 0), ('Explaining change', 0), ('The atmosphere', 0), ('Water', 0), ('Ecosystems and biodiversity', 0), ('Inheritance', 0), ('Evolution', 0), ('Building blocks for understanding', 0), ('The periodic table', 0), ('Groups in the periodic table', 0), ('Chemical equations', 0), ('Calculations in chemistry', 0), ('Interactions over small and large distances', 0), ('Forces', 0), ('Ionic compounds', 0), ('Covalent bonding', 0), ('Metals', 0), ('Magnetism and electromagnetism', 0), ('Movement and interactions', 0), ('Motion', 0), ("Newton's laws", 0), ('Circuits', 0), ('Mains electricity', 0), ('Acids and alkalis', 0), ('Rates of reaction', 0), ('Equilibria', 0), ('Electrons and chemical reactions', 0), ('Guiding Spaceship Earth towards a sustainable future', 0), ('Carbon chemistry', 0), ('Material resources', 0), ('Energy resources', 0), ('Practical skills', 0), ('Practical skills for carrying out a scientific investigation', 0)]
#
# Homeostasis
#
# [('Homeostasis', 1), ('Energy changes', 1), ('Energy, rates and reactions', 1), ('Combined Science', 0), ('Not related', 0), ('Building blocks', 0), ('States of matter', 0), ('Atomic structure', 0), ('Cells in animals and plants', 0), ('Transport into and out of cells', 0), ('Cell division', 0), ('Waves', 0), ('Transport over larger distances', 0), ('Respiration', 0), ('Exchange surfaces and transport systems', 0), ('The digestive system', 0), ('Coordination and control', 0), ('Plant organisation', 0), ('Photosynthesis', 0), ('Plant diseases', 0), ('Interactions with the environment', 0), ('Lifestyle and health', 0), ('Reproduction and fertility', 0), ('Radiation and risk', 0), ('Preventing, treating and curing diseases', 0), ('Explaining change', 0), ('The atmosphere', 0), ('Water', 0), ('Ecosystems and biodiversity', 0), ('Inheritance', 0), ('Evolution', 0), ('Building blocks for understanding', 0), ('The periodic table', 0), ('Groups in the periodic table', 0), ('Chemical equations', 0), ('Calculations in chemistry', 0), ('Interactions over small and large distances', 0), ('Forces', 0), ('Ionic compounds', 0), ('Covalent bonding', 0), ('Metals', 0), ('Magnetism and electromagnetism', 0), ('Movement and interactions', 0), ('Motion', 0), ("Newton's laws", 0), ('Circuits', 0), ('Mains electricity', 0), ('Acids and alkalis', 0), ('Rates of reaction', 0), ('Equilibria', 0), ('Electrons and chemical reactions', 0), ('Guiding Spaceship Earth towards a sustainable future', 0), ('Carbon chemistry', 0), ('Material resources', 0), ('Energy resources', 0), ('Practical skills', 0), ('Practical skills for carrying out a scientific investigation', 0)]
#
# Homeostasis
#
# [('Homeostasis', 1), ('Combined Science', 0), ('Not related', 0), ('Building blocks', 0), ('States of matter', 0), ('Atomic structure', 0), ('Cells in animals and plants', 0), ('Transport into and out of cells', 0), ('Cell division', 0), ('Waves', 0), ('Transport over larger distances', 0), ('Respiration', 0), ('Exchange surfaces and transport systems', 0), ('The digestive system', 0), ('Coordination and control', 0), ('Plant organisation', 0), ('Photosynthesis', 0), ('Plant diseases', 0), ('Interactions with the environment', 0), ('Lifestyle and health', 0), ('Reproduction and fertility', 0), ('Radiation and risk', 0), ('Preventing, treating and curing diseases', 0), ('Explaining change', 0), ('The atmosphere', 0), ('Water', 0), ('Ecosystems and biodiversity', 0), ('Inheritance', 0), ('Evolution', 0), ('Building blocks for understanding', 0), ('The periodic table', 0), ('Groups in the periodic table', 0), ('Chemical equations', 0), ('Calculations in chemistry', 0), ('Interactions over small and large distances', 0), ('Forces', 0), ('Energy changes', 0), ('Ionic compounds', 0), ('Covalent bonding', 0), ('Metals', 0), ('Magnetism and electromagnetism', 0), ('Movement and interactions', 0), ('Motion', 0), ("Newton's laws", 0), ('Circuits', 0), ('Mains electricity', 0), ('Acids and alkalis', 0), ('Rates of reaction', 0), ('Energy, rates and reactions', 0), ('Equilibria', 0), ('Electrons and chemical reactions', 0), ('Guiding Spaceship Earth towards a sustainable future', 0), ('Carbon chemistry', 0), ('Material resources', 0), ('Energy resources', 0), ('Practical skills', 0), ('Practical skills for carrying out a scientific investigation', 0)]
#
# Homeostasis
#
# [('Atomic structure', 3), ('States of matter', 1), ('Metals', 1), ('Combined Science', 0), ('Not related', 0), ('Building blocks', 0), ('Cells in animals and plants', 0), ('Transport into and out of cells', 0), ('Cell division', 0), ('Waves', 0), ('Transport over larger distances', 0), ('Respiration', 0), ('Exchange surfaces and transport systems', 0), ('The digestive system', 0), ('Coordination and control', 0), ('Plant organisation', 0), ('Photosynthesis', 0), ('Plant diseases', 0), ('Interactions with the environment', 0), ('Lifestyle and health', 0), ('Homeostasis', 0), ('Reproduction and fertility', 0), ('Radiation and risk', 0), ('Preventing, treating and curing diseases', 0), ('Explaining change', 0), ('The atmosphere', 0), ('Water', 0), ('Ecosystems and biodiversity', 0), ('Inheritance', 0), ('Evolution', 0), ('Building blocks for understanding', 0), ('The periodic table', 0), ('Groups in the periodic table', 0), ('Chemical equations', 0), ('Calculations in chemistry', 0), ('Interactions over small and large distances', 0), ('Forces', 0), ('Energy changes', 0), ('Ionic compounds', 0), ('Covalent bonding', 0), ('Magnetism and electromagnetism', 0), ('Movement and interactions', 0), ('Motion', 0), ("Newton's laws", 0), ('Circuits', 0), ('Mains electricity', 0), ('Acids and alkalis', 0), ('Rates of reaction', 0), ('Energy, rates and reactions', 0), ('Equilibria', 0), ('Electrons and chemical reactions', 0), ('Guiding Spaceship Earth towards a sustainable future', 0), ('Carbon chemistry', 0), ('Material resources', 0), ('Energy resources', 0), ('Practical skills', 0), ('Practical skills for carrying out a scientific investigation', 0)]
#
# Atomic structure
#
# [('Atomic structure', 6), ('States of matter', 2), ('Cells in animals and plants', 1), ('Exchange surfaces and transport systems', 1), ('Coordination and control', 1), ('Energy changes', 1), ('Ionic compounds', 1), ('Metals', 1), ('Combined Science', 0), ('Not related', 0), ('Building blocks', 0), ('Transport into and out of cells', 0), ('Cell division', 0), ('Waves', 0), ('Transport over larger distances', 0), ('Respiration', 0), ('The digestive system', 0), ('Plant organisation', 0), ('Photosynthesis', 0), ('Plant diseases', 0), ('Interactions with the environment', 0), ('Lifestyle and health', 0), ('Homeostasis', 0), ('Reproduction and fertility', 0), ('Radiation and risk', 0), ('Preventing, treating and curing diseases', 0), ('Explaining change', 0), ('The atmosphere', 0), ('Water', 0), ('Ecosystems and biodiversity', 0), ('Inheritance', 0), ('Evolution', 0), ('Building blocks for understanding', 0), ('The periodic table', 0), ('Groups in the periodic table', 0), ('Chemical equations', 0), ('Calculations in chemistry', 0), ('Interactions over small and large distances', 0), ('Forces', 0), ('Covalent bonding', 0), ('Magnetism and electromagnetism', 0), ('Movement and interactions', 0), ('Motion', 0), ("Newton's laws", 0), ('Circuits', 0), ('Mains electricity', 0), ('Acids and alkalis', 0), ('Rates of reaction', 0), ('Energy, rates and reactions', 0), ('Equilibria', 0), ('Electrons and chemical reactions', 0), ('Guiding Spaceship Earth towards a sustainable future', 0), ('Carbon chemistry', 0), ('Material resources', 0), ('Energy resources', 0), ('Practical skills', 0), ('Practical skills for carrying out a scientific investigation', 0)]
#
# Atomic structure
#
# [('Atomic structure', 5), ('States of matter', 1), ('The periodic table', 1), ('Energy changes', 1), ('Ionic compounds', 1), ('Metals', 1), ('Circuits', 1), ('Combined Science', 0), ('Not related', 0), ('Building blocks', 0), ('Cells in animals and plants', 0), ('Transport into and out of cells', 0), ('Cell division', 0), ('Waves', 0), ('Transport over larger distances', 0), ('Respiration', 0), ('Exchange surfaces and transport systems', 0), ('The digestive system', 0), ('Coordination and control', 0), ('Plant organisation', 0), ('Photosynthesis', 0), ('Plant diseases', 0), ('Interactions with the environment', 0), ('Lifestyle and health', 0), ('Homeostasis', 0), ('Reproduction and fertility', 0), ('Radiation and risk', 0), ('Preventing, treating and curing diseases', 0), ('Explaining change', 0), ('The atmosphere', 0), ('Water', 0), ('Ecosystems and biodiversity', 0), ('Inheritance', 0), ('Evolution', 0), ('Building blocks for understanding', 0), ('Groups in the periodic table', 0), ('Chemical equations', 0), ('Calculations in chemistry', 0), ('Interactions over small and large distances', 0), ('Forces', 0), ('Covalent bonding', 0), ('Magnetism and electromagnetism', 0), ('Movement and interactions', 0), ('Motion', 0), ("Newton's laws", 0), ('Mains electricity', 0), ('Acids and alkalis', 0), ('Rates of reaction', 0), ('Energy, rates and reactions', 0), ('Equilibria', 0), ('Electrons and chemical reactions', 0), ('Guiding Spaceship Earth towards a sustainable future', 0), ('Carbon chemistry', 0), ('Material resources', 0), ('Energy resources', 0), ('Practical skills', 0), ('Practical skills for carrying out a scientific investigation', 0)]
#
# Atomic structure
#
# [('Atomic structure', 6), ('The periodic table', 2), ('States of matter', 1), ('Energy changes', 1), ('Ionic compounds', 1), ('Metals', 1), ('Combined Science', 0), ('Not related', 0), ('Building blocks', 0), ('Cells in animals and plants', 0), ('Transport into and out of cells', 0), ('Cell division', 0), ('Waves', 0), ('Transport over larger distances', 0), ('Respiration', 0), ('Exchange surfaces and transport systems', 0), ('The digestive system', 0), ('Coordination and control', 0), ('Plant organisation', 0), ('Photosynthesis', 0), ('Plant diseases', 0), ('Interactions with the environment', 0), ('Lifestyle and health', 0), ('Homeostasis', 0), ('Reproduction and fertility', 0), ('Radiation and risk', 0), ('Preventing, treating and curing diseases', 0), ('Explaining change', 0), ('The atmosphere', 0), ('Water', 0), ('Ecosystems and biodiversity', 0), ('Inheritance', 0), ('Evolution', 0), ('Building blocks for understanding', 0), ('Groups in the periodic table', 0), ('Chemical equations', 0), ('Calculations in chemistry', 0), ('Interactions over small and large distances', 0), ('Forces', 0), ('Covalent bonding', 0), ('Magnetism and electromagnetism', 0), ('Movement and interactions', 0), ('Motion', 0), ("Newton's laws", 0), ('Circuits', 0), ('Mains electricity', 0), ('Acids and alkalis', 0), ('Rates of reaction', 0), ('Energy, rates and reactions', 0), ('Equilibria', 0), ('Electrons and chemical reactions', 0), ('Guiding Spaceship Earth towards a sustainable future', 0), ('Carbon chemistry', 0), ('Material resources', 0), ('Energy resources', 0), ('Practical skills', 0), ('Practical skills for carrying out a scientific investigation', 0)]
#
# Atomic structure
#
# [('Atomic structure', 3), ('Cells in animals and plants', 1), ('Exchange surfaces and transport systems', 1), ('Coordination and control', 1), ('Energy changes', 1), ('Metals', 1), ('Energy, rates and reactions', 1), ('Combined Science', 0), ('Not related', 0), ('Building blocks', 0), ('States of matter', 0), ('Transport into and out of cells', 0), ('Cell division', 0), ('Waves', 0), ('Transport over larger distances', 0), ('Respiration', 0), ('The digestive system', 0), ('Plant organisation', 0), ('Photosynthesis', 0), ('Plant diseases', 0), ('Interactions with the environment', 0), ('Lifestyle and health', 0), ('Homeostasis', 0), ('Reproduction and fertility', 0), ('Radiation and risk', 0), ('Preventing, treating and curing diseases', 0), ('Explaining change', 0), ('The atmosphere', 0), ('Water', 0), ('Ecosystems and biodiversity', 0), ('Inheritance', 0), ('Evolution', 0), ('Building blocks for understanding', 0), ('The periodic table', 0), ('Groups in the periodic table', 0), ('Chemical equations', 0), ('Calculations in chemistry', 0), ('Interactions over small and large distances', 0), ('Forces', 0), ('Ionic compounds', 0), ('Covalent bonding', 0), ('Magnetism and electromagnetism', 0), ('Movement and interactions', 0), ('Motion', 0), ("Newton's laws", 0), ('Circuits', 0), ('Mains electricity', 0), ('Acids and alkalis', 0), ('Rates of reaction', 0), ('Equilibria', 0), ('Electrons and chemical reactions', 0), ('Guiding Spaceship Earth towards a sustainable future', 0), ('Carbon chemistry', 0), ('Material resources', 0), ('Energy resources', 0), ('Practical skills', 0), ('Practical skills for carrying out a scientific investigation', 0)]
#
# Atomic structure
#
# [('Cells in animals and plants', 2), ('The periodic table', 1), ('Combined Science', 0), ('Not related', 0), ('Building blocks', 0), ('States of matter', 0), ('Atomic structure', 0), ('Transport into and out of cells', 0), ('Cell division', 0), ('Waves', 0), ('Transport over larger distances', 0), ('Respiration', 0), ('Exchange surfaces and transport systems', 0), ('The digestive system', 0), ('Coordination and control', 0), ('Plant organisation', 0), ('Photosynthesis', 0), ('Plant diseases', 0), ('Interactions with the environment', 0), ('Lifestyle and health', 0), ('Homeostasis', 0), ('Reproduction and fertility', 0), ('Radiation and risk', 0), ('Preventing, treating and curing diseases', 0), ('Explaining change', 0), ('The atmosphere', 0), ('Water', 0), ('Ecosystems and biodiversity', 0), ('Inheritance', 0), ('Evolution', 0), ('Building blocks for understanding', 0), ('Groups in the periodic table', 0), ('Chemical equations', 0), ('Calculations in chemistry', 0), ('Interactions over small and large distances', 0), ('Forces', 0), ('Energy changes', 0), ('Ionic compounds', 0), ('Covalent bonding', 0), ('Metals', 0), ('Magnetism and electromagnetism', 0), ('Movement and interactions', 0), ('Motion', 0), ("Newton's laws", 0), ('Circuits', 0), ('Mains electricity', 0), ('Acids and alkalis', 0), ('Rates of reaction', 0), ('Energy, rates and reactions', 0), ('Equilibria', 0), ('Electrons and chemical reactions', 0), ('Guiding Spaceship Earth towards a sustainable future', 0), ('Carbon chemistry', 0), ('Material resources', 0), ('Energy resources', 0), ('Practical skills', 0), ('Practical skills for carrying out a scientific investigation', 0)]
#
# Cells in animals and plants
#
# [('Cells in animals and plants', 2), ('Atomic structure', 1), ('Combined Science', 0), ('Not related', 0), ('Building blocks', 0), ('States of matter', 0), ('Transport into and out of cells', 0), ('Cell division', 0), ('Waves', 0), ('Transport over larger distances', 0), ('Respiration', 0), ('Exchange surfaces and transport systems', 0), ('The digestive system', 0), ('Coordination and control', 0), ('Plant organisation', 0), ('Photosynthesis', 0), ('Plant diseases', 0), ('Interactions with the environment', 0), ('Lifestyle and health', 0), ('Homeostasis', 0), ('Reproduction and fertility', 0), ('Radiation and risk', 0), ('Preventing, treating and curing diseases', 0), ('Explaining change', 0), ('The atmosphere', 0), ('Water', 0), ('Ecosystems and biodiversity', 0), ('Inheritance', 0), ('Evolution', 0), ('Building blocks for understanding', 0), ('The periodic table', 0), ('Groups in the periodic table', 0), ('Chemical equations', 0), ('Calculations in chemistry', 0), ('Interactions over small and large distances', 0), ('Forces', 0), ('Energy changes', 0), ('Ionic compounds', 0), ('Covalent bonding', 0), ('Metals', 0), ('Magnetism and electromagnetism', 0), ('Movement and interactions', 0), ('Motion', 0), ("Newton's laws", 0), ('Circuits', 0), ('Mains electricity', 0), ('Acids and alkalis', 0), ('Rates of reaction', 0), ('Energy, rates and reactions', 0), ('Equilibria', 0), ('Electrons and chemical reactions', 0), ('Guiding Spaceship Earth towards a sustainable future', 0), ('Carbon chemistry', 0), ('Material resources', 0), ('Energy resources', 0), ('Practical skills', 0), ('Practical skills for carrying out a scientific investigation', 0)]
#
# Cells in animals and plants
#
# [('Cells in animals and plants', 1), ('Respiration', 1), ('Combined Science', 0), ('Not related', 0), ('Building blocks', 0), ('States of matter', 0), ('Atomic structure', 0), ('Transport into and out of cells', 0), ('Cell division', 0), ('Waves', 0), ('Transport over larger distances', 0), ('Exchange surfaces and transport systems', 0), ('The digestive system', 0), ('Coordination and control', 0), ('Plant organisation', 0), ('Photosynthesis', 0), ('Plant diseases', 0), ('Interactions with the environment', 0), ('Lifestyle and health', 0), ('Homeostasis', 0), ('Reproduction and fertility', 0), ('Radiation and risk', 0), ('Preventing, treating and curing diseases', 0), ('Explaining change', 0), ('The atmosphere', 0), ('Water', 0), ('Ecosystems and biodiversity', 0), ('Inheritance', 0), ('Evolution', 0), ('Building blocks for understanding', 0), ('The periodic table', 0), ('Groups in the periodic table', 0), ('Chemical equations', 0), ('Calculations in chemistry', 0), ('Interactions over small and large distances', 0), ('Forces', 0), ('Energy changes', 0), ('Ionic compounds', 0), ('Covalent bonding', 0), ('Metals', 0), ('Magnetism and electromagnetism', 0), ('Movement and interactions', 0), ('Motion', 0), ("Newton's laws", 0), ('Circuits', 0), ('Mains electricity', 0), ('Acids and alkalis', 0), ('Rates of reaction', 0), ('Energy, rates and reactions', 0), ('Equilibria', 0), ('Electrons and chemical reactions', 0), ('Guiding Spaceship Earth towards a sustainable future', 0), ('Carbon chemistry', 0), ('Material resources', 0), ('Energy resources', 0), ('Practical skills', 0), ('Practical skills for carrying out a scientific investigation', 0)]
#
# Cells in animals and plants
#
# [('The digestive system', 1), ('Plant diseases', 1), ('Energy, rates and reactions', 1), ('Combined Science', 0), ('Not related', 0), ('Building blocks', 0), ('States of matter', 0), ('Atomic structure', 0), ('Cells in animals and plants', 0), ('Transport into and out of cells', 0), ('Cell division', 0), ('Waves', 0), ('Transport over larger distances', 0), ('Respiration', 0), ('Exchange surfaces and transport systems', 0), ('Coordination and control', 0), ('Plant organisation', 0), ('Photosynthesis', 0), ('Interactions with the environment', 0), ('Lifestyle and health', 0), ('Homeostasis', 0), ('Reproduction and fertility', 0), ('Radiation and risk', 0), ('Preventing, treating and curing diseases', 0), ('Explaining change', 0), ('The atmosphere', 0), ('Water', 0), ('Ecosystems and biodiversity', 0), ('Inheritance', 0), ('Evolution', 0), ('Building blocks for understanding', 0), ('The periodic table', 0), ('Groups in the periodic table', 0), ('Chemical equations', 0), ('Calculations in chemistry', 0), ('Interactions over small and large distances', 0), ('Forces', 0), ('Energy changes', 0), ('Ionic compounds', 0), ('Covalent bonding', 0), ('Metals', 0), ('Magnetism and electromagnetism', 0), ('Movement and interactions', 0), ('Motion', 0), ("Newton's laws", 0), ('Circuits', 0), ('Mains electricity', 0), ('Acids and alkalis', 0), ('Rates of reaction', 0), ('Equilibria', 0), ('Electrons and chemical reactions', 0), ('Guiding Spaceship Earth towards a sustainable future', 0), ('Carbon chemistry', 0), ('Material resources', 0), ('Energy resources', 0), ('Practical skills', 0), ('Practical skills for carrying out a scientific investigation', 0)]
#
# The digestive system
#
# [('Cells in animals and plants', 3), ('Transport into and out of cells', 2), ('Plant diseases', 2), ('Cell division', 1), ('Respiration', 1), ('Coordination and control', 1), ('Plant organisation', 1), ('Lifestyle and health', 1), ('Inheritance', 1), ('Combined Science', 0), ('Not related', 0), ('Building blocks', 0), ('States of matter', 0), ('Atomic structure', 0), ('Waves', 0), ('Transport over larger distances', 0), ('Exchange surfaces and transport systems', 0), ('The digestive system', 0), ('Photosynthesis', 0), ('Interactions with the environment', 0), ('Homeostasis', 0), ('Reproduction and fertility', 0), ('Radiation and risk', 0), ('Preventing, treating and curing diseases', 0), ('Explaining change', 0), ('The atmosphere', 0), ('Water', 0), ('Ecosystems and biodiversity', 0), ('Evolution', 0), ('Building blocks for understanding', 0), ('The periodic table', 0), ('Groups in the periodic table', 0), ('Chemical equations', 0), ('Calculations in chemistry', 0), ('Interactions over small and large distances', 0), ('Forces', 0), ('Energy changes', 0), ('Ionic compounds', 0), ('Covalent bonding', 0), ('Metals', 0), ('Magnetism and electromagnetism', 0), ('Movement and interactions', 0), ('Motion', 0), ("Newton's laws", 0), ('Circuits', 0), ('Mains electricity', 0), ('Acids and alkalis', 0), ('Rates of reaction', 0), ('Energy, rates and reactions', 0), ('Equilibria', 0), ('Electrons and chemical reactions', 0), ('Guiding Spaceship Earth towards a sustainable future', 0), ('Carbon chemistry', 0), ('Material resources', 0), ('Energy resources', 0), ('Practical skills', 0), ('Practical skills for carrying out a scientific investigation', 0)]
#
# Cells in animals and plants
#
# [('Cells in animals and plants', 1), ('Combined Science', 0), ('Not related', 0), ('Building blocks', 0), ('States of matter', 0), ('Atomic structure', 0), ('Transport into and out of cells', 0), ('Cell division', 0), ('Waves', 0), ('Transport over larger distances', 0), ('Respiration', 0), ('Exchange surfaces and transport systems', 0), ('The digestive system', 0), ('Coordination and control', 0), ('Plant organisation', 0), ('Photosynthesis', 0), ('Plant diseases', 0), ('Interactions with the environment', 0), ('Lifestyle and health', 0), ('Homeostasis', 0), ('Reproduction and fertility', 0), ('Radiation and risk', 0), ('Preventing, treating and curing diseases', 0), ('Explaining change', 0), ('The atmosphere', 0), ('Water', 0), ('Ecosystems and biodiversity', 0), ('Inheritance', 0), ('Evolution', 0), ('Building blocks for understanding', 0), ('The periodic table', 0), ('Groups in the periodic table', 0), ('Chemical equations', 0), ('Calculations in chemistry', 0), ('Interactions over small and large distances', 0), ('Forces', 0), ('Energy changes', 0), ('Ionic compounds', 0), ('Covalent bonding', 0), ('Metals', 0), ('Magnetism and electromagnetism', 0), ('Movement and interactions', 0), ('Motion', 0), ("Newton's laws", 0), ('Circuits', 0), ('Mains electricity', 0), ('Acids and alkalis', 0), ('Rates of reaction', 0), ('Energy, rates and reactions', 0), ('Equilibria', 0), ('Electrons and chemical reactions', 0), ('Guiding Spaceship Earth towards a sustainable future', 0), ('Carbon chemistry', 0), ('Material resources', 0), ('Energy resources', 0), ('Practical skills', 0), ('Practical skills for carrying out a scientific investigation', 0)]
#
# Cells in animals and plants
#
# [('Cells in animals and plants', 2), ('Motion', 1), ('Combined Science', 0), ('Not related', 0), ('Building blocks', 0), ('States of matter', 0), ('Atomic structure', 0), ('Transport into and out of cells', 0), ('Cell division', 0), ('Waves', 0), ('Transport over larger distances', 0), ('Respiration', 0), ('Exchange surfaces and transport systems', 0), ('The digestive system', 0), ('Coordination and control', 0), ('Plant organisation', 0), ('Photosynthesis', 0), ('Plant diseases', 0), ('Interactions with the environment', 0), ('Lifestyle and health', 0), ('Homeostasis', 0), ('Reproduction and fertility', 0), ('Radiation and risk', 0), ('Preventing, treating and curing diseases', 0), ('Explaining change', 0), ('The atmosphere', 0), ('Water', 0), ('Ecosystems and biodiversity', 0), ('Inheritance', 0), ('Evolution', 0), ('Building blocks for understanding', 0), ('The periodic table', 0), ('Groups in the periodic table', 0), ('Chemical equations', 0), ('Calculations in chemistry', 0), ('Interactions over small and large distances', 0), ('Forces', 0), ('Energy changes', 0), ('Ionic compounds', 0), ('Covalent bonding', 0), ('Metals', 0), ('Magnetism and electromagnetism', 0), ('Movement and interactions', 0), ("Newton's laws", 0), ('Circuits', 0), ('Mains electricity', 0), ('Acids and alkalis', 0), ('Rates of reaction', 0), ('Energy, rates and reactions', 0), ('Equilibria', 0), ('Electrons and chemical reactions', 0), ('Guiding Spaceship Earth towards a sustainable future', 0), ('Carbon chemistry', 0), ('Material resources', 0), ('Energy resources', 0), ('Practical skills', 0), ('Practical skills for carrying out a scientific investigation', 0)]
#
# Cells in animals and plants
#
# [('Combined Science', 0), ('Not related', 0), ('Building blocks', 0), ('States of matter', 0), ('Atomic structure', 0), ('Cells in animals and plants', 0), ('Transport into and out of cells', 0), ('Cell division', 0), ('Waves', 0), ('Transport over larger distances', 0), ('Respiration', 0), ('Exchange surfaces and transport systems', 0), ('The digestive system', 0), ('Coordination and control', 0), ('Plant organisation', 0), ('Photosynthesis', 0), ('Plant diseases', 0), ('Interactions with the environment', 0), ('Lifestyle and health', 0), ('Homeostasis', 0), ('Reproduction and fertility', 0), ('Radiation and risk', 0), ('Preventing, treating and curing diseases', 0), ('Explaining change', 0), ('The atmosphere', 0), ('Water', 0), ('Ecosystems and biodiversity', 0), ('Inheritance', 0), ('Evolution', 0), ('Building blocks for understanding', 0), ('The periodic table', 0), ('Groups in the periodic table', 0), ('Chemical equations', 0), ('Calculations in chemistry', 0), ('Interactions over small and large distances', 0), ('Forces', 0), ('Energy changes', 0), ('Ionic compounds', 0), ('Covalent bonding', 0), ('Metals', 0), ('Magnetism and electromagnetism', 0), ('Movement and interactions', 0), ('Motion', 0), ("Newton's laws", 0), ('Circuits', 0), ('Mains electricity', 0), ('Acids and alkalis', 0), ('Rates of reaction', 0), ('Energy, rates and reactions', 0), ('Equilibria', 0), ('Electrons and chemical reactions', 0), ('Guiding Spaceship Earth towards a sustainable future', 0), ('Carbon chemistry', 0), ('Material resources', 0), ('Energy resources', 0), ('Practical skills', 0), ('Practical skills for carrying out a scientific investigation', 0)]
#
# Combined Science
#
# [('Cells in animals and plants', 1), ('Combined Science', 0), ('Not related', 0), ('Building blocks', 0), ('States of matter', 0), ('Atomic structure', 0), ('Transport into and out of cells', 0), ('Cell division', 0), ('Waves', 0), ('Transport over larger distances', 0), ('Respiration', 0), ('Exchange surfaces and transport systems', 0), ('The digestive system', 0), ('Coordination and control', 0), ('Plant organisation', 0), ('Photosynthesis', 0), ('Plant diseases', 0), ('Interactions with the environment', 0), ('Lifestyle and health', 0), ('Homeostasis', 0), ('Reproduction and fertility', 0), ('Radiation and risk', 0), ('Preventing, treating and curing diseases', 0), ('Explaining change', 0), ('The atmosphere', 0), ('Water', 0), ('Ecosystems and biodiversity', 0), ('Inheritance', 0), ('Evolution', 0), ('Building blocks for understanding', 0), ('The periodic table', 0), ('Groups in the periodic table', 0), ('Chemical equations', 0), ('Calculations in chemistry', 0), ('Interactions over small and large distances', 0), ('Forces', 0), ('Energy changes', 0), ('Ionic compounds', 0), ('Covalent bonding', 0), ('Metals', 0), ('Magnetism and electromagnetism', 0), ('Movement and interactions', 0), ('Motion', 0), ("Newton's laws", 0), ('Circuits', 0), ('Mains electricity', 0), ('Acids and alkalis', 0), ('Rates of reaction', 0), ('Energy, rates and reactions', 0), ('Equilibria', 0), ('Electrons and chemical reactions', 0), ('Guiding Spaceship Earth towards a sustainable future', 0), ('Carbon chemistry', 0), ('Material resources', 0), ('Energy resources', 0), ('Practical skills', 0), ('Practical skills for carrying out a scientific investigation', 0)]
#
# Cells in animals and plants
#
# [('Forces', 1), ('Combined Science', 0), ('Not related', 0), ('Building blocks', 0), ('States of matter', 0), ('Atomic structure', 0), ('Cells in animals and plants', 0), ('Transport into and out of cells', 0), ('Cell division', 0), ('Waves', 0), ('Transport over larger distances', 0), ('Respiration', 0), ('Exchange surfaces and transport systems', 0), ('The digestive system', 0), ('Coordination and control', 0), ('Plant organisation', 0), ('Photosynthesis', 0), ('Plant diseases', 0), ('Interactions with the environment', 0), ('Lifestyle and health', 0), ('Homeostasis', 0), ('Reproduction and fertility', 0), ('Radiation and risk', 0), ('Preventing, treating and curing diseases', 0), ('Explaining change', 0), ('The atmosphere', 0), ('Water', 0), ('Ecosystems and biodiversity', 0), ('Inheritance', 0), ('Evolution', 0), ('Building blocks for understanding', 0), ('The periodic table', 0), ('Groups in the periodic table', 0), ('Chemical equations', 0), ('Calculations in chemistry', 0), ('Interactions over small and large distances', 0), ('Energy changes', 0), ('Ionic compounds', 0), ('Covalent bonding', 0), ('Metals', 0), ('Magnetism and electromagnetism', 0), ('Movement and interactions', 0), ('Motion', 0), ("Newton's laws", 0), ('Circuits', 0), ('Mains electricity', 0), ('Acids and alkalis', 0), ('Rates of reaction', 0), ('Energy, rates and reactions', 0), ('Equilibria', 0), ('Electrons and chemical reactions', 0), ('Guiding Spaceship Earth towards a sustainable future', 0), ('Carbon chemistry', 0), ('Material resources', 0), ('Energy resources', 0), ('Practical skills', 0), ('Practical skills for carrying out a scientific investigation', 0)]
#
# Forces
#
# [('States of matter', 3), ('Exchange surfaces and transport systems', 2), ('Atomic structure', 1), ('Transport into and out of cells', 1), ('The digestive system', 1), ('Water', 1), ('Calculations in chemistry', 1), ('Acids and alkalis', 1), ('Combined Science', 0), ('Not related', 0), ('Building blocks', 0), ('Cells in animals and plants', 0), ('Cell division', 0), ('Waves', 0), ('Transport over larger distances', 0), ('Respiration', 0), ('Coordination and control', 0), ('Plant organisation', 0), ('Photosynthesis', 0), ('Plant diseases', 0), ('Interactions with the environment', 0), ('Lifestyle and health', 0), ('Homeostasis', 0), ('Reproduction and fertility', 0), ('Radiation and risk', 0), ('Preventing, treating and curing diseases', 0), ('Explaining change', 0), ('The atmosphere', 0), ('Ecosystems and biodiversity', 0), ('Inheritance', 0), ('Evolution', 0), ('Building blocks for understanding', 0), ('The periodic table', 0), ('Groups in the periodic table', 0), ('Chemical equations', 0), ('Interactions over small and large distances', 0), ('Forces', 0), ('Energy changes', 0), ('Ionic compounds', 0), ('Covalent bonding', 0), ('Metals', 0), ('Magnetism and electromagnetism', 0), ('Movement and interactions', 0), ('Motion', 0), ("Newton's laws", 0), ('Circuits', 0), ('Mains electricity', 0), ('Rates of reaction', 0), ('Energy, rates and reactions', 0), ('Equilibria', 0), ('Electrons and chemical reactions', 0), ('Guiding Spaceship Earth towards a sustainable future', 0), ('Carbon chemistry', 0), ('Material resources', 0), ('Energy resources', 0), ('Practical skills', 0), ('Practical skills for carrying out a scientific investigation', 0)]
#
# States of matter
#
# [('States of matter', 1), ('Atomic structure', 1), ('Transport into and out of cells', 1), ('Exchange surfaces and transport systems', 1), ('Calculations in chemistry', 1), ('Acids and alkalis', 1), ('Energy, rates and reactions', 1), ('Combined Science', 0), ('Not related', 0), ('Building blocks', 0), ('Cells in animals and plants', 0), ('Cell division', 0), ('Waves', 0), ('Transport over larger distances', 0), ('Respiration', 0), ('The digestive system', 0), ('Coordination and control', 0), ('Plant organisation', 0), ('Photosynthesis', 0), ('Plant diseases', 0), ('Interactions with the environment', 0), ('Lifestyle and health', 0), ('Homeostasis', 0), ('Reproduction and fertility', 0), ('Radiation and risk', 0), ('Preventing, treating and curing diseases', 0), ('Explaining change', 0), ('The atmosphere', 0), ('Water', 0), ('Ecosystems and biodiversity', 0), ('Inheritance', 0), ('Evolution', 0), ('Building blocks for understanding', 0), ('The periodic table', 0), ('Groups in the periodic table', 0), ('Chemical equations', 0), ('Interactions over small and large distances', 0), ('Forces', 0), ('Energy changes', 0), ('Ionic compounds', 0), ('Covalent bonding', 0), ('Metals', 0), ('Magnetism and electromagnetism', 0), ('Movement and interactions', 0), ('Motion', 0), ("Newton's laws", 0), ('Circuits', 0), ('Mains electricity', 0), ('Rates of reaction', 0), ('Equilibria', 0), ('Electrons and chemical reactions', 0), ('Guiding Spaceship Earth towards a sustainable future', 0), ('Carbon chemistry', 0), ('Material resources', 0), ('Energy resources', 0), ('Practical skills', 0), ('Practical skills for carrying out a scientific investigation', 0)]
#
# States of matter
#
# [('Transport into and out of cells', 2), ('Calculations in chemistry', 2), ('States of matter', 1), ('Plant organisation', 1), ('Plant diseases', 1), ('Water', 1), ('Chemical equations', 1), ('Covalent bonding', 1), ('Acids and alkalis', 1), ('Combined Science', 0), ('Not related', 0), ('Building blocks', 0), ('Atomic structure', 0), ('Cells in animals and plants', 0), ('Cell division', 0), ('Waves', 0), ('Transport over larger distances', 0), ('Respiration', 0), ('Exchange surfaces and transport systems', 0), ('The digestive system', 0), ('Coordination and control', 0), ('Photosynthesis', 0), ('Interactions with the environment', 0), ('Lifestyle and health', 0), ('Homeostasis', 0), ('Reproduction and fertility', 0), ('Radiation and risk', 0), ('Preventing, treating and curing diseases', 0), ('Explaining change', 0), ('The atmosphere', 0), ('Ecosystems and biodiversity', 0), ('Inheritance', 0), ('Evolution', 0), ('Building blocks for understanding', 0), ('The periodic table', 0), ('Groups in the periodic table', 0), ('Interactions over small and large distances', 0), ('Forces', 0), ('Energy changes', 0), ('Ionic compounds', 0), ('Metals', 0), ('Magnetism and electromagnetism', 0), ('Movement and interactions', 0), ('Motion', 0), ("Newton's laws", 0), ('Circuits', 0), ('Mains electricity', 0), ('Rates of reaction', 0), ('Energy, rates and reactions', 0), ('Equilibria', 0), ('Electrons and chemical reactions', 0), ('Guiding Spaceship Earth towards a sustainable future', 0), ('Carbon chemistry', 0), ('Material resources', 0), ('Energy resources', 0), ('Practical skills', 0), ('Practical skills for carrying out a scientific investigation', 0)]
#
# Transport into and out of cells
#
# [('Calculations in chemistry', 2), ('Cells in animals and plants', 1), ('Transport into and out of cells', 1), ('Acids and alkalis', 1), ('Combined Science', 0), ('Not related', 0), ('Building blocks', 0), ('States of matter', 0), ('Atomic structure', 0), ('Cell division', 0), ('Waves', 0), ('Transport over larger distances', 0), ('Respiration', 0), ('Exchange surfaces and transport systems', 0), ('The digestive system', 0), ('Coordination and control', 0), ('Plant organisation', 0), ('Photosynthesis', 0), ('Plant diseases', 0), ('Interactions with the environment', 0), ('Lifestyle and health', 0), ('Homeostasis', 0), ('Reproduction and fertility', 0), ('Radiation and risk', 0), ('Preventing, treating and curing diseases', 0), ('Explaining change', 0), ('The atmosphere', 0), ('Water', 0), ('Ecosystems and biodiversity', 0), ('Inheritance', 0), ('Evolution', 0), ('Building blocks for understanding', 0), ('The periodic table', 0), ('Groups in the periodic table', 0), ('Chemical equations', 0), ('Interactions over small and large distances', 0), ('Forces', 0), ('Energy changes', 0), ('Ionic compounds', 0), ('Covalent bonding', 0), ('Metals', 0), ('Magnetism and electromagnetism', 0), ('Movement and interactions', 0), ('Motion', 0), ("Newton's laws", 0), ('Circuits', 0), ('Mains electricity', 0), ('Rates of reaction', 0), ('Energy, rates and reactions', 0), ('Equilibria', 0), ('Electrons and chemical reactions', 0), ('Guiding Spaceship Earth towards a sustainable future', 0), ('Carbon chemistry', 0), ('Material resources', 0), ('Energy resources', 0), ('Practical skills', 0), ('Practical skills for carrying out a scientific investigation', 0)]
#
# Calculations in chemistry
#
# ...
#
# Energy resources
#
# [('Forces', 1), ('Energy changes', 1), ("Newton's laws", 1), ('Energy, rates and reactions', 1), ('Combined Science', 0), ('Not related', 0), ('Building blocks', 0), ('States of matter', 0), ('Atomic structure', 0), ('Cells in animals and plants', 0), ('Transport into and out of cells', 0), ('Cell division', 0), ('Waves', 0), ('Transport over larger distances', 0), ('Respiration', 0), ('Exchange surfaces and transport systems', 0), ('The digestive system', 0), ('Coordination and control', 0), ('Plant organisation', 0), ('Photosynthesis', 0), ('Plant diseases', 0), ('Interactions with the environment', 0), ('Lifestyle and health', 0), ('Homeostasis', 0), ('Reproduction and fertility', 0), ('Radiation and risk', 0), ('Preventing, treating and curing diseases', 0), ('Explaining change', 0), ('The atmosphere', 0), ('Water', 0), ('Ecosystems and biodiversity', 0), ('Inheritance', 0), ('Evolution', 0), ('Building blocks for understanding', 0), ('The periodic table', 0), ('Groups in the periodic table', 0), ('Chemical equations', 0), ('Calculations in chemistry', 0), ('Interactions over small and large distances', 0), ('Ionic compounds', 0), ('Covalent bonding', 0), ('Metals', 0), ('Magnetism and electromagnetism', 0), ('Movement and interactions', 0), ('Motion', 0), ('Circuits', 0), ('Mains electricity', 0), ('Acids and alkalis', 0), ('Rates of reaction', 0), ('Equilibria', 0), ('Electrons and chemical reactions', 0), ('Guiding Spaceship Earth towards a sustainable future', 0), ('Carbon chemistry', 0), ('Material resources', 0), ('Energy resources', 0), ('Practical skills', 0), ('Practical skills for carrying out a scientific investigation', 0)]
#
# Forces
#
# [('Energy changes', 1), ('Energy, rates and reactions', 1), ('Combined Science', 0), ('Not related', 0), ('Building blocks', 0), ('States of matter', 0), ('Atomic structure', 0), ('Cells in animals and plants', 0), ('Transport into and out of cells', 0), ('Cell division', 0), ('Waves', 0), ('Transport over larger distances', 0), ('Respiration', 0), ('Exchange surfaces and transport systems', 0), ('The digestive system', 0), ('Coordination and control', 0), ('Plant organisation', 0), ('Photosynthesis', 0), ('Plant diseases', 0), ('Interactions with the environment', 0), ('Lifestyle and health', 0), ('Homeostasis', 0), ('Reproduction and fertility', 0), ('Radiation and risk', 0), ('Preventing, treating and curing diseases', 0), ('Explaining change', 0), ('The atmosphere', 0), ('Water', 0), ('Ecosystems and biodiversity', 0), ('Inheritance', 0), ('Evolution', 0), ('Building blocks for understanding', 0), ('The periodic table', 0), ('Groups in the periodic table', 0), ('Chemical equations', 0), ('Calculations in chemistry', 0), ('Interactions over small and large distances', 0), ('Forces', 0), ('Ionic compounds', 0), ('Covalent bonding', 0), ('Metals', 0), ('Magnetism and electromagnetism', 0), ('Movement and interactions', 0), ('Motion', 0), ("Newton's laws", 0), ('Circuits', 0), ('Mains electricity', 0), ('Acids and alkalis', 0), ('Rates of reaction', 0), ('Equilibria', 0), ('Electrons and chemical reactions', 0), ('Guiding Spaceship Earth towards a sustainable future', 0), ('Carbon chemistry', 0), ('Material resources', 0), ('Energy resources', 0), ('Practical skills', 0), ('Practical skills for carrying out a scientific investigation', 0)]
#
# Energy changes
#
# [('Forces', 1), ('Energy changes', 1), ("Newton's laws", 1), ('Energy, rates and reactions', 1), ('Combined Science', 0), ('Not related', 0), ('Building blocks', 0), ('States of matter', 0), ('Atomic structure', 0), ('Cells in animals and plants', 0), ('Transport into and out of cells', 0), ('Cell division', 0), ('Waves', 0), ('Transport over larger distances', 0), ('Respiration', 0), ('Exchange surfaces and transport systems', 0), ('The digestive system', 0), ('Coordination and control', 0), ('Plant organisation', 0), ('Photosynthesis', 0), ('Plant diseases', 0), ('Interactions with the environment', 0), ('Lifestyle and health', 0), ('Homeostasis', 0), ('Reproduction and fertility', 0), ('Radiation and risk', 0), ('Preventing, treating and curing diseases', 0), ('Explaining change', 0), ('The atmosphere', 0), ('Water', 0), ('Ecosystems and biodiversity', 0), ('Inheritance', 0), ('Evolution', 0), ('Building blocks for understanding', 0), ('The periodic table', 0), ('Groups in the periodic table', 0), ('Chemical equations', 0), ('Calculations in chemistry', 0), ('Interactions over small and large distances', 0), ('Ionic compounds', 0), ('Covalent bonding', 0), ('Metals', 0), ('Magnetism and electromagnetism', 0), ('Movement and interactions', 0), ('Motion', 0), ('Circuits', 0), ('Mains electricity', 0), ('Acids and alkalis', 0), ('Rates of reaction', 0), ('Equilibria', 0), ('Electrons and chemical reactions', 0), ('Guiding Spaceship Earth towards a sustainable future', 0), ('Carbon chemistry', 0), ('Material resources', 0), ('Energy resources', 0), ('Practical skills', 0), ('Practical skills for carrying out a scientific investigation', 0)]
#
# Forces
#
# [('Plant organisation', 1), ('Energy changes', 1), ('Energy, rates and reactions', 1), ('Combined Science', 0), ('Not related', 0), ('Building blocks', 0), ('States of matter', 0), ('Atomic structure', 0), ('Cells in animals and plants', 0), ('Transport into and out of cells', 0), ('Cell division', 0), ('Waves', 0), ('Transport over larger distances', 0), ('Respiration', 0), ('Exchange surfaces and transport systems', 0), ('The digestive system', 0), ('Coordination and control', 0), ('Photosynthesis', 0), ('Plant diseases', 0), ('Interactions with the environment', 0), ('Lifestyle and health', 0), ('Homeostasis', 0), ('Reproduction and fertility', 0), ('Radiation and risk', 0), ('Preventing, treating and curing diseases', 0), ('Explaining change', 0), ('The atmosphere', 0), ('Water', 0), ('Ecosystems and biodiversity', 0), ('Inheritance', 0), ('Evolution', 0), ('Building blocks for understanding', 0), ('The periodic table', 0), ('Groups in the periodic table', 0), ('Chemical equations', 0), ('Calculations in chemistry', 0), ('Interactions over small and large distances', 0), ('Forces', 0), ('Ionic compounds', 0), ('Covalent bonding', 0), ('Metals', 0), ('Magnetism and electromagnetism', 0), ('Movement and interactions', 0), ('Motion', 0), ("Newton's laws", 0), ('Circuits', 0), ('Mains electricity', 0), ('Acids and alkalis', 0), ('Rates of reaction', 0), ('Equilibria', 0), ('Electrons and chemical reactions', 0), ('Guiding Spaceship Earth towards a sustainable future', 0), ('Carbon chemistry', 0), ('Material resources', 0), ('Energy resources', 0), ('Practical skills', 0), ('Practical skills for carrying out a scientific investigation', 0)]
#
# Plant organisation
#
# [('Energy, rates and reactions', 2), ('Combined Science', 0), ('Not related', 0), ('Building blocks', 0), ('States of matter', 0), ('Atomic structure', 0), ('Cells in animals and plants', 0), ('Transport into and out of cells', 0), ('Cell division', 0), ('Waves', 0), ('Transport over larger distances', 0), ('Respiration', 0), ('Exchange surfaces and transport systems', 0), ('The digestive system', 0), ('Coordination and control', 0), ('Plant organisation', 0), ('Photosynthesis', 0), ('Plant diseases', 0), ('Interactions with the environment', 0), ('Lifestyle and health', 0), ('Homeostasis', 0), ('Reproduction and fertility', 0), ('Radiation and risk', 0), ('Preventing, treating and curing diseases', 0), ('Explaining change', 0), ('The atmosphere', 0), ('Water', 0), ('Ecosystems and biodiversity', 0), ('Inheritance', 0), ('Evolution', 0), ('Building blocks for understanding', 0), ('The periodic table', 0), ('Groups in the periodic table', 0), ('Chemical equations', 0), ('Calculations in chemistry', 0), ('Interactions over small and large distances', 0), ('Forces', 0), ('Energy changes', 0), ('Ionic compounds', 0), ('Covalent bonding', 0), ('Metals', 0), ('Magnetism and electromagnetism', 0), ('Movement and interactions', 0), ('Motion', 0), ("Newton's laws", 0), ('Circuits', 0), ('Mains electricity', 0), ('Acids and alkalis', 0), ('Rates of reaction', 0), ('Equilibria', 0), ('Electrons and chemical reactions', 0), ('Guiding Spaceship Earth towards a sustainable future', 0), ('Carbon chemistry', 0), ('Material resources', 0), ('Energy resources', 0), ('Practical skills', 0), ('Practical skills for carrying out a scientific investigation', 0)]
#
# Energy, rates and reactions
#
# [('States of matter', 1), ('Combined Science', 0), ('Not related', 0), ('Building blocks', 0), ('Atomic structure', 0), ('Cells in animals and plants', 0), ('Transport into and out of cells', 0), ('Cell division', 0), ('Waves', 0), ('Transport over larger distances', 0), ('Respiration', 0), ('Exchange surfaces and transport systems', 0), ('The digestive system', 0), ('Coordination and control', 0), ('Plant organisation', 0), ('Photosynthesis', 0), ('Plant diseases', 0), ('Interactions with the environment', 0), ('Lifestyle and health', 0), ('Homeostasis', 0), ('Reproduction and fertility', 0), ('Radiation and risk', 0), ('Preventing, treating and curing diseases', 0), ('Explaining change', 0), ('The atmosphere', 0), ('Water', 0), ('Ecosystems and biodiversity', 0), ('Inheritance', 0), ('Evolution', 0), ('Building blocks for understanding', 0), ('The periodic table', 0), ('Groups in the periodic table', 0), ('Chemical equations', 0), ('Calculations in chemistry', 0), ('Interactions over small and large distances', 0), ('Forces', 0), ('Energy changes', 0), ('Ionic compounds', 0), ('Covalent bonding', 0), ('Metals', 0), ('Magnetism and electromagnetism', 0), ('Movement and interactions', 0), ('Motion', 0), ("Newton's laws", 0), ('Circuits', 0), ('Mains electricity', 0), ('Acids and alkalis', 0), ('Rates of reaction', 0), ('Energy, rates and reactions', 0), ('Equilibria', 0), ('Electrons and chemical reactions', 0), ('Guiding Spaceship Earth towards a sustainable future', 0), ('Carbon chemistry', 0), ('Material resources', 0), ('Energy resources', 0), ('Practical skills', 0), ('Practical skills for carrying out a scientific investigation', 0)]
#
# States of matter
#
# [('States of matter', 1), ('Energy changes', 1), ('Motion', 1), ('Energy, rates and reactions', 1), ('Practical skills for carrying out a scientific investigation', 1), ('Combined Science', 0), ('Not related', 0), ('Building blocks', 0), ('Atomic structure', 0), ('Cells in animals and plants', 0), ('Transport into and out of cells', 0), ('Cell division', 0), ('Waves', 0), ('Transport over larger distances', 0), ('Respiration', 0), ('Exchange surfaces and transport systems', 0), ('The digestive system', 0), ('Coordination and control', 0), ('Plant organisation', 0), ('Photosynthesis', 0), ('Plant diseases', 0), ('Interactions with the environment', 0), ('Lifestyle and health', 0), ('Homeostasis', 0), ('Reproduction and fertility', 0), ('Radiation and risk', 0), ('Preventing, treating and curing diseases', 0), ('Explaining change', 0), ('The atmosphere', 0), ('Water', 0), ('Ecosystems and biodiversity', 0), ('Inheritance', 0), ('Evolution', 0), ('Building blocks for understanding', 0), ('The periodic table', 0), ('Groups in the periodic table', 0), ('Chemical equations', 0), ('Calculations in chemistry', 0), ('Interactions over small and large distances', 0), ('Forces', 0), ('Ionic compounds', 0), ('Covalent bonding', 0), ('Metals', 0), ('Magnetism and electromagnetism', 0), ('Movement and interactions', 0), ("Newton's laws", 0), ('Circuits', 0), ('Mains electricity', 0), ('Acids and alkalis', 0), ('Rates of reaction', 0), ('Equilibria', 0), ('Electrons and chemical reactions', 0), ('Guiding Spaceship Earth towards a sustainable future', 0), ('Carbon chemistry', 0), ('Material resources', 0), ('Energy resources', 0), ('Practical skills', 0)]
#
# States of matter
#
# [('Combined Science', 0), ('Not related', 0), ('Building blocks', 0), ('States of matter', 0), ('Atomic structure', 0), ('Cells in animals and plants', 0), ('Transport into and out of cells', 0), ('Cell division', 0), ('Waves', 0), ('Transport over larger distances', 0), ('Respiration', 0), ('Exchange surfaces and transport systems', 0), ('The digestive system', 0), ('Coordination and control', 0), ('Plant organisation', 0), ('Photosynthesis', 0), ('Plant diseases', 0), ('Interactions with the environment', 0), ('Lifestyle and health', 0), ('Homeostasis', 0), ('Reproduction and fertility', 0), ('Radiation and risk', 0), ('Preventing, treating and curing diseases', 0), ('Explaining change', 0), ('The atmosphere', 0), ('Water', 0), ('Ecosystems and biodiversity', 0), ('Inheritance', 0), ('Evolution', 0), ('Building blocks for understanding', 0), ('The periodic table', 0), ('Groups in the periodic table', 0), ('Chemical equations', 0), ('Calculations in chemistry', 0), ('Interactions over small and large distances', 0), ('Forces', 0), ('Energy changes', 0), ('Ionic compounds', 0), ('Covalent bonding', 0), ('Metals', 0), ('Magnetism and electromagnetism', 0), ('Movement and interactions', 0), ('Motion', 0), ("Newton's laws", 0), ('Circuits', 0), ('Mains electricity', 0), ('Acids and alkalis', 0), ('Rates of reaction', 0), ('Energy, rates and reactions', 0), ('Equilibria', 0), ('Electrons and chemical reactions', 0), ('Guiding Spaceship Earth towards a sustainable future', 0), ('Carbon chemistry', 0), ('Material resources', 0), ('Energy resources', 0), ('Practical skills', 0), ('Practical skills for carrying out a scientific investigation', 0)]
#
# Combined Science
#
# [('Combined Science', 0), ('Not related', 0), ('Building blocks', 0), ('States of matter', 0), ('Atomic structure', 0), ('Cells in animals and plants', 0), ('Transport into and out of cells', 0), ('Cell division', 0), ('Waves', 0), ('Transport over larger distances', 0), ('Respiration', 0), ('Exchange surfaces and transport systems', 0), ('The digestive system', 0), ('Coordination and control', 0), ('Plant organisation', 0), ('Photosynthesis', 0), ('Plant diseases', 0), ('Interactions with the environment', 0), ('Lifestyle and health', 0), ('Homeostasis', 0), ('Reproduction and fertility', 0), ('Radiation and risk', 0), ('Preventing, treating and curing diseases', 0), ('Explaining change', 0), ('The atmosphere', 0), ('Water', 0), ('Ecosystems and biodiversity', 0), ('Inheritance', 0), ('Evolution', 0), ('Building blocks for understanding', 0), ('The periodic table', 0), ('Groups in the periodic table', 0), ('Chemical equations', 0), ('Calculations in chemistry', 0), ('Interactions over small and large distances', 0), ('Forces', 0), ('Energy changes', 0), ('Ionic compounds', 0), ('Covalent bonding', 0), ('Metals', 0), ('Magnetism and electromagnetism', 0), ('Movement and interactions', 0), ('Motion', 0), ("Newton's laws", 0), ('Circuits', 0), ('Mains electricity', 0), ('Acids and alkalis', 0), ('Rates of reaction', 0), ('Energy, rates and reactions', 0), ('Equilibria', 0), ('Electrons and chemical reactions', 0), ('Guiding Spaceship Earth towards a sustainable future', 0), ('Carbon chemistry', 0), ('Material resources', 0), ('Energy resources', 0), ('Practical skills', 0), ('Practical skills for carrying out a scientific investigation', 0)]
#
# Combined Science
