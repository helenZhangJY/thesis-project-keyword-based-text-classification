# %%
import pandas as pd
import re, os, string
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score, average_precision_score,precision_score,f1_score,recall_score
import spacy

# %%
nlp_nl = spacy.load('nl_core_news_sm')

# %%
def clean_text(text):
    """Doc cleaning"""
    
    # Lowering text
    text = text.lower()
    
    # Removing punctuation
    text = "".join([c for c in text if c not in PUNCTUATION])
    
    # Removing whitespace and newlines
    text = re.sub('\s+',' ',text)
    
    # extract Noun
    noun_words = []
    for token in nlp_nl(text):
        taged_w = token.pos_
        if taged_w == 'NOUN':
            noun_words.append(token.lemma_)
            text = ' '.join(noun_words)
    
    return text

# %%
def get_stopwords_list(stop_file_path):
    """load stop words """
    
    with open(stop_file_path, 'r', encoding="utf-8") as f:
        stopwords = f.readlines()
        stop_set = set(m.strip() for m in stopwords)
        return list(frozenset(stop_set))

# %%
def sort_coo(coo_matrix):
    """Sort a dict with highest score"""
    tuples = zip(coo_matrix.col, coo_matrix.data)
    return sorted(tuples, key=lambda x: (x[1], x[0]), reverse=True)

def extract_topn_from_vector(feature_names, sorted_items, topn=10):
    """get the feature names and tf-idf score of top n items"""
    
    #use only topn items from vector
    sorted_items = sorted_items[:topn]

    score_vals = []
    feature_vals = []
    
    # word index and corresponding tf-idf score
    for idx, score in sorted_items:
        
        #keep track of feature name and its corresponding score
        score_vals.append(round(score, 3))
        feature_vals.append(feature_names[idx])

    #create a tuples of feature, score
    results= {}
    for idx in range(len(feature_vals)):
        results[feature_vals[idx]]=score_vals[idx]
    
    return results

# %%
def get_keywords(vectorizer, feature_names, doc):
    """Return top k keywords from a doc using TF-IDF method"""

    #generate tf-idf for the given document
    tf_idf_vector = vectorizer.transform([doc])
    
    #sort the tf-idf vectors by descending order of scores
    sorted_items=sort_coo(tf_idf_vector.tocoo())

    #extract only TOP_K_KEYWORDS
    keywords=extract_topn_from_vector(feature_names,sorted_items,TOP_K_KEYWORDS)
    
    return list(keywords.keys())

# %%
# Constants
PUNCTUATION = """!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~""" 
TOP_K_KEYWORDS = 10 # top k number of keywords to retrieve in a ranked document
STOPWORD_PATH = "../data/stopwords/nl_stopwords_list.txt"
PAPERS_PATH = "../data/test_data.csv"

# %%
data = pd.read_csv(PAPERS_PATH,encoding="unicode_escape")
data.head()
# Out:
#                           title         chapter  \
# 0  Library Guide Google scholar  Google scholar
# 1  Library Guide Healthy Ageing  Healthy Ageing
# 2        Library Guide Refworks         Reforks
# 3             Outreach de focus  Hoe wat waarom
# 4       Hoe herken je fake news             NaN
#
#                                              content  \
# 0  Wat is Google Scholar?\nGoogle Scholar biedt e...
# 1  Systematisch zoeken\nIn deze library guide kri...
# 2  Wat is RefWorks?\nBeheer en verwerk je bronnen...
# 3  Na het voltooien van je scriptie, hoeft het we...
# 4  en heel erg om de nieuws uit met name rusland ...
#
#                                          gold_label  \
# 0      Selecteren informatiebronnen en zoeksystemen
# 1                                 Plannen en zoeken
# 2                  Managen proces en zoekresultaten
# 3            Valoriseren van bevindingen (outreach)
# 4  Beoordelingscriteria relevantie/ betrouwbaarheid
#
#                                        bl_label  \
# 0  Selecteren informatiebronnen en zoeksystemen
# 1                        Informatievaardigheden
# 2               Manage proces en zoekresultaten
# 3        Valoriseren van bevindingen (outreach)
# 4          Beoordelen van resultaten (kritisch)
#
#                                          w2v_label
# 0  Aard en verschijningsvormen van informatie/data
# 1                  Manage proces en zoekresultaten
# 2                  Manage proces en zoekresultaten
# 3                       Waarde van informatie/data
# 4             Beoordelen van resultaten (kritisch)

# %%
data.dropna(subset=['content'], inplace=True)

# %%
data['content'] = data['content'].apply(clean_text)
data.head()
# Out:
#                           title         chapter  \
# 0  Library Guide Google scholar  Google scholar
# 1  Library Guide Healthy Ageing  Healthy Ageing
# 2        Library Guide Refworks         Reforks
# 3             Outreach de focus  Hoe wat waarom
# 4       Hoe herken je fake news             NaN
#
#                                              content  \
# 0  manier lijn literatuur plek discipline bron ar...
# 1  uitleg aanpak gebied ageing tabblad zoekstrate...
# 2  beheer verwerken refwork refwork citatie logbo...
# 3  scriptie proces einde wetenschap rapporter ond...
# 4  nieuws naam democratie muziek koning mens inte...
#
#                                          gold_label  \
# 0      Selecteren informatiebronnen en zoeksystemen
# 1                                 Plannen en zoeken
# 2                  Managen proces en zoekresultaten
# 3            Valoriseren van bevindingen (outreach)
# 4  Beoordelingscriteria relevantie/ betrouwbaarheid
#
#                                        bl_label  \
# 0  Selecteren informatiebronnen en zoeksystemen
# 1                        Informatievaardigheden
# 2               Manage proces en zoekresultaten
# 3        Valoriseren van bevindingen (outreach)
# 4          Beoordelen van resultaten (kritisch)
#
#                                          w2v_label
# 0  Aard en verschijningsvormen van informatie/data
# 1                  Manage proces en zoekresultaten
# 2                  Manage proces en zoekresultaten
# 3                       Waarde van informatie/data
# 4             Beoordelen van resultaten (kritisch)

# %%
corpora = data['content'].to_list()

# %%
#load a set of stop words
stopwords=get_stopwords_list(STOPWORD_PATH)

# Initializing TF-IDF Vectorizer with stopwords
vectorizer = TfidfVectorizer(ngram_range=(1,1),stop_words=stopwords, smooth_idf=True, use_idf=True)

# Creating vocab with our corpora
vectorizer.fit_transform(corpora)

# Storing vocab
feature_names = vectorizer.get_feature_names()

# %%
result = [] #a list of dictionary, key is 'top_keywords', value is list of keywords
for doc in corpora:
    df = {}
    #df['full_text'] = doc
    df['top_keywords'] = get_keywords(vectorizer, feature_names, doc)
    result.append(df)


final = pd.DataFrame(result)
final
# Out:
#                                          top_keywords
# 0   [schouder, reus, literatuur, document, plek, c...
# 1   [zoekstrategie, uitleg, tabblad, literatuurond...
# 2   [citatie, referentie, toevoeg, refwork, logboe...
# 3   [kennis, publiek, maatschappij, doelgroep, die...
# 4   [nieuws, bericht, verkiezing, leven, intentie,...
# 5   [search, mesh, subject, querie, filter, zoekop...
# 6   [informatie, vraag, waarde, proces, kanaal, fa...
# 7   [afbeelding, plaat, toestemming, licentie, rec...
# 8   [foto, film, maker, kunstwerk, toestemming, af...
# 9   [zoekbalk, optie, zoekresultaat, motivatie, le...
# 10  [industrie, hotel, airbnb, catalogus, woord, z...
# 11  [koffie, invloed, deelvrag, onderzoeksonderwer...
# 12  [drank, koffie, hyponiem, zoekterm, student, o...
# 13  [informatie, internet, catalogus, database, br...
# 14  [zoekterm, koffie, consumptie, student, filety...
# 15  [bron, punt, overheid, ding, autoriteit, menin...
# 16  [bron, atema, achternaam, citatie, auteur, bro...
# 17  [verslag, bedrijfsgegeven, persoon, informatie...
# 18  [jans, stijl, inwoner, criminaliteit, citatie,...
# 19  [verwijzing, lijst, referentie, stijl, bibliot...
# 20  [informatie, obesitas, boek, artikel, vraag, u...
# 21  [kop, einde, conclusie, tekst, hoofdstuk, arti...
# 22  [melding, scholar, filter, google, zoekopdrach...
# 23  [informatie, mening, vraag, bron, datum, auteu...
# 24  [bron, informatie, catalogus, verwijzing, soor...
# 25  [autoriteit, bruikbaarheid, werkstuk, houding,...
# 26  [richtlijn, volstaan, verwerk, bod, betrekking...
# 27  [zoekvraag, punt, resultaat, informatiebron, z...
# 28  [jans, stijl, inwoner, criminaliteit, citatie,...
# 29  [schermafbeelding, libguide, universiteit, voo...
# 30  [informatie, herkomst, uitgever, site, web, br...
# 31  [publicatie, boek, literatuurverwijzing, weten...
# 32  [onderzoek, bron, taal, materiaal, gebied, mus...
# 33  [operator, woord, zoekoperator, wildcard, teke...
# 34  [referentie, boek, hoofdstuk, titel, type, tij...
# 35  [boek, ebook, librarie, titel, artikel, refere...
# 36  [collectie, dissertatie, zoekmogelijkheid, scr...
# 37  [schermafbeelding, libguide, universiteit, voo...
# 38  [informatie, herkomst, uitgever, site, web, br...
# 39  [publicatie, boek, literatuurverwijzing, weten...
# 40  [rechtsbron, wet, uitspraak, rechtsorde, juris...
# 41  [operator, woord, zoekoperator, wildcard, teke...
# 42  [referentie, boek, hoofdstuk, titel, type, tij...
# 43  [boek, ebook, librarie, titel, artikel, refere...
# 44  [zoeklicht, informatie, onderbouwing, gericht,...
# 45  [thesaurus, term, onderwijs, zoekterm, vakblad...
# 46  [tijdschrift, niveau, bron, databank, vaktijds...
# 47  [werk, cclicentie, informatie, licentie, bouws...
# 48  [cursus, informatie, manier, logboek, zoeklogb...
# 49  [zoekterm, hulpmiddel, woordenboek, element, g...
# 50  [informatie, databank, soort, informatiebron, ...
# 51  [zoekfilter, zoekveld, stad, zoekresultaat, pu...
# 52  [website, criterium, betrouwbaarheid, relevant...
# 53  [verslag, citatiestijl, apastijl, auteursrecht...

# %%
text_keyword=[]
for item in result:
    text_keyword.append(item['top_keywords'])
print(text_keyword[:5])
# Out:
# [['schouder', 'reus', 'literatuur', 'document', 'plek', 'collectie', 'onderzoeker', 'vereniging', 'repositorie', 'opinie'], ['zoekstrategie', 'uitleg', 'tabblad', 'literatuuronderzoek', 'onderdeel', 'beoordeel', 'pagina', 'zoektechniek', 'zoekmethode', 'subpagina'], ['citatie', 'referentie', 'toevoeg', 'refwork', 'logboek', 'worddocument', 'verwerken', 'procesmanagement', 'kopie', 'folder'], ['kennis', 'publiek', 'maatschappij', 'doelgroep', 'dienst', 'einde', 'resultaat', 'onderzoek', 'writing', 'weg'], ['nieuws', 'bericht', 'verkiezing', 'leven', 'intentie', 'beslissing', 'arno', 'tijd', 'muziek', 'mens']]

# %%
# read taxonomy
import pickle
with open('../data/LO_picklefile/surf.pickle','rb') as pickle_file:
    los = pickle.load(pickle_file)

# %%
extracted_key_value_from_dict = []
for item in los:
    key_to_extract = {'name','keywords'}
    extracted_dict = {key: item[key] for key in item.keys()
                               & key_to_extract}
    extracted_key_value_from_dict.append(extracted_dict)

# %%
from gensim.models import KeyedVectors
print("loading")
word2vec_model  = KeyedVectors.load_word2vec_format("/Users/zjy/Desktop/EDIA intern/code/w2v_model/cc.nl.300.vec")
print("done loading")
# Out:
# loading
# done loading

# %%
import numpy as np

# A function that takes a sentence as a list of tokens and returns the mean vector for a given model
def get_sentence_vector(sentence, model): 
    word_vectors =[]
    for word in sentence: 
        # Ignore words that are not in the vocabulary
        try: 
            index = model.key_to_index[word]
            word_vectors.append(model.get_vector(word))
        except:
            continue
    
    word_matrix = np.asarray(word_vectors)
    mean_vector = np.mean(word_matrix, axis=0)
    sum_vector = np.sum(word_matrix, axis=0)

    return mean_vector, sum_vector

# %%
def classify_text(text_kws, los):
    """classify text by counting the overlapping keywords between text and taxonomy
       text_kws: list of lists, keywords extracted from text
       los: list of dicts, keywords of learning objectives
    """
    from scipy.spatial import distance
    rv = []
    for ks in text_kws:
        #initialize the value of lo['name']
        scores = {lo['name']: 0 for lo in los}
        vector1 = get_sentence_vector(ks, word2vec_model)[0]
        for lo in los:
            #create a set to collect cleaned value of dictionary
            cl=set()
            for kw in lo['keywords']:
                # clean up the value of dictionary
                cw = kw.lower().replace('_',' ')
#                 for i in nlp_nl(cw):
                cl.add(cw)
            
            if cl:
                vector2 = get_sentence_vector(cl, word2vec_model)[0]
                scores[lo['name']] = 1- distance.cosine(vector1,vector2)
            
        rv.append(scores)
            
    return rv

# %%
text_kws = text_keyword
los = extracted_key_value_from_dict
classified=classify_text(text_kws, los)
# Out:
# /Users/zjy/opt/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/zjy/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
#sort dictionary by the number of overlapping keywords, from high to low
#def sort_dict(classify_text):
for dic in classified:
    x=sorted(dic.items(), key=lambda dic:dic[1], reverse=True)
    print(x)
    print()
    print(x[0][0])
    print()
# Out:
# [('Zoeken ter oriëntatie', 0.6533944010734558), ('Kritisch beoordelen', nan), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 0.6874606013298035), ('Aard en verschijningsvormen van informatie/data', 0.6791712045669556), ('Waarde van informatie/data', 0.6546018123626709), ('Beoordelen van resultaten (kritisch)', 0.6287640929222107), ('Valoriseren van bevindingen (outreach)', 0.6248579621315002), ('Publiceren (van eindproduct)', 0.5950257778167725), ('Samenwerken (in teams)', 0.5879917144775391), ('Synthetiseren of creëren van nieuwe informatie', 0.5835874676704407), ('Communiceren (van eindproduct)', 0.5758397579193115), ('Selecteren informatiebronnen en zoeksystemen', 0.5680572986602783), ('Informatieverwerking (lezen, luisteren e.d.)', 0.5451504588127136), ('Manage proces en zoekresultaten', 0.5294864773750305), ('Formuleren van onderzoeksvraag', 0.5220149159431458), ('Werking en structuur van het internet', 0.5183538198471069), ('Identificeren van informatiebehoefte', 0.5175941586494446), ('Analyseren van zoekresultaten (informatieanalyse)', 0.5116521120071411), ('Privacygevoelige informatie', 0.5113664269447327), ('Selecteren zoektermen', 0.5002055764198303), ('Individu in het informatielandschap', 0.48417922854423523), ('Zoeken naar informatie', 0.4791993498802185), ('Auteursrecht', 0.4732106029987335), ('Evalueren van zoekproces (kritisch)', 0.47184059023857117), ('Bronvermelding', 0.4503192603588104), ('Rol en totstandkoming van netwerken', 0.4429361820220947), ('Gebruik en verwerken van informatie (ethisch)', 0.34985148906707764), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Plannen en zoeken', 0), ('Organiseren en verwerken', 0), ('Publiceren en communiceren', 0)]
#
# Zoeken ter oriëntatie
#
# [('Aard en verschijningsvormen van informatie/data', 0.7035737633705139), ('Zoeken ter oriëntatie', 0.7015700936317444), ('Selecteren informatiebronnen en zoeksystemen', 0.6726576685905457), ('Kritisch beoordelen', nan), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 0.6698370575904846), ('Manage proces en zoekresultaten', 0.6665121912956238), ('Analyseren van zoekresultaten (informatieanalyse)', 0.6626582741737366), ('Communiceren (van eindproduct)', 0.6568635702133179), ('Synthetiseren of creëren van nieuwe informatie', 0.6538705229759216), ('Beoordelen van resultaten (kritisch)', 0.647893488407135), ('Zoeken naar informatie', 0.646996021270752), ('Valoriseren van bevindingen (outreach)', 0.6399300694465637), ('Publiceren (van eindproduct)', 0.6270207166671753), ('Selecteren zoektermen', 0.6245357990264893), ('Werking en structuur van het internet', 0.6000736355781555), ('Identificeren van informatiebehoefte', 0.5687206983566284), ('Evalueren van zoekproces (kritisch)', 0.5664985179901123), ('Waarde van informatie/data', 0.5628712773323059), ('Samenwerken (in teams)', 0.556127667427063), ('Bronvermelding', 0.5288088917732239), ('Formuleren van onderzoeksvraag', 0.5251643061637878), ('Rol en totstandkoming van netwerken', 0.48002201318740845), ('Privacygevoelige informatie', 0.4501541256904602), ('Informatieverwerking (lezen, luisteren e.d.)', 0.4290841817855835), ('Individu in het informatielandschap', 0.410742849111557), ('Auteursrecht', 0.3791709840297699), ('Gebruik en verwerken van informatie (ethisch)', 0.2743297517299652), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Plannen en zoeken', 0), ('Organiseren en verwerken', 0), ('Publiceren en communiceren', 0)]
#
# Aard en verschijningsvormen van informatie/data
#
# [('Zoeken ter oriëntatie', 0.7257831692695618), ('Kritisch beoordelen', nan), ('Manage proces en zoekresultaten', 0.7232936024665833), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 0.7207149863243103), ('Aard en verschijningsvormen van informatie/data', 0.7202239036560059), ('Publiceren (van eindproduct)', 0.6653467416763306), ('Selecteren informatiebronnen en zoeksystemen', 0.6629576683044434), ('Synthetiseren of creëren van nieuwe informatie', 0.6402992010116577), ('Beoordelen van resultaten (kritisch)', 0.6367626190185547), ('Bronvermelding', 0.6087958216667175), ('Evalueren van zoekproces (kritisch)', 0.600849986076355), ('Valoriseren van bevindingen (outreach)', 0.5905722975730896), ('Communiceren (van eindproduct)', 0.5900892615318298), ('Zoeken naar informatie', 0.5891469120979309), ('Waarde van informatie/data', 0.5871490240097046), ('Selecteren zoektermen', 0.5769447088241577), ('Werking en structuur van het internet', 0.5553363561630249), ('Analyseren van zoekresultaten (informatieanalyse)', 0.5410869121551514), ('Identificeren van informatiebehoefte', 0.5359439253807068), ('Formuleren van onderzoeksvraag', 0.5241205096244812), ('Samenwerken (in teams)', 0.5060310959815979), ('Privacygevoelige informatie', 0.4761623740196228), ('Rol en totstandkoming van netwerken', 0.47228825092315674), ('Individu in het informatielandschap', 0.4433276057243347), ('Auteursrecht', 0.43127864599227905), ('Informatieverwerking (lezen, luisteren e.d.)', 0.4199027121067047), ('Gebruik en verwerken van informatie (ethisch)', 0.2461262345314026), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Plannen en zoeken', 0), ('Organiseren en verwerken', 0), ('Publiceren en communiceren', 0)]
#
# Zoeken ter oriëntatie
#
# [('Waarde van informatie/data', 0.7187680602073669), ('Kritisch beoordelen', nan), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 0.6937030553817749), ('Beoordelen van resultaten (kritisch)', 0.6798762679100037), ('Valoriseren van bevindingen (outreach)', 0.6688038110733032), ('Aard en verschijningsvormen van informatie/data', 0.664902925491333), ('Synthetiseren of creëren van nieuwe informatie', 0.6539110541343689), ('Identificeren van informatiebehoefte', 0.6324360966682434), ('Formuleren van onderzoeksvraag', 0.625347375869751), ('Zoeken ter oriëntatie', 0.6061022281646729), ('Samenwerken (in teams)', 0.605099618434906), ('Informatieverwerking (lezen, luisteren e.d.)', 0.5948988795280457), ('Publiceren (van eindproduct)', 0.594769299030304), ('Communiceren (van eindproduct)', 0.5756981372833252), ('Evalueren van zoekproces (kritisch)', 0.5528095960617065), ('Analyseren van zoekresultaten (informatieanalyse)', 0.5448203682899475), ('Auteursrecht', 0.541864275932312), ('Werking en structuur van het internet', 0.5141681432723999), ('Individu in het informatielandschap', 0.5139905214309692), ('Privacygevoelige informatie', 0.5133863091468811), ('Selecteren zoektermen', 0.5103589296340942), ('Selecteren informatiebronnen en zoeksystemen', 0.509888768196106), ('Manage proces en zoekresultaten', 0.5052697658538818), ('Rol en totstandkoming van netwerken', 0.4786299765110016), ('Bronvermelding', 0.4659441411495209), ('Zoeken naar informatie', 0.44702625274658203), ('Gebruik en verwerken van informatie (ethisch)', 0.4030229449272156), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Plannen en zoeken', 0), ('Organiseren en verwerken', 0), ('Publiceren en communiceren', 0)]
#
# Waarde van informatie/data
#
# [('Waarde van informatie/data', 0.6672388315200806), ('Kritisch beoordelen', nan), ('Valoriseren van bevindingen (outreach)', 0.677861750125885), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 0.6625758409500122), ('Beoordelen van resultaten (kritisch)', 0.6624408960342407), ('Aard en verschijningsvormen van informatie/data', 0.6276892423629761), ('Synthetiseren of creëren van nieuwe informatie', 0.6178838610649109), ('Communiceren (van eindproduct)', 0.6174651980400085), ('Samenwerken (in teams)', 0.5966901183128357), ('Informatieverwerking (lezen, luisteren e.d.)', 0.5852217078208923), ('Zoeken ter oriëntatie', 0.5645744800567627), ('Publiceren (van eindproduct)', 0.5588839650154114), ('Identificeren van informatiebehoefte', 0.5442963242530823), ('Individu in het informatielandschap', 0.5403810739517212), ('Formuleren van onderzoeksvraag', 0.5257381796836853), ('Rol en totstandkoming van netwerken', 0.5065407156944275), ('Auteursrecht', 0.5024536848068237), ('Werking en structuur van het internet', 0.4851931631565094), ('Privacygevoelige informatie', 0.4775376617908478), ('Evalueren van zoekproces (kritisch)', 0.47582221031188965), ('Selecteren zoektermen', 0.4660756587982178), ('Analyseren van zoekresultaten (informatieanalyse)', 0.45382142066955566), ('Manage proces en zoekresultaten', 0.4465737044811249), ('Gebruik en verwerken van informatie (ethisch)', 0.42914485931396484), ('Selecteren informatiebronnen en zoeksystemen', 0.4287837743759155), ('Zoeken naar informatie', 0.41595861315727234), ('Bronvermelding', 0.40072229504585266), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Plannen en zoeken', 0), ('Organiseren en verwerken', 0), ('Publiceren en communiceren', 0)]
#
# Waarde van informatie/data
#
# [('Selecteren zoektermen', 0.6656714677810669), ('Werking en structuur van het internet', 0.6585143804550171), ('Zoeken naar informatie', 0.647018313407898), ('Selecteren informatiebronnen en zoeksystemen', 0.6245090365409851), ('Zoeken ter oriëntatie', 0.604455828666687), ('Kritisch beoordelen', nan), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 0.6110349893569946), ('Valoriseren van bevindingen (outreach)', 0.6016343832015991), ('Manage proces en zoekresultaten', 0.5925605297088623), ('Analyseren van zoekresultaten (informatieanalyse)', 0.5910377502441406), ('Beoordelen van resultaten (kritisch)', 0.5829052925109863), ('Identificeren van informatiebehoefte', 0.5689609050750732), ('Waarde van informatie/data', 0.5678385496139526), ('Communiceren (van eindproduct)', 0.5665273070335388), ('Aard en verschijningsvormen van informatie/data', 0.5562678575515747), ('Synthetiseren of creëren van nieuwe informatie', 0.5520124435424805), ('Publiceren (van eindproduct)', 0.539941132068634), ('Formuleren van onderzoeksvraag', 0.5227096080780029), ('Rol en totstandkoming van netwerken', 0.5197284817695618), ('Individu in het informatielandschap', 0.5052942633628845), ('Samenwerken (in teams)', 0.49968665838241577), ('Evalueren van zoekproces (kritisch)', 0.47858762741088867), ('Bronvermelding', 0.44115349650382996), ('Privacygevoelige informatie', 0.4320341646671295), ('Informatieverwerking (lezen, luisteren e.d.)', 0.4312824308872223), ('Auteursrecht', 0.381894052028656), ('Gebruik en verwerken van informatie (ethisch)', 0.2993689775466919), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Plannen en zoeken', 0), ('Organiseren en verwerken', 0), ('Publiceren en communiceren', 0)]
#
# Selecteren zoektermen
#
# [('Waarde van informatie/data', 0.7183725833892822), ('Kritisch beoordelen', nan), ('Synthetiseren of creëren van nieuwe informatie', 0.7118410468101501), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 0.682322084903717), ('Beoordelen van resultaten (kritisch)', 0.6790225505828857), ('Valoriseren van bevindingen (outreach)', 0.6712347269058228), ('Aard en verschijningsvormen van informatie/data', 0.6480570435523987), ('Publiceren (van eindproduct)', 0.6239922642707825), ('Formuleren van onderzoeksvraag', 0.6195765733718872), ('Communiceren (van eindproduct)', 0.6155579090118408), ('Identificeren van informatiebehoefte', 0.6125246286392212), ('Samenwerken (in teams)', 0.5923576354980469), ('Zoeken ter oriëntatie', 0.5852630734443665), ('Analyseren van zoekresultaten (informatieanalyse)', 0.5799290537834167), ('Manage proces en zoekresultaten', 0.5464221239089966), ('Evalueren van zoekproces (kritisch)', 0.5404236316680908), ('Informatieverwerking (lezen, luisteren e.d.)', 0.5398924350738525), ('Individu in het informatielandschap', 0.5264714360237122), ('Selecteren zoektermen', 0.52154141664505), ('Werking en structuur van het internet', 0.5174792408943176), ('Privacygevoelige informatie', 0.5134868025779724), ('Selecteren informatiebronnen en zoeksystemen', 0.5075931549072266), ('Rol en totstandkoming van netwerken', 0.483676016330719), ('Zoeken naar informatie', 0.47788506746292114), ('Auteursrecht', 0.4589855670928955), ('Bronvermelding', 0.42527902126312256), ('Gebruik en verwerken van informatie (ethisch)', 0.3761519193649292), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Plannen en zoeken', 0), ('Organiseren en verwerken', 0), ('Publiceren en communiceren', 0)]
#
# Waarde van informatie/data
#
# [('Aard en verschijningsvormen van informatie/data', 0.7016530632972717), ('Kritisch beoordelen', nan), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 0.695901095867157), ('Waarde van informatie/data', 0.6951776146888733), ('Publiceren (van eindproduct)', 0.6863602995872498), ('Beoordelen van resultaten (kritisch)', 0.6698098182678223), ('Zoeken ter oriëntatie', 0.6590824723243713), ('Valoriseren van bevindingen (outreach)', 0.6584727764129639), ('Auteursrecht', 0.6332629323005676), ('Synthetiseren of creëren van nieuwe informatie', 0.6236542463302612), ('Communiceren (van eindproduct)', 0.6110178232192993), ('Werking en structuur van het internet', 0.6031947135925293), ('Selecteren informatiebronnen en zoeksystemen', 0.5988768935203552), ('Privacygevoelige informatie', 0.5644192099571228), ('Bronvermelding', 0.5522707104682922), ('Samenwerken (in teams)', 0.5377443432807922), ('Formuleren van onderzoeksvraag', 0.5296977758407593), ('Selecteren zoektermen', 0.516807496547699), ('Identificeren van informatiebehoefte', 0.5125501155853271), ('Zoeken naar informatie', 0.504806399345398), ('Manage proces en zoekresultaten', 0.5041028261184692), ('Rol en totstandkoming van netwerken', 0.49268805980682373), ('Individu in het informatielandschap', 0.4910348057746887), ('Informatieverwerking (lezen, luisteren e.d.)', 0.48974230885505676), ('Analyseren van zoekresultaten (informatieanalyse)', 0.47278591990470886), ('Evalueren van zoekproces (kritisch)', 0.4129265248775482), ('Gebruik en verwerken van informatie (ethisch)', 0.292986661195755), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Plannen en zoeken', 0), ('Organiseren en verwerken', 0), ('Publiceren en communiceren', 0)]
#
# Aard en verschijningsvormen van informatie/data
#
# [('Kritisch beoordelen', nan), ('Publiceren (van eindproduct)', 0.7051304578781128), ('Valoriseren van bevindingen (outreach)', 0.6874257922172546), ('Synthetiseren of creëren van nieuwe informatie', 0.6834224462509155), ('Aard en verschijningsvormen van informatie/data', 0.666671097278595), ('Communiceren (van eindproduct)', 0.6625965237617493), ('Zoeken ter oriëntatie', 0.6272902488708496), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 0.5982895493507385), ('Beoordelen van resultaten (kritisch)', 0.5728546977043152), ('Waarde van informatie/data', 0.5565627217292786), ('Werking en structuur van het internet', 0.5461512804031372), ('Rol en totstandkoming van netwerken', 0.5438609719276428), ('Bronvermelding', 0.5299588441848755), ('Samenwerken (in teams)', 0.5121715664863586), ('Manage proces en zoekresultaten', 0.4975767731666565), ('Selecteren informatiebronnen en zoeksystemen', 0.4933190941810608), ('Auteursrecht', 0.492360383272171), ('Individu in het informatielandschap', 0.4820009171962738), ('Zoeken naar informatie', 0.4380890727043152), ('Formuleren van onderzoeksvraag', 0.43140965700149536), ('Selecteren zoektermen', 0.4234306514263153), ('Analyseren van zoekresultaten (informatieanalyse)', 0.4166571795940399), ('Privacygevoelige informatie', 0.41128644347190857), ('Identificeren van informatiebehoefte', 0.4089800715446472), ('Informatieverwerking (lezen, luisteren e.d.)', 0.4069632291793823), ('Evalueren van zoekproces (kritisch)', 0.40325284004211426), ('Gebruik en verwerken van informatie (ethisch)', 0.2493642121553421), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Plannen en zoeken', 0), ('Organiseren en verwerken', 0), ('Publiceren en communiceren', 0)]
#
# Kritisch beoordelen
#
# [('Zoeken ter oriëntatie', 0.6935319900512695), ('Zoeken naar informatie', 0.6885788440704346), ('Selecteren zoektermen', 0.6785445809364319), ('Selecteren informatiebronnen en zoeksystemen', 0.6657636165618896), ('Aard en verschijningsvormen van informatie/data', 0.6541151404380798), ('Kritisch beoordelen', nan), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 0.6675032377243042), ('Analyseren van zoekresultaten (informatieanalyse)', 0.6425630450248718), ('Valoriseren van bevindingen (outreach)', 0.640880286693573), ('Beoordelen van resultaten (kritisch)', 0.6279129981994629), ('Werking en structuur van het internet', 0.6214762926101685), ('Manage proces en zoekresultaten', 0.6153017282485962), ('Communiceren (van eindproduct)', 0.5998955368995667), ('Waarde van informatie/data', 0.5951586961746216), ('Publiceren (van eindproduct)', 0.5860397815704346), ('Synthetiseren of creëren van nieuwe informatie', 0.5859277248382568), ('Identificeren van informatiebehoefte', 0.5856273174285889), ('Formuleren van onderzoeksvraag', 0.5618167519569397), ('Samenwerken (in teams)', 0.5305267572402954), ('Evalueren van zoekproces (kritisch)', 0.5114924311637878), ('Rol en totstandkoming van netwerken', 0.5028565526008606), ('Bronvermelding', 0.4940439760684967), ('Informatieverwerking (lezen, luisteren e.d.)', 0.4913591742515564), ('Individu in het informatielandschap', 0.442851722240448), ('Auteursrecht', 0.4357515573501587), ('Privacygevoelige informatie', 0.4284673035144806), ('Gebruik en verwerken van informatie (ethisch)', 0.308785080909729), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Plannen en zoeken', 0), ('Organiseren en verwerken', 0), ('Publiceren en communiceren', 0)]
#
# Zoeken ter oriëntatie
#
# [('Zoeken ter oriëntatie', 0.6546341180801392), ('Aard en verschijningsvormen van informatie/data', 0.6266742944717407), ('Zoeken naar informatie', 0.6128361225128174), ('Selecteren zoektermen', 0.6108905076980591), ('Selecteren informatiebronnen en zoeksystemen', 0.6097630262374878), ('Kritisch beoordelen', nan), ('Valoriseren van bevindingen (outreach)', 0.6101646423339844), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 0.5831176042556763), ('Werking en structuur van het internet', 0.5701835751533508), ('Communiceren (van eindproduct)', 0.5692641735076904), ('Manage proces en zoekresultaten', 0.5574473142623901), ('Beoordelen van resultaten (kritisch)', 0.5533066391944885), ('Waarde van informatie/data', 0.5426494479179382), ('Publiceren (van eindproduct)', 0.5253432393074036), ('Samenwerken (in teams)', 0.5252215266227722), ('Identificeren van informatiebehoefte', 0.511779248714447), ('Formuleren van onderzoeksvraag', 0.5034738183021545), ('Synthetiseren of creëren van nieuwe informatie', 0.503079354763031), ('Analyseren van zoekresultaten (informatieanalyse)', 0.5003390908241272), ('Rol en totstandkoming van netwerken', 0.495095819234848), ('Informatieverwerking (lezen, luisteren e.d.)', 0.48588162660598755), ('Bronvermelding', 0.4087817668914795), ('Privacygevoelige informatie', 0.4001365602016449), ('Individu in het informatielandschap', 0.39472612738609314), ('Auteursrecht', 0.39124584197998047), ('Evalueren van zoekproces (kritisch)', 0.3519671857357025), ('Gebruik en verwerken van informatie (ethisch)', 0.2914431691169739), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Plannen en zoeken', 0), ('Organiseren en verwerken', 0), ('Publiceren en communiceren', 0)]
#
# Zoeken ter oriëntatie
#
# [('Waarde van informatie/data', 0.733130156993866), ('Identificeren van informatiebehoefte', 0.7069992423057556), ('Kritisch beoordelen', nan), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 0.7136054039001465), ('Beoordelen van resultaten (kritisch)', 0.6868501901626587), ('Aard en verschijningsvormen van informatie/data', 0.6748673319816589), ('Formuleren van onderzoeksvraag', 0.6551202535629272), ('Analyseren van zoekresultaten (informatieanalyse)', 0.6460306644439697), ('Synthetiseren of creëren van nieuwe informatie', 0.6396068930625916), ('Zoeken ter oriëntatie', 0.6170520782470703), ('Publiceren (van eindproduct)', 0.6157040596008301), ('Valoriseren van bevindingen (outreach)', 0.6089023351669312), ('Samenwerken (in teams)', 0.5930344462394714), ('Informatieverwerking (lezen, luisteren e.d.)', 0.5872050523757935), ('Selecteren zoektermen', 0.579362154006958), ('Manage proces en zoekresultaten', 0.5690515041351318), ('Evalueren van zoekproces (kritisch)', 0.5685045719146729), ('Individu in het informatielandschap', 0.559807300567627), ('Communiceren (van eindproduct)', 0.5363894701004028), ('Auteursrecht', 0.48926734924316406), ('Privacygevoelige informatie', 0.48813724517822266), ('Bronvermelding', 0.480294406414032), ('Werking en structuur van het internet', 0.47253531217575073), ('Selecteren informatiebronnen en zoeksystemen', 0.4682440757751465), ('Rol en totstandkoming van netwerken', 0.4672359526157379), ('Zoeken naar informatie', 0.46393680572509766), ('Gebruik en verwerken van informatie (ethisch)', 0.4171745777130127), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Plannen en zoeken', 0), ('Organiseren en verwerken', 0), ('Publiceren en communiceren', 0)]
#
# Waarde van informatie/data
#
# [('Waarde van informatie/data', 0.5994107723236084), ('Kritisch beoordelen', nan), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 0.5979411602020264), ('Selecteren zoektermen', 0.5907604694366455), ('Valoriseren van bevindingen (outreach)', 0.5906270742416382), ('Aard en verschijningsvormen van informatie/data', 0.5820213556289673), ('Zoeken ter oriëntatie', 0.5766627192497253), ('Publiceren (van eindproduct)', 0.5635912418365479), ('Zoeken naar informatie', 0.5555261373519897), ('Werking en structuur van het internet', 0.5513042211532593), ('Beoordelen van resultaten (kritisch)', 0.5488806366920471), ('Synthetiseren of creëren van nieuwe informatie', 0.5418850183486938), ('Manage proces en zoekresultaten', 0.540213406085968), ('Selecteren informatiebronnen en zoeksystemen', 0.5266748666763306), ('Individu in het informatielandschap', 0.5231086015701294), ('Identificeren van informatiebehoefte', 0.52115797996521), ('Communiceren (van eindproduct)', 0.518677830696106), ('Analyseren van zoekresultaten (informatieanalyse)', 0.5079902410507202), ('Rol en totstandkoming van netwerken', 0.49704694747924805), ('Samenwerken (in teams)', 0.49148133397102356), ('Formuleren van onderzoeksvraag', 0.4714653789997101), ('Bronvermelding', 0.4557661712169647), ('Informatieverwerking (lezen, luisteren e.d.)', 0.4552184045314789), ('Auteursrecht', 0.4346729815006256), ('Privacygevoelige informatie', 0.426673948764801), ('Evalueren van zoekproces (kritisch)', 0.41453883051872253), ('Gebruik en verwerken van informatie (ethisch)', 0.2948843836784363), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Plannen en zoeken', 0), ('Organiseren en verwerken', 0), ('Publiceren en communiceren', 0)]
#
# Waarde van informatie/data
#
# [('Zoeken ter oriëntatie', 0.8323543071746826), ('Aard en verschijningsvormen van informatie/data', 0.8210480213165283), ('Kritisch beoordelen', nan), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 0.7865851521492004), ('Selecteren informatiebronnen en zoeksystemen', 0.7556715607643127), ('Publiceren (van eindproduct)', 0.7230850458145142), ('Beoordelen van resultaten (kritisch)', 0.7206641435623169), ('Valoriseren van bevindingen (outreach)', 0.7025216221809387), ('Synthetiseren of creëren van nieuwe informatie', 0.6979238390922546), ('Communiceren (van eindproduct)', 0.6865042448043823), ('Waarde van informatie/data', 0.6822406649589539), ('Manage proces en zoekresultaten', 0.6568330526351929), ('Zoeken naar informatie', 0.6206808686256409), ('Selecteren zoektermen', 0.6014184951782227), ('Identificeren van informatiebehoefte', 0.6010690927505493), ('Bronvermelding', 0.6005644798278809), ('Analyseren van zoekresultaten (informatieanalyse)', 0.5937957763671875), ('Formuleren van onderzoeksvraag', 0.5905718803405762), ('Werking en structuur van het internet', 0.5871360898017883), ('Privacygevoelige informatie', 0.5822315216064453), ('Samenwerken (in teams)', 0.5637454390525818), ('Individu in het informatielandschap', 0.5634130835533142), ('Rol en totstandkoming van netwerken', 0.5169855356216431), ('Evalueren van zoekproces (kritisch)', 0.5167336463928223), ('Informatieverwerking (lezen, luisteren e.d.)', 0.5054730176925659), ('Auteursrecht', 0.4938608705997467), ('Gebruik en verwerken van informatie (ethisch)', 0.3331064283847809), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Plannen en zoeken', 0), ('Organiseren en verwerken', 0), ('Publiceren en communiceren', 0)]
#
# Zoeken ter oriëntatie
#
# [('Aard en verschijningsvormen van informatie/data', 0.6510142683982849), ('Zoeken ter oriëntatie', 0.6287729144096375), ('Kritisch beoordelen', nan), ('Valoriseren van bevindingen (outreach)', 0.6139370203018188), ('Publiceren (van eindproduct)', 0.611566960811615), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 0.5992189049720764), ('Communiceren (van eindproduct)', 0.5921560525894165), ('Manage proces en zoekresultaten', 0.5888781547546387), ('Synthetiseren of creëren van nieuwe informatie', 0.5724813938140869), ('Selecteren informatiebronnen en zoeksystemen', 0.5579922795295715), ('Beoordelen van resultaten (kritisch)', 0.5560455918312073), ('Waarde van informatie/data', 0.5511806607246399), ('Selecteren zoektermen', 0.5328181385993958), ('Werking en structuur van het internet', 0.5327415466308594), ('Informatieverwerking (lezen, luisteren e.d.)', 0.5248410701751709), ('Analyseren van zoekresultaten (informatieanalyse)', 0.5204601883888245), ('Zoeken naar informatie', 0.5186945796012878), ('Identificeren van informatiebehoefte', 0.5041301846504211), ('Samenwerken (in teams)', 0.5000511407852173), ('Evalueren van zoekproces (kritisch)', 0.49740341305732727), ('Rol en totstandkoming van netwerken', 0.49479737877845764), ('Individu in het informatielandschap', 0.470867782831192), ('Bronvermelding', 0.4505649507045746), ('Formuleren van onderzoeksvraag', 0.4500269889831543), ('Privacygevoelige informatie', 0.3950459659099579), ('Auteursrecht', 0.37981465458869934), ('Gebruik en verwerken van informatie (ethisch)', 0.3209846019744873), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Plannen en zoeken', 0), ('Organiseren en verwerken', 0), ('Publiceren en communiceren', 0)]
#
# Aard en verschijningsvormen van informatie/data
#
# [('Kritisch beoordelen', nan), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 0.7304880023002625), ('Beoordelen van resultaten (kritisch)', 0.704487681388855), ('Waarde van informatie/data', 0.6909576058387756), ('Aard en verschijningsvormen van informatie/data', 0.6682831645011902), ('Zoeken ter oriëntatie', 0.6336610317230225), ('Synthetiseren of creëren van nieuwe informatie', 0.6283919215202332), ('Valoriseren van bevindingen (outreach)', 0.617661714553833), ('Identificeren van informatiebehoefte', 0.5987251996994019), ('Samenwerken (in teams)', 0.5924302935600281), ('Formuleren van onderzoeksvraag', 0.5872962474822998), ('Communiceren (van eindproduct)', 0.5831372737884521), ('Publiceren (van eindproduct)', 0.5665509104728699), ('Analyseren van zoekresultaten (informatieanalyse)', 0.551563560962677), ('Auteursrecht', 0.544698178768158), ('Informatieverwerking (lezen, luisteren e.d.)', 0.5444181561470032), ('Manage proces en zoekresultaten', 0.5429388880729675), ('Selecteren informatiebronnen en zoeksystemen', 0.5368295311927795), ('Privacygevoelige informatie', 0.5278151035308838), ('Bronvermelding', 0.5235287547111511), ('Selecteren zoektermen', 0.5204548835754395), ('Individu in het informatielandschap', 0.5131799578666687), ('Werking en structuur van het internet', 0.5060122609138489), ('Evalueren van zoekproces (kritisch)', 0.5034676790237427), ('Zoeken naar informatie', 0.4705584645271301), ('Rol en totstandkoming van netwerken', 0.4368014931678772), ('Gebruik en verwerken van informatie (ethisch)', 0.3548929691314697), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Plannen en zoeken', 0), ('Organiseren en verwerken', 0), ('Publiceren en communiceren', 0)]
#
# Kritisch beoordelen
#
# [('Zoeken ter oriëntatie', 0.7265180349349976), ('Kritisch beoordelen', nan), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 0.7470855712890625), ('Aard en verschijningsvormen van informatie/data', 0.7365327477455139), ('Bronvermelding', 0.6974315047264099), ('Publiceren (van eindproduct)', 0.6947305202484131), ('Synthetiseren of creëren van nieuwe informatie', 0.6791059970855713), ('Beoordelen van resultaten (kritisch)', 0.6775645017623901), ('Communiceren (van eindproduct)', 0.6640752553939819), ('Valoriseren van bevindingen (outreach)', 0.6601730585098267), ('Manage proces en zoekresultaten', 0.6271289587020874), ('Waarde van informatie/data', 0.6249603629112244), ('Selecteren informatiebronnen en zoeksystemen', 0.5739077925682068), ('Selecteren zoektermen', 0.5722144842147827), ('Samenwerken (in teams)', 0.5646163821220398), ('Zoeken naar informatie', 0.5597503781318665), ('Formuleren van onderzoeksvraag', 0.5541655421257019), ('Analyseren van zoekresultaten (informatieanalyse)', 0.5518544912338257), ('Werking en structuur van het internet', 0.5483102798461914), ('Evalueren van zoekproces (kritisch)', 0.5313077569007874), ('Identificeren van informatiebehoefte', 0.5284931063652039), ('Auteursrecht', 0.4872299134731293), ('Rol en totstandkoming van netwerken', 0.4837045967578888), ('Individu in het informatielandschap', 0.46915408968925476), ('Privacygevoelige informatie', 0.4649043381214142), ('Informatieverwerking (lezen, luisteren e.d.)', 0.4527134299278259), ('Gebruik en verwerken van informatie (ethisch)', 0.30196869373321533), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Plannen en zoeken', 0), ('Organiseren en verwerken', 0), ('Publiceren en communiceren', 0)]
#
# Zoeken ter oriëntatie
#
# [('Aard en verschijningsvormen van informatie/data', 0.7149079442024231), ('Kritisch beoordelen', nan), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 0.7182823419570923), ('Beoordelen van resultaten (kritisch)', 0.6760258078575134), ('Zoeken ter oriëntatie', 0.6666138768196106), ('Waarde van informatie/data', 0.611186683177948), ('Publiceren (van eindproduct)', 0.6096943020820618), ('Valoriseren van bevindingen (outreach)', 0.6038402915000916), ('Synthetiseren of creëren van nieuwe informatie', 0.5993317365646362), ('Communiceren (van eindproduct)', 0.5927940607070923), ('Identificeren van informatiebehoefte', 0.5629518032073975), ('Privacygevoelige informatie', 0.5604113340377808), ('Samenwerken (in teams)', 0.5577185750007629), ('Selecteren informatiebronnen en zoeksystemen', 0.5517171025276184), ('Manage proces en zoekresultaten', 0.5464996099472046), ('Formuleren van onderzoeksvraag', 0.5456822514533997), ('Informatieverwerking (lezen, luisteren e.d.)', 0.5410102009773254), ('Selecteren zoektermen', 0.5238689184188843), ('Bronvermelding', 0.5095922350883484), ('Werking en structuur van het internet', 0.5067366361618042), ('Analyseren van zoekresultaten (informatieanalyse)', 0.5052609443664551), ('Evalueren van zoekproces (kritisch)', 0.4892047941684723), ('Zoeken naar informatie', 0.4791523218154907), ('Individu in het informatielandschap', 0.475355327129364), ('Auteursrecht', 0.4608180522918701), ('Rol en totstandkoming van netwerken', 0.4402911365032196), ('Gebruik en verwerken van informatie (ethisch)', 0.2707906663417816), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Plannen en zoeken', 0), ('Organiseren en verwerken', 0), ('Publiceren en communiceren', 0)]
#
# Aard en verschijningsvormen van informatie/data
#
# [('Zoeken ter oriëntatie', 0.6695325374603271), ('Kritisch beoordelen', nan), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 0.6946487426757812), ('Aard en verschijningsvormen van informatie/data', 0.6801164746284485), ('Beoordelen van resultaten (kritisch)', 0.6296806335449219), ('Manage proces en zoekresultaten', 0.6161271929740906), ('Valoriseren van bevindingen (outreach)', 0.6147284507751465), ('Waarde van informatie/data', 0.6057438254356384), ('Publiceren (van eindproduct)', 0.6013901829719543), ('Selecteren zoektermen', 0.5928426384925842), ('Communiceren (van eindproduct)', 0.576307475566864), ('Zoeken naar informatie', 0.5734801292419434), ('Synthetiseren of creëren van nieuwe informatie', 0.5708167552947998), ('Selecteren informatiebronnen en zoeksystemen', 0.5609927177429199), ('Bronvermelding', 0.5600172877311707), ('Samenwerken (in teams)', 0.5564366579055786), ('Identificeren van informatiebehoefte', 0.5202517509460449), ('Werking en structuur van het internet', 0.5150578618049622), ('Analyseren van zoekresultaten (informatieanalyse)', 0.5121301412582397), ('Evalueren van zoekproces (kritisch)', 0.5061144828796387), ('Formuleren van onderzoeksvraag', 0.49566400051116943), ('Rol en totstandkoming van netwerken', 0.48427531123161316), ('Individu in het informatielandschap', 0.4753063917160034), ('Privacygevoelige informatie', 0.4715816080570221), ('Informatieverwerking (lezen, luisteren e.d.)', 0.4482405483722687), ('Auteursrecht', 0.43654733896255493), ('Gebruik en verwerken van informatie (ethisch)', 0.30372539162635803), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Plannen en zoeken', 0), ('Organiseren en verwerken', 0), ('Publiceren en communiceren', 0)]
#
# Zoeken ter oriëntatie
#
# [('Zoeken ter oriëntatie', 0.7672480940818787), ('Aard en verschijningsvormen van informatie/data', 0.7480114102363586), ('Kritisch beoordelen', nan), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 0.7269656658172607), ('Valoriseren van bevindingen (outreach)', 0.7081627249717712), ('Selecteren informatiebronnen en zoeksystemen', 0.697313129901886), ('Communiceren (van eindproduct)', 0.6944106817245483), ('Manage proces en zoekresultaten', 0.6881949305534363), ('Beoordelen van resultaten (kritisch)', 0.6807569265365601), ('Publiceren (van eindproduct)', 0.6505827903747559), ('Synthetiseren of creëren van nieuwe informatie', 0.641183078289032), ('Zoeken naar informatie', 0.6402658820152283), ('Waarde van informatie/data', 0.6237396597862244), ('Bronvermelding', 0.6236074566841125), ('Selecteren zoektermen', 0.6085763573646545), ('Werking en structuur van het internet', 0.6020864844322205), ('Samenwerken (in teams)', 0.5836511850357056), ('Rol en totstandkoming van netwerken', 0.5752347111701965), ('Analyseren van zoekresultaten (informatieanalyse)', 0.5653798580169678), ('Identificeren van informatiebehoefte', 0.5384199023246765), ('Formuleren van onderzoeksvraag', 0.5268329977989197), ('Evalueren van zoekproces (kritisch)', 0.505733847618103), ('Privacygevoelige informatie', 0.5019144415855408), ('Auteursrecht', 0.4828881323337555), ('Individu in het informatielandschap', 0.46313533186912537), ('Informatieverwerking (lezen, luisteren e.d.)', 0.44734448194503784), ('Gebruik en verwerken van informatie (ethisch)', 0.3113405704498291), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Plannen en zoeken', 0), ('Organiseren en verwerken', 0), ('Publiceren en communiceren', 0)]
#
# Zoeken ter oriëntatie
#
# [('Zoeken ter oriëntatie', 0.7245224714279175), ('Kritisch beoordelen', nan), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 0.8012952208518982), ('Aard en verschijningsvormen van informatie/data', 0.7856450080871582), ('Publiceren (van eindproduct)', 0.712411642074585), ('Beoordelen van resultaten (kritisch)', 0.7038764357566833), ('Waarde van informatie/data', 0.6754993200302124), ('Synthetiseren of creëren van nieuwe informatie', 0.6586383581161499), ('Valoriseren van bevindingen (outreach)', 0.6246315836906433), ('Formuleren van onderzoeksvraag', 0.6200918555259705), ('Identificeren van informatiebehoefte', 0.5995250940322876), ('Communiceren (van eindproduct)', 0.5801644325256348), ('Manage proces en zoekresultaten', 0.5762289762496948), ('Auteursrecht', 0.5631798505783081), ('Bronvermelding', 0.5611374378204346), ('Selecteren informatiebronnen en zoeksystemen', 0.5597569346427917), ('Analyseren van zoekresultaten (informatieanalyse)', 0.5587209463119507), ('Samenwerken (in teams)', 0.548578143119812), ('Selecteren zoektermen', 0.5329243540763855), ('Individu in het informatielandschap', 0.5199052095413208), ('Informatieverwerking (lezen, luisteren e.d.)', 0.5010930895805359), ('Zoeken naar informatie', 0.49554264545440674), ('Evalueren van zoekproces (kritisch)', 0.4891231060028076), ('Privacygevoelige informatie', 0.48536884784698486), ('Werking en structuur van het internet', 0.47413134574890137), ('Rol en totstandkoming van netwerken', 0.43799668550491333), ('Gebruik en verwerken van informatie (ethisch)', 0.3702298402786255), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Plannen en zoeken', 0), ('Organiseren en verwerken', 0), ('Publiceren en communiceren', 0)]
#
# Zoeken ter oriëntatie
#
# [('Aard en verschijningsvormen van informatie/data', 0.7664222121238708), ('Zoeken ter oriëntatie', 0.6981854438781738), ('Kritisch beoordelen', nan), ('Publiceren (van eindproduct)', 0.6954010128974915), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 0.695376992225647), ('Synthetiseren of creëren van nieuwe informatie', 0.6538936495780945), ('Valoriseren van bevindingen (outreach)', 0.6482498645782471), ('Beoordelen van resultaten (kritisch)', 0.6438475847244263), ('Waarde van informatie/data', 0.6189684271812439), ('Communiceren (van eindproduct)', 0.6091574430465698), ('Informatieverwerking (lezen, luisteren e.d.)', 0.5740703344345093), ('Formuleren van onderzoeksvraag', 0.5735369920730591), ('Manage proces en zoekresultaten', 0.5569148063659668), ('Selecteren informatiebronnen en zoeksystemen', 0.5552611947059631), ('Identificeren van informatiebehoefte', 0.5551411509513855), ('Selecteren zoektermen', 0.5387605428695679), ('Analyseren van zoekresultaten (informatieanalyse)', 0.5285078287124634), ('Bronvermelding', 0.5276851058006287), ('Samenwerken (in teams)', 0.5264093279838562), ('Werking en structuur van het internet', 0.5251497030258179), ('Zoeken naar informatie', 0.5106036067008972), ('Auteursrecht', 0.5081780552864075), ('Evalueren van zoekproces (kritisch)', 0.5044922232627869), ('Rol en totstandkoming van netwerken', 0.46935904026031494), ('Individu in het informatielandschap', 0.4620263874530792), ('Privacygevoelige informatie', 0.42675986886024475), ('Gebruik en verwerken van informatie (ethisch)', 0.3021780252456665), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Plannen en zoeken', 0), ('Organiseren en verwerken', 0), ('Publiceren en communiceren', 0)]
#
# Aard en verschijningsvormen van informatie/data
#
# [('Kritisch beoordelen', nan), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 0.7103037238121033), ('Zoeken naar informatie', 0.6942606568336487), ('Selecteren informatiebronnen en zoeksystemen', 0.6935198903083801), ('Zoeken ter oriëntatie', 0.6930589079856873), ('Beoordelen van resultaten (kritisch)', 0.6727436780929565), ('Werking en structuur van het internet', 0.6715929508209229), ('Analyseren van zoekresultaten (informatieanalyse)', 0.6650667786598206), ('Manage proces en zoekresultaten', 0.6635465025901794), ('Valoriseren van bevindingen (outreach)', 0.6559931635856628), ('Selecteren zoektermen', 0.642268180847168), ('Aard en verschijningsvormen van informatie/data', 0.6374795436859131), ('Publiceren (van eindproduct)', 0.6315888166427612), ('Communiceren (van eindproduct)', 0.6116942167282104), ('Synthetiseren of creëren van nieuwe informatie', 0.6006659865379333), ('Waarde van informatie/data', 0.5987571477890015), ('Rol en totstandkoming van netwerken', 0.5546408891677856), ('Evalueren van zoekproces (kritisch)', 0.5406842827796936), ('Bronvermelding', 0.5334764122962952), ('Identificeren van informatiebehoefte', 0.5194704532623291), ('Individu in het informatielandschap', 0.5061360597610474), ('Formuleren van onderzoeksvraag', 0.5031003355979919), ('Auteursrecht', 0.5007033348083496), ('Samenwerken (in teams)', 0.48777899146080017), ('Privacygevoelige informatie', 0.44300392270088196), ('Informatieverwerking (lezen, luisteren e.d.)', 0.4043632745742798), ('Gebruik en verwerken van informatie (ethisch)', 0.3168739676475525), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Plannen en zoeken', 0), ('Organiseren en verwerken', 0), ('Publiceren en communiceren', 0)]
#
# Kritisch beoordelen
#
# [('Kritisch beoordelen', nan), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 0.7622925043106079), ('Beoordelen van resultaten (kritisch)', 0.7027331590652466), ('Aard en verschijningsvormen van informatie/data', 0.6970269680023193), ('Synthetiseren of creëren van nieuwe informatie', 0.6871150135993958), ('Waarde van informatie/data', 0.667768120765686), ('Publiceren (van eindproduct)', 0.6497605443000793), ('Zoeken ter oriëntatie', 0.6380369663238525), ('Valoriseren van bevindingen (outreach)', 0.6108160614967346), ('Communiceren (van eindproduct)', 0.5852342247962952), ('Bronvermelding', 0.5844039916992188), ('Formuleren van onderzoeksvraag', 0.5741008520126343), ('Analyseren van zoekresultaten (informatieanalyse)', 0.5551204681396484), ('Identificeren van informatiebehoefte', 0.5538281202316284), ('Manage proces en zoekresultaten', 0.5370386242866516), ('Samenwerken (in teams)', 0.5327442288398743), ('Auteursrecht', 0.5303056240081787), ('Evalueren van zoekproces (kritisch)', 0.5259672999382019), ('Privacygevoelige informatie', 0.5202996730804443), ('Individu in het informatielandschap', 0.5029193162918091), ('Selecteren informatiebronnen en zoeksystemen', 0.5002745985984802), ('Informatieverwerking (lezen, luisteren e.d.)', 0.49146568775177), ('Selecteren zoektermen', 0.47903576493263245), ('Werking en structuur van het internet', 0.4649323523044586), ('Zoeken naar informatie', 0.4515690505504608), ('Rol en totstandkoming van netwerken', 0.4293440878391266), ('Gebruik en verwerken van informatie (ethisch)', 0.3286359906196594), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Plannen en zoeken', 0), ('Organiseren en verwerken', 0), ('Publiceren en communiceren', 0)]
#
# Kritisch beoordelen
#
# [('Aard en verschijningsvormen van informatie/data', 0.7486922144889832), ('Zoeken ter oriëntatie', 0.7364453077316284), ('Kritisch beoordelen', nan), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 0.7137814164161682), ('Selecteren informatiebronnen en zoeksystemen', 0.6730594635009766), ('Publiceren (van eindproduct)', 0.6586486101150513), ('Synthetiseren of creëren van nieuwe informatie', 0.6531012654304504), ('Beoordelen van resultaten (kritisch)', 0.6476095914840698), ('Communiceren (van eindproduct)', 0.6378740072250366), ('Valoriseren van bevindingen (outreach)', 0.6282076835632324), ('Waarde van informatie/data', 0.6280102729797363), ('Manage proces en zoekresultaten', 0.5679689049720764), ('Bronvermelding', 0.5662997961044312), ('Formuleren van onderzoeksvraag', 0.5596128106117249), ('Identificeren van informatiebehoefte', 0.557126522064209), ('Zoeken naar informatie', 0.5431346893310547), ('Samenwerken (in teams)', 0.5337120294570923), ('Selecteren zoektermen', 0.5325051546096802), ('Analyseren van zoekresultaten (informatieanalyse)', 0.52964848279953), ('Privacygevoelige informatie', 0.5203202366828918), ('Werking en structuur van het internet', 0.5039232969284058), ('Evalueren van zoekproces (kritisch)', 0.4750311076641083), ('Informatieverwerking (lezen, luisteren e.d.)', 0.47441136837005615), ('Individu in het informatielandschap', 0.4628763198852539), ('Auteursrecht', 0.45239362120628357), ('Rol en totstandkoming van netwerken', 0.43818172812461853), ('Gebruik en verwerken van informatie (ethisch)', 0.33337682485580444), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Plannen en zoeken', 0), ('Organiseren en verwerken', 0), ('Publiceren en communiceren', 0)]
#
# Aard en verschijningsvormen van informatie/data
#
# [('Aard en verschijningsvormen van informatie/data', 0.7042978405952454), ('Kritisch beoordelen', nan), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 0.6868384480476379), ('Beoordelen van resultaten (kritisch)', 0.6683332920074463), ('Zoeken ter oriëntatie', 0.6503489017486572), ('Synthetiseren of creëren van nieuwe informatie', 0.6428274512290955), ('Evalueren van zoekproces (kritisch)', 0.5921513438224792), ('Waarde van informatie/data', 0.5910202860832214), ('Publiceren (van eindproduct)', 0.590905487537384), ('Manage proces en zoekresultaten', 0.5872318148612976), ('Valoriseren van bevindingen (outreach)', 0.5833851099014282), ('Communiceren (van eindproduct)', 0.5599766969680786), ('Identificeren van informatiebehoefte', 0.5550360679626465), ('Analyseren van zoekresultaten (informatieanalyse)', 0.5514855980873108), ('Samenwerken (in teams)', 0.5437844395637512), ('Formuleren van onderzoeksvraag', 0.5261690616607666), ('Informatieverwerking (lezen, luisteren e.d.)', 0.5121822953224182), ('Selecteren informatiebronnen en zoeksystemen', 0.5002802014350891), ('Selecteren zoektermen', 0.4873846173286438), ('Werking en structuur van het internet', 0.46955281496047974), ('Bronvermelding', 0.46653202176094055), ('Zoeken naar informatie', 0.45714280009269714), ('Auteursrecht', 0.44303879141807556), ('Privacygevoelige informatie', 0.429451048374176), ('Individu in het informatielandschap', 0.4019961357116699), ('Rol en totstandkoming van netwerken', 0.39922040700912476), ('Gebruik en verwerken van informatie (ethisch)', 0.34096840023994446), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Plannen en zoeken', 0), ('Organiseren en verwerken', 0), ('Publiceren en communiceren', 0)]
#
# Aard en verschijningsvormen van informatie/data
#
# ...
#
# Zoeken ter oriëntatie
#
# [('Zoeken ter oriëntatie', 0.7634896636009216), ('Kritisch beoordelen', nan), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 0.7914290428161621), ('Aard en verschijningsvormen van informatie/data', 0.7808440327644348), ('Beoordelen van resultaten (kritisch)', 0.7007339000701904), ('Synthetiseren of creëren van nieuwe informatie', 0.6830258369445801), ('Waarde van informatie/data', 0.6696237325668335), ('Publiceren (van eindproduct)', 0.6679583191871643), ('Valoriseren van bevindingen (outreach)', 0.6574326157569885), ('Selecteren informatiebronnen en zoeksystemen', 0.633486270904541), ('Communiceren (van eindproduct)', 0.6333139538764954), ('Samenwerken (in teams)', 0.6323581337928772), ('Identificeren van informatiebehoefte', 0.6271767020225525), ('Analyseren van zoekresultaten (informatieanalyse)', 0.6128502488136292), ('Manage proces en zoekresultaten', 0.6125319600105286), ('Selecteren zoektermen', 0.6045030355453491), ('Formuleren van onderzoeksvraag', 0.6014856100082397), ('Bronvermelding', 0.5677096843719482), ('Zoeken naar informatie', 0.5580798387527466), ('Evalueren van zoekproces (kritisch)', 0.5539481043815613), ('Werking en structuur van het internet', 0.5331591367721558), ('Individu in het informatielandschap', 0.5216057896614075), ('Auteursrecht', 0.5105859637260437), ('Informatieverwerking (lezen, luisteren e.d.)', 0.4938260316848755), ('Privacygevoelige informatie', 0.4814479351043701), ('Rol en totstandkoming van netwerken', 0.4680015742778778), ('Gebruik en verwerken van informatie (ethisch)', 0.3852340877056122), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Plannen en zoeken', 0), ('Organiseren en verwerken', 0), ('Publiceren en communiceren', 0)]
#
# Zoeken ter oriëntatie
#
# [('Aard en verschijningsvormen van informatie/data', 0.6831294298171997), ('Kritisch beoordelen', nan), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 0.6881983280181885), ('Waarde van informatie/data', 0.6490871906280518), ('Beoordelen van resultaten (kritisch)', 0.6469427943229675), ('Zoeken ter oriëntatie', 0.6364433169364929), ('Publiceren (van eindproduct)', 0.6247993111610413), ('Synthetiseren of creëren van nieuwe informatie', 0.6145979166030884), ('Valoriseren van bevindingen (outreach)', 0.6026374101638794), ('Communiceren (van eindproduct)', 0.5815117955207825), ('Bronvermelding', 0.5630577206611633), ('Selecteren informatiebronnen en zoeksystemen', 0.5579546689987183), ('Manage proces en zoekresultaten', 0.556157648563385), ('Identificeren van informatiebehoefte', 0.5553027987480164), ('Samenwerken (in teams)', 0.546645998954773), ('Selecteren zoektermen', 0.5454847812652588), ('Formuleren van onderzoeksvraag', 0.5274230241775513), ('Privacygevoelige informatie', 0.522757351398468), ('Werking en structuur van het internet', 0.5225144624710083), ('Auteursrecht', 0.5070697069168091), ('Zoeken naar informatie', 0.5037609338760376), ('Analyseren van zoekresultaten (informatieanalyse)', 0.4857960641384125), ('Evalueren van zoekproces (kritisch)', 0.4701356291770935), ('Informatieverwerking (lezen, luisteren e.d.)', 0.46720609068870544), ('Individu in het informatielandschap', 0.4474334418773651), ('Rol en totstandkoming van netwerken', 0.4405337870121002), ('Gebruik en verwerken van informatie (ethisch)', 0.29440614581108093), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Plannen en zoeken', 0), ('Organiseren en verwerken', 0), ('Publiceren en communiceren', 0)]
#
# Aard en verschijningsvormen van informatie/data
#
# [('Kritisch beoordelen', nan), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 0.6956085562705994), ('Evalueren van zoekproces (kritisch)', 0.693600594997406), ('Aard en verschijningsvormen van informatie/data', 0.6883845329284668), ('Synthetiseren of creëren van nieuwe informatie', 0.6645610928535461), ('Beoordelen van resultaten (kritisch)', 0.6642902493476868), ('Zoeken ter oriëntatie', 0.6376960873603821), ('Valoriseren van bevindingen (outreach)', 0.6263825297355652), ('Communiceren (van eindproduct)', 0.617838442325592), ('Manage proces en zoekresultaten', 0.6102244257926941), ('Waarde van informatie/data', 0.6101095676422119), ('Publiceren (van eindproduct)', 0.5842004418373108), ('Samenwerken (in teams)', 0.5788989067077637), ('Identificeren van informatiebehoefte', 0.5691056251525879), ('Formuleren van onderzoeksvraag', 0.5590094923973083), ('Selecteren informatiebronnen en zoeksystemen', 0.5527525544166565), ('Selecteren zoektermen', 0.5423163771629333), ('Analyseren van zoekresultaten (informatieanalyse)', 0.5391272902488708), ('Zoeken naar informatie', 0.5229495763778687), ('Werking en structuur van het internet', 0.4934801161289215), ('Informatieverwerking (lezen, luisteren e.d.)', 0.4755624830722809), ('Privacygevoelige informatie', 0.4653324484825134), ('Individu in het informatielandschap', 0.45959150791168213), ('Rol en totstandkoming van netwerken', 0.45381951332092285), ('Bronvermelding', 0.43023285269737244), ('Auteursrecht', 0.40880993008613586), ('Gebruik en verwerken van informatie (ethisch)', 0.32458049058914185), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Plannen en zoeken', 0), ('Organiseren en verwerken', 0), ('Publiceren en communiceren', 0)]
#
# Kritisch beoordelen
#
# [('Zoeken ter oriëntatie', 0.7766956686973572), ('Aard en verschijningsvormen van informatie/data', 0.7304649949073792), ('Selecteren informatiebronnen en zoeksystemen', 0.7240020632743835), ('Zoeken naar informatie', 0.7180108428001404), ('Selecteren zoektermen', 0.7088983058929443), ('Kritisch beoordelen', nan), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 0.6790571212768555), ('Valoriseren van bevindingen (outreach)', 0.669091522693634), ('Werking en structuur van het internet', 0.6584845781326294), ('Manage proces en zoekresultaten', 0.6509808301925659), ('Publiceren (van eindproduct)', 0.6400094032287598), ('Communiceren (van eindproduct)', 0.6324446201324463), ('Samenwerken (in teams)', 0.6319576501846313), ('Beoordelen van resultaten (kritisch)', 0.6176829934120178), ('Synthetiseren of creëren van nieuwe informatie', 0.6127448678016663), ('Identificeren van informatiebehoefte', 0.5807505249977112), ('Waarde van informatie/data', 0.5726766586303711), ('Analyseren van zoekresultaten (informatieanalyse)', 0.5456845760345459), ('Formuleren van onderzoeksvraag', 0.5358635783195496), ('Bronvermelding', 0.5107433199882507), ('Rol en totstandkoming van netwerken', 0.5043169856071472), ('Evalueren van zoekproces (kritisch)', 0.48701125383377075), ('Informatieverwerking (lezen, luisteren e.d.)', 0.48141971230506897), ('Individu in het informatielandschap', 0.4774225354194641), ('Privacygevoelige informatie', 0.4145795404911041), ('Auteursrecht', 0.41351261734962463), ('Gebruik en verwerken van informatie (ethisch)', 0.3376781940460205), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Plannen en zoeken', 0), ('Organiseren en verwerken', 0), ('Publiceren en communiceren', 0)]
#
# Zoeken ter oriëntatie
#
# [('Aard en verschijningsvormen van informatie/data', 0.7834481596946716), ('Zoeken ter oriëntatie', 0.7798065543174744), ('Selecteren informatiebronnen en zoeksystemen', 0.7501159310340881), ('Kritisch beoordelen', nan), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 0.739028811454773), ('Beoordelen van resultaten (kritisch)', 0.6841006278991699), ('Communiceren (van eindproduct)', 0.658025860786438), ('Valoriseren van bevindingen (outreach)', 0.6474564075469971), ('Publiceren (van eindproduct)', 0.6198397874832153), ('Waarde van informatie/data', 0.6174592971801758), ('Synthetiseren of creëren van nieuwe informatie', 0.6056901812553406), ('Zoeken naar informatie', 0.5938754081726074), ('Werking en structuur van het internet', 0.593038022518158), ('Selecteren zoektermen', 0.5869237780570984), ('Samenwerken (in teams)', 0.5682379603385925), ('Identificeren van informatiebehoefte', 0.5675275921821594), ('Manage proces en zoekresultaten', 0.5649867653846741), ('Formuleren van onderzoeksvraag', 0.55613112449646), ('Privacygevoelige informatie', 0.5503787994384766), ('Analyseren van zoekresultaten (informatieanalyse)', 0.5311471223831177), ('Bronvermelding', 0.47936487197875977), ('Auteursrecht', 0.47796162962913513), ('Individu in het informatielandschap', 0.4646895229816437), ('Rol en totstandkoming van netwerken', 0.46297016739845276), ('Evalueren van zoekproces (kritisch)', 0.46296238899230957), ('Informatieverwerking (lezen, luisteren e.d.)', 0.4466414749622345), ('Gebruik en verwerken van informatie (ethisch)', 0.24292246997356415), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Plannen en zoeken', 0), ('Organiseren en verwerken', 0), ('Publiceren en communiceren', 0)]
#
# Aard en verschijningsvormen van informatie/data
#
# [('Zoeken ter oriëntatie', 0.6865502595901489), ('Aard en verschijningsvormen van informatie/data', 0.6810568571090698), ('Kritisch beoordelen', nan), ('Valoriseren van bevindingen (outreach)', 0.6673465967178345), ('Communiceren (van eindproduct)', 0.6485524773597717), ('Publiceren (van eindproduct)', 0.6317381262779236), ('Selecteren informatiebronnen en zoeksystemen', 0.6296213269233704), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 0.6262253522872925), ('Werking en structuur van het internet', 0.5986472964286804), ('Synthetiseren of creëren van nieuwe informatie', 0.5970829129219055), ('Manage proces en zoekresultaten', 0.595812976360321), ('Beoordelen van resultaten (kritisch)', 0.5884461402893066), ('Waarde van informatie/data', 0.5861350297927856), ('Zoeken naar informatie', 0.5736561417579651), ('Analyseren van zoekresultaten (informatieanalyse)', 0.5496305823326111), ('Selecteren zoektermen', 0.5457789897918701), ('Samenwerken (in teams)', 0.527546763420105), ('Rol en totstandkoming van netwerken', 0.4968058466911316), ('Formuleren van onderzoeksvraag', 0.494069367647171), ('Identificeren van informatiebehoefte', 0.48606035113334656), ('Individu in het informatielandschap', 0.4697367548942566), ('Bronvermelding', 0.4457640051841736), ('Privacygevoelige informatie', 0.4319728910923004), ('Informatieverwerking (lezen, luisteren e.d.)', 0.4130045473575592), ('Auteursrecht', 0.41153305768966675), ('Evalueren van zoekproces (kritisch)', 0.40987297892570496), ('Gebruik en verwerken van informatie (ethisch)', 0.3140173554420471), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Plannen en zoeken', 0), ('Organiseren en verwerken', 0), ('Publiceren en communiceren', 0)]
#
# Zoeken ter oriëntatie
#
# [('Kritisch beoordelen', nan), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 0.7524627447128296), ('Beoordelen van resultaten (kritisch)', 0.74579256772995), ('Waarde van informatie/data', 0.7393314838409424), ('Aard en verschijningsvormen van informatie/data', 0.7134826183319092), ('Synthetiseren of creëren van nieuwe informatie', 0.6877719163894653), ('Zoeken ter oriëntatie', 0.6809728741645813), ('Analyseren van zoekresultaten (informatieanalyse)', 0.6402978301048279), ('Publiceren (van eindproduct)', 0.6395046710968018), ('Identificeren van informatiebehoefte', 0.6383923292160034), ('Valoriseren van bevindingen (outreach)', 0.6320602893829346), ('Privacygevoelige informatie', 0.6173052787780762), ('Communiceren (van eindproduct)', 0.6133407950401306), ('Selecteren informatiebronnen en zoeksystemen', 0.6007100343704224), ('Samenwerken (in teams)', 0.5932289958000183), ('Individu in het informatielandschap', 0.5845051407814026), ('Formuleren van onderzoeksvraag', 0.5827140808105469), ('Werking en structuur van het internet', 0.582252025604248), ('Evalueren van zoekproces (kritisch)', 0.5675882697105408), ('Selecteren zoektermen', 0.5669575333595276), ('Manage proces en zoekresultaten', 0.5577324032783508), ('Zoeken naar informatie', 0.5348725318908691), ('Informatieverwerking (lezen, luisteren e.d.)', 0.5297214984893799), ('Bronvermelding', 0.525895357131958), ('Auteursrecht', 0.49272385239601135), ('Rol en totstandkoming van netwerken', 0.4612712562084198), ('Gebruik en verwerken van informatie (ethisch)', 0.39179113507270813), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Plannen en zoeken', 0), ('Organiseren en verwerken', 0), ('Publiceren en communiceren', 0)]
#
# Kritisch beoordelen
#
# [('Aard en verschijningsvormen van informatie/data', 0.7058555483818054), ('Zoeken ter oriëntatie', 0.6721780300140381), ('Kritisch beoordelen', nan), ('Publiceren (van eindproduct)', 0.6795659065246582), ('Bronvermelding', 0.668470025062561), ('Synthetiseren of creëren van nieuwe informatie', 0.6533141136169434), ('Beoordelingscriteria (relevantie/betrouwbaarheid)', 0.632994532585144), ('Communiceren (van eindproduct)', 0.6264816522598267), ('Valoriseren van bevindingen (outreach)', 0.6145744323730469), ('Beoordelen van resultaten (kritisch)', 0.5786920785903931), ('Selecteren informatiebronnen en zoeksystemen', 0.5736665725708008), ('Manage proces en zoekresultaten', 0.5673303604125977), ('Waarde van informatie/data', 0.5401424765586853), ('Samenwerken (in teams)', 0.49291718006134033), ('Selecteren zoektermen', 0.4923061728477478), ('Werking en structuur van het internet', 0.4919503927230835), ('Zoeken naar informatie', 0.4896755814552307), ('Analyseren van zoekresultaten (informatieanalyse)', 0.4879373610019684), ('Auteursrecht', 0.4785356819629669), ('Rol en totstandkoming van netwerken', 0.4783762991428375), ('Privacygevoelige informatie', 0.4696623980998993), ('Identificeren van informatiebehoefte', 0.4569868743419647), ('Individu in het informatielandschap', 0.4389343857765198), ('Evalueren van zoekproces (kritisch)', 0.4340757727622986), ('Formuleren van onderzoeksvraag', 0.4194142818450928), ('Informatieverwerking (lezen, luisteren e.d.)', 0.36499229073524475), ('Gebruik en verwerken van informatie (ethisch)', 0.294196218252182), ('Informatievaardigheden', 0), ('Oriënteren en specificeren', 0), ('Oriënteren op informatielandschap', 0), ('Plannen en zoeken', 0), ('Organiseren en verwerken', 0), ('Publiceren en communiceren', 0)]
#
# Aard en verschijningsvormen van informatie/data
